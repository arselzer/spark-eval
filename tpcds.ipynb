# %%
from pyspark.sql import SparkSession
import os

# %%
spark = SparkSession.builder \
        .master("local[12]") \
        .appName("app") \
        .config("spark.driver.memory", "45g") \
        .config("spark.executor.memory", "45g") \
        .config("spark.jars", "postgresql-42.3.3.jar") \
        .getOrCreate()
#spark.sparkContext.setLogLevel("DEBUG")
# Out:
# 23/10/25 14:26:37 WARN Utils: Your hostname, server-rennweg resolves to a loopback address: 127.0.1.1; using 192.168.1.196 instead (on interface enp5s0f1)
# 23/10/25 14:26:37 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 23/10/25 14:26:37 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/10/25 14:26:37 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
spark.sparkContext.setLogLevel("WARN") # ALL, DEBUG, WARN,
#spark.sparkContext.setLogLevel("ALL") # ALL, DEBUG, WARN,

# %%
username = os.environ.get('USERNAME', 'tpcds')
password = os.environ.get('PASSWORD', 'tpcds')
dbname = os.environ.get('DBNAME', 'tpcds')
dbhost = os.environ.get('DBHOST', 'localhost')

df_tables = spark.read.format("jdbc") \
    .option("url", f'jdbc:postgresql://{dbhost}:5432/{dbname}') \
    .option("driver", "org.postgresql.Driver") \
    .option("dbtable", "information_schema.tables") \
    .option("user", username) \
    .option("password", password) \
    .load()

for idx, row in df_tables.toPandas().iterrows():
        if row.table_schema == 'public':
            table_name = row.table_name
            df = spark.read.format("jdbc") \
                .option("url", f'jdbc:postgresql://{dbhost}:5432/{dbname}') \
                .option("driver", "org.postgresql.Driver") \
                .option("dbtable", table_name) \
                .option("user", username) \
                .option("password", password) \
                .load()
    
            print(table_name)
            print(df.show())
            df.createOrReplaceTempView(table_name)
# Out:
# dbgen_version
# +----------+--------------+-------------------+--------------------+
# |dv_version|dv_create_date|     dv_create_time|     dv_cmdline_args|
# +----------+--------------+-------------------+--------------------+
# |    2.10.0|    2023-10-25|1970-01-01 12:25:35|-terminate N -ver...|
# +----------+--------------+-------------------+--------------------+
#
# None
# customer_address
# +-------------+----------------+----------------+------------------+---------------+---------------+---------------+-----------------+--------+----------+-------------+-------------+--------------------+
# |ca_address_sk|   ca_address_id|ca_street_number|    ca_street_name| ca_street_type|ca_suite_number|        ca_city|        ca_county|ca_state|    ca_zip|   ca_country|ca_gmt_offset|    ca_location_type|
# +-------------+----------------+----------------+------------------+---------------+---------------+---------------+-----------------+--------+----------+-------------+-------------+--------------------+
# |            1|AAAAAAAABAAAAAAA|      18        |          Jackson |Parkway        |     Suite 280 |      Fairfield|  Maricopa County|      AZ|86192     |United States|        -7.00|condo               |
# |            2|AAAAAAAACAAAAAAA|      362       |    Washington 6th|RD             |     Suite 80  |       Fairview|      Taos County|      NM|85709     |United States|        -7.00|condo               |
# |            3|AAAAAAAADAAAAAAA|      585       |Dogwood Washington|Circle         |     Suite Q   |Pleasant Valley|      York County|      PA|12477     |United States|        -5.00|single family       |
# |            4|AAAAAAAAEAAAAAAA|      111       |            Smith |Wy             |     Suite A   |      Oak Ridge|Kit Carson County|      CO|88371     |United States|        -7.00|condo               |
# |            5|AAAAAAAAFAAAAAAA|      31        |          College |Blvd           |     Suite 180 |       Glendale|     Barry County|      MO|63951     |United States|        -6.00|single family       |
# |            6|AAAAAAAAGAAAAAAA|      59        |    Williams Sixth|Parkway        |     Suite 100 |       Lakeview|    Chelan County|      WA|98579     |United States|        -8.00|single family       |
# |            7|AAAAAAAAHAAAAAAA|            NULL|          Hill 7th|Road           |     Suite U   |     Farmington|             NULL|    NULL|39145     |United States|         NULL|                NULL|
# |            8|AAAAAAAAIAAAAAAA|      875       |          Lincoln |Ct.            |     Suite Y   |          Union|   Bledsoe County|      TN|38721     |United States|        -5.00|apartment           |
# |            9|AAAAAAAAJAAAAAAA|      819       |        1st Laurel|Ave            |     Suite 70  |       New Hope|     Perry County|      AL|39431     |United States|        -6.00|condo               |
# |           10|AAAAAAAAKAAAAAAA|      851       |   Woodland Poplar|ST             |     Suite Y   |   Martinsville|   Haines Borough|      AK|90419     |United States|        -9.00|condo               |
# |           11|AAAAAAAALAAAAAAA|      189       |          13th 2nd|Street         |     Suite 470 |    Maple Grove|   Madison County|      MT|68252     |United States|        -7.00|single family       |
# |           12|AAAAAAAAMAAAAAAA|      76        |           Ash 8th|Ct.            |     Suite O   |       Edgewood|   Mifflin County|      PA|10069     |United States|        -5.00|apartment           |
# |           13|AAAAAAAANAAAAAAA|      424       |       Main Second|Ln             |     Suite 130 |     Greenville|   Noxubee County|      MS|51387     |United States|        -6.00|single family       |
# |           14|AAAAAAAAOAAAAAAA|      923       |          Pine Oak|Dr.            |     Suite 100 |           NULL|  Lipscomb County|      TX|77752     |         NULL|        -6.00|                NULL|
# |           15|AAAAAAAAPAAAAAAA|      314       |           Spring |Ct.            |     Suite B   |        Oakland|Washington County|      OH|49843     |United States|        -5.00|apartment           |
# |           16|AAAAAAAAABAAAAAA|      576       |      Adams Center|Street         |     Suite J   |    Valley View|    Oldham County|      TX|75124     |United States|        -6.00|condo               |
# |           17|AAAAAAAABBAAAAAA|      801       |            Green |Dr.            |     Suite 0   |     Montpelier|  Richland County|      OH|48930     |United States|        -5.00|single family       |
# |           18|AAAAAAAACBAAAAAA|      460       |      Maple Spruce|Court          |     Suite 480 |     Somerville|    Potter County|      SD|57783     |United States|        -7.00|condo               |
# |           19|AAAAAAAADBAAAAAA|      611       |           Wilson |Way            |     Suite O   |        Oakdale|Tangipahoa Parish|      LA|79584     |United States|        -6.00|apartment           |
# |           20|AAAAAAAAEBAAAAAA|      675       |        Elm Wilson|Street         |     Suite I   |       Hopewell|  Williams County|      OH|40587     |United States|        -5.00|condo               |
# +-------------+----------------+----------------+------------------+---------------+---------------+---------------+-----------------+--------+----------+-------------+-------------+--------------------+
# only showing top 20 rows
#
# None
# customer_demographics
# 23/10/25 14:26:46 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +----------+---------+-----------------+--------------------+--------------------+----------------+------------+---------------------+--------------------+
# |cd_demo_sk|cd_gender|cd_marital_status| cd_education_status|cd_purchase_estimate|cd_credit_rating|cd_dep_count|cd_dep_employed_count|cd_dep_college_count|
# +----------+---------+-----------------+--------------------+--------------------+----------------+------------+---------------------+--------------------+
# |         1|        M|                M|Primary             |                 500|      Good      |           0|                    0|                   0|
# |         2|        F|                M|Primary             |                 500|      Good      |           0|                    0|                   0|
# |         3|        M|                S|Primary             |                 500|      Good      |           0|                    0|                   0|
# |         4|        F|                S|Primary             |                 500|      Good      |           0|                    0|                   0|
# |         5|        M|                D|Primary             |                 500|      Good      |           0|                    0|                   0|
# |         6|        F|                D|Primary             |                 500|      Good      |           0|                    0|                   0|
# |         7|        M|                W|Primary             |                 500|      Good      |           0|                    0|                   0|
# |         8|        F|                W|Primary             |                 500|      Good      |           0|                    0|                   0|
# |         9|        M|                U|Primary             |                 500|      Good      |           0|                    0|                   0|
# |        10|        F|                U|Primary             |                 500|      Good      |           0|                    0|                   0|
# |        11|        M|                M|Secondary           |                 500|      Good      |           0|                    0|                   0|
# |        12|        F|                M|Secondary           |                 500|      Good      |           0|                    0|                   0|
# |        13|        M|                S|Secondary           |                 500|      Good      |           0|                    0|                   0|
# |        14|        F|                S|Secondary           |                 500|      Good      |           0|                    0|                   0|
# |        15|        M|                D|Secondary           |                 500|      Good      |           0|                    0|                   0|
# |        16|        F|                D|Secondary           |                 500|      Good      |           0|                    0|                   0|
# |        17|        M|                W|Secondary           |                 500|      Good      |           0|                    0|                   0|
# |        18|        F|                W|Secondary           |                 500|      Good      |           0|                    0|                   0|
# |        19|        M|                U|Secondary           |                 500|      Good      |           0|                    0|                   0|
# |        20|        F|                U|Secondary           |                 500|      Good      |           0|                    0|                   0|
# +----------+---------+-----------------+--------------------+--------------------+----------------+------------+---------------------+--------------------+
# only showing top 20 rows
#
# None
# date_dim
# +---------+----------------+----------+-----------+----------+-------------+------+-----+-----+-----+-----+---------+----------------+-------------+----------+--------------+---------+---------+-------------------+-----------+----------+-------------+-------------+-------------+--------------+---------------+-----------------+--------------+
# |d_date_sk|       d_date_id|    d_date|d_month_seq|d_week_seq|d_quarter_seq|d_year|d_dow|d_moy|d_dom|d_qoy|d_fy_year|d_fy_quarter_seq|d_fy_week_seq|d_day_name|d_quarter_name|d_holiday|d_weekend|d_following_holiday|d_first_dom|d_last_dom|d_same_day_ly|d_same_day_lq|d_current_day|d_current_week|d_current_month|d_current_quarter|d_current_year|
# +---------+----------------+----------+-----------+----------+-------------+------+-----+-----+-----+-----+---------+----------------+-------------+----------+--------------+---------+---------+-------------------+-----------+----------+-------------+-------------+-------------+--------------+---------------+-----------------+--------------+
# |  2415022|AAAAAAAAOKJNECAA|1900-01-02|          0|         1|            1|  1900|    1|    1|    2|    1|     1900|               1|            1| Monday   |        1900Q1|        N|        N|                  Y|    2415021|   2415020|      2414657|      2414930|            N|             N|              N|                N|             N|
# |  2415023|AAAAAAAAPKJNECAA|1900-01-03|          0|         1|            1|  1900|    2|    1|    3|    1|     1900|               1|            1| Tuesday  |        1900Q1|        N|        N|                  N|    2415021|   2415020|      2414658|      2414931|            N|             N|              N|                N|             N|
# |  2415024|AAAAAAAAALJNECAA|1900-01-04|          0|         1|            1|  1900|    3|    1|    4|    1|     1900|               1|            1| Wednesday|        1900Q1|        N|        N|                  N|    2415021|   2415020|      2414659|      2414932|            N|             N|              N|                N|             N|
# |  2415025|AAAAAAAABLJNECAA|1900-01-05|          0|         1|            1|  1900|    4|    1|    5|    1|     1900|               1|            1| Thursday |        1900Q1|        N|        N|                  N|    2415021|   2415020|      2414660|      2414933|            N|             N|              N|                N|             N|
# |  2415026|AAAAAAAACLJNECAA|1900-01-06|          0|         1|            1|  1900|    5|    1|    6|    1|     1900|               1|            1| Friday   |        1900Q1|        N|        Y|                  N|    2415021|   2415020|      2414661|      2414934|            N|             N|              N|                N|             N|
# |  2415027|AAAAAAAADLJNECAA|1900-01-07|          0|         1|            1|  1900|    6|    1|    7|    1|     1900|               1|            1| Saturday |        1900Q1|        N|        Y|                  N|    2415021|   2415020|      2414662|      2414935|            N|             N|              N|                N|             N|
# |  2415028|AAAAAAAAELJNECAA|1900-01-08|          0|         1|            1|  1900|    0|    1|    8|    1|     1900|               1|            1| Sunday   |        1900Q1|        N|        N|                  N|    2415021|   2415020|      2414663|      2414936|            N|             N|              N|                N|             N|
# |  2415029|AAAAAAAAFLJNECAA|1900-01-09|          0|         2|            1|  1900|    1|    1|    9|    1|     1900|               1|            2| Monday   |        1900Q1|        N|        N|                  N|    2415021|   2415020|      2414664|      2414937|            N|             N|              N|                N|             N|
# |  2415030|AAAAAAAAGLJNECAA|1900-01-10|          0|         2|            1|  1900|    2|    1|   10|    1|     1900|               1|            2| Tuesday  |        1900Q1|        N|        N|                  N|    2415021|   2415020|      2414665|      2414938|            N|             N|              N|                N|             N|
# |  2415031|AAAAAAAAHLJNECAA|1900-01-11|          0|         2|            1|  1900|    3|    1|   11|    1|     1900|               1|            2| Wednesday|        1900Q1|        N|        N|                  N|    2415021|   2415020|      2414666|      2414939|            N|             N|              N|                N|             N|
# |  2415032|AAAAAAAAILJNECAA|1900-01-12|          0|         2|            1|  1900|    4|    1|   12|    1|     1900|               1|            2| Thursday |        1900Q1|        N|        N|                  N|    2415021|   2415020|      2414667|      2414940|            N|             N|              N|                N|             N|
# |  2415033|AAAAAAAAJLJNECAA|1900-01-13|          0|         2|            1|  1900|    5|    1|   13|    1|     1900|               1|            2| Friday   |        1900Q1|        N|        Y|                  N|    2415021|   2415020|      2414668|      2414941|            N|             N|              N|                N|             N|
# |  2415034|AAAAAAAAKLJNECAA|1900-01-14|          0|         2|            1|  1900|    6|    1|   14|    1|     1900|               1|            2| Saturday |        1900Q1|        N|        Y|                  N|    2415021|   2415020|      2414669|      2414942|            N|             N|              N|                N|             N|
# |  2415035|AAAAAAAALLJNECAA|1900-01-15|          0|         2|            1|  1900|    0|    1|   15|    1|     1900|               1|            2| Sunday   |        1900Q1|        N|        N|                  N|    2415021|   2415020|      2414670|      2414943|            N|             N|              N|                N|             N|
# |  2415036|AAAAAAAAMLJNECAA|1900-01-16|          0|         3|            1|  1900|    1|    1|   16|    1|     1900|               1|            3| Monday   |        1900Q1|        N|        N|                  N|    2415021|   2415020|      2414671|      2414944|            N|             N|              N|                N|             N|
# |  2415037|AAAAAAAANLJNECAA|1900-01-17|          0|         3|            1|  1900|    2|    1|   17|    1|     1900|               1|            3| Tuesday  |        1900Q1|        N|        N|                  N|    2415021|   2415020|      2414672|      2414945|            N|             N|              N|                N|             N|
# |  2415038|AAAAAAAAOLJNECAA|1900-01-18|          0|         3|            1|  1900|    3|    1|   18|    1|     1900|               1|            3| Wednesday|        1900Q1|        N|        N|                  N|    2415021|   2415020|      2414673|      2414946|            N|             N|              N|                N|             N|
# |  2415039|AAAAAAAAPLJNECAA|1900-01-19|          0|         3|            1|  1900|    4|    1|   19|    1|     1900|               1|            3| Thursday |        1900Q1|        N|        N|                  N|    2415021|   2415020|      2414674|      2414947|            N|             N|              N|                N|             N|
# |  2415040|AAAAAAAAAMJNECAA|1900-01-20|          0|         3|            1|  1900|    5|    1|   20|    1|     1900|               1|            3| Friday   |        1900Q1|        N|        Y|                  N|    2415021|   2415020|      2414675|      2414948|            N|             N|              N|                N|             N|
# |  2415041|AAAAAAAABMJNECAA|1900-01-21|          0|         3|            1|  1900|    6|    1|   21|    1|     1900|               1|            3| Saturday |        1900Q1|        N|        Y|                  N|    2415021|   2415020|      2414676|      2414949|            N|             N|              N|                N|             N|
# +---------+----------------+----------+-----------+----------+-------------+------+-----+-----+-----+-----+---------+----------------+-------------+----------+--------------+---------+---------+-------------------+-----------+----------+-------------+-------------+-------------+--------------+---------------+-----------------+--------------+
# only showing top 20 rows
#
# None
# warehouse
# +--------------+----------------+--------------------+-----------------+---------------+-------------+---------------+--------------+-------------+--------------+-------+----------+-------------+------------+
# |w_warehouse_sk|  w_warehouse_id|    w_warehouse_name|w_warehouse_sq_ft|w_street_number|w_street_name|  w_street_type|w_suite_number|       w_city|      w_county|w_state|     w_zip|    w_country|w_gmt_offset|
# +--------------+----------------+--------------------+-----------------+---------------+-------------+---------------+--------------+-------------+--------------+-------+----------+-------------+------------+
# |             1|AAAAAAAABAAAAAAA| Conventional childr|           977787|     651       |         6th |Parkway        |    Suite 470 |    Riverside|Ziebach County|     SD|59231     |United States|       -6.00|
# |             2|AAAAAAAACAAAAAAA|Important issues liv|           138504|     600       |   View First|Avenue         |    Suite P   |     Fairview| Walker County|     AL|35709     |United States|       -6.00|
# |             3|AAAAAAAADAAAAAAA|         Doors canno|           294242|     534       |   Ash Laurel|Dr.            |    Suite 0   |    Riverside|Ziebach County|     SD|59231     |United States|       -6.00|
# |             4|AAAAAAAAEAAAAAAA|Bad cards must make.|           621234|     368       |   Wilson Elm|Drive          |    Suite 80  |     Fairview|Ziebach County|     SD|55709     |United States|       -6.00|
# |             5|AAAAAAAAFAAAAAAA|                NULL|             NULL|           NULL|         NULL|           NULL|          NULL|    Riverside| Walker County|     AL|39231     |United States|        NULL|
# |             6|AAAAAAAAGAAAAAAA|Local, mass universi|           838797|     957       |Lincoln Adams|Dr.            |    Suite X   |    Riverside|Ziebach County|     SD|59231     |United States|       -6.00|
# |             7|AAAAAAAAHAAAAAAA|      Quite effectiv|           662475|     69        |   7th Sunset|Ct.            |    Suite 350 |Pleasant Hill|Ziebach County|     SD|53604     |United States|       -6.00|
# |             8|AAAAAAAAIAAAAAAA|    Plain, reluctant|           514427|     410       |         3rd |ST             |    Suite 370 |    Riverside|Ziebach County|     SD|59231     |United States|       -6.00|
# |             9|AAAAAAAAJAAAAAAA|         Rooms cook |            73065|     420       |      Spring |Wy             |    Suite I   |    Oak Grove|Ziebach County|     SD|58370     |United States|       -6.00|
# |            10|AAAAAAAAKAAAAAAA|    National, comple|           914242|     269       |  Elm Madison|Street         |    Suite 90  |Pleasant Hill|Ziebach County|     SD|53604     |United States|       -6.00|
# +--------------+----------------+--------------------+-----------------+---------------+-------------+---------------+--------------+-------------+--------------+-------+----------+-------------+------------+
#
# None
# ship_mode
# +---------------+----------------+--------------------+----------+--------------------+--------------------+
# |sm_ship_mode_sk| sm_ship_mode_id|             sm_type|   sm_code|          sm_carrier|         sm_contract|
# +---------------+----------------+--------------------+----------+--------------------+--------------------+
# |              1|AAAAAAAABAAAAAAA|EXPRESS          ...|AIR       |UPS                 |YvxVaJI10           |
# |              2|AAAAAAAACAAAAAAA|NEXT DAY         ...|AIR       |FEDEX               |ldhM8IvpzHgdbBgDfI  |
# |              3|AAAAAAAADAAAAAAA|OVERNIGHT        ...|AIR       |AIRBORNE            |6Hzzp4JkzjqD8MGXLCDa|
# |              4|AAAAAAAAEAAAAAAA|TWO DAY          ...|AIR       |USPS                |UaAJjKDnL4gTOqbpj   |
# |              5|AAAAAAAAFAAAAAAA|LIBRARY          ...|AIR       |DHL                 |HVDFCcQ             |
# |              6|AAAAAAAAGAAAAAAA|REGULAR          ...|SURFACE   |TBS                 |Ek                  |
# |              7|AAAAAAAAHAAAAAAA|EXPRESS          ...|SURFACE   |ZHOU                |hGoF18SLDDPBj       |
# |              8|AAAAAAAAIAAAAAAA|NEXT DAY         ...|SURFACE   |ZOUROS              |yVfotg7Tio3MVhBg6Bkn|
# |              9|AAAAAAAAJAAAAAAA|OVERNIGHT        ...|SURFACE   |MSC                 |Xjy3ZPuiDjzHlRx14Z3 |
# |             10|AAAAAAAAKAAAAAAA|TWO DAY          ...|SURFACE   |LATVIAN             |P7FBIt8yd           |
# |             11|AAAAAAAALAAAAAAA|LIBRARY          ...|SURFACE   |ALLIANCE            |OrDuVy2H            |
# |             12|AAAAAAAAMAAAAAAA|REGULAR          ...|SEA       |ORIENTAL            |GNJr3g5i7oorKqtX    |
# |             13|AAAAAAAANAAAAAAA|EXPRESS          ...|SEA       |BARIAN              |qENFQ               |
# |             14|AAAAAAAAOAAAAAAA|NEXT DAY         ...|SEA       |BOXBUNDLES          |A5BYO1qH8HGTTN      |
# |             15|AAAAAAAAPAAAAAAA|OVERNIGHT        ...|SEA       |GREAT EASTERN       |uukTktPYycct8       |
# |             16|AAAAAAAAABAAAAAA|TWO DAY          ...|SEA       |DIAMOND             |2mM8l               |
# |             17|AAAAAAAABBAAAAAA|LIBRARY          ...|SEA       |RUPEKSA             |5FKNB0j8aaqTB       |
# |             18|AAAAAAAACBAAAAAA|REGULAR          ...|BIKE      |GERMA               |I3uCelXtjP          |
# |             19|AAAAAAAADBAAAAAA|EXPRESS          ...|BIKE      |HARMSTORF           |fop0bcSd91J26IVpR   |
# |             20|AAAAAAAAEBAAAAAA|NEXT DAY         ...|BIKE      |PRIVATECARRIER      |O9V6oF8RJnLMmZYd1   |
# +---------------+----------------+--------------------+----------+--------------------+--------------------+
#
# None
# time_dim
# +---------+----------------+------+------+--------+--------+-------+--------------------+--------------------+-----------+
# |t_time_sk|       t_time_id|t_time|t_hour|t_minute|t_second|t_am_pm|             t_shift|         t_sub_shift|t_meal_time|
# +---------+----------------+------+------+--------+--------+-------+--------------------+--------------------+-----------+
# |        0|AAAAAAAABAAAAAAA|     0|     0|       0|       0|     AM|third               |night               |       NULL|
# |        1|AAAAAAAACAAAAAAA|     1|     0|       0|       1|     AM|third               |night               |       NULL|
# |        2|AAAAAAAADAAAAAAA|     2|     0|       0|       2|     AM|third               |night               |       NULL|
# |        3|AAAAAAAAEAAAAAAA|     3|     0|       0|       3|     AM|third               |night               |       NULL|
# |        4|AAAAAAAAFAAAAAAA|     4|     0|       0|       4|     AM|third               |night               |       NULL|
# |        5|AAAAAAAAGAAAAAAA|     5|     0|       0|       5|     AM|third               |night               |       NULL|
# |        6|AAAAAAAAHAAAAAAA|     6|     0|       0|       6|     AM|third               |night               |       NULL|
# |        7|AAAAAAAAIAAAAAAA|     7|     0|       0|       7|     AM|third               |night               |       NULL|
# |        8|AAAAAAAAJAAAAAAA|     8|     0|       0|       8|     AM|third               |night               |       NULL|
# |        9|AAAAAAAAKAAAAAAA|     9|     0|       0|       9|     AM|third               |night               |       NULL|
# |       10|AAAAAAAALAAAAAAA|    10|     0|       0|      10|     AM|third               |night               |       NULL|
# |       11|AAAAAAAAMAAAAAAA|    11|     0|       0|      11|     AM|third               |night               |       NULL|
# |       12|AAAAAAAANAAAAAAA|    12|     0|       0|      12|     AM|third               |night               |       NULL|
# |       13|AAAAAAAAOAAAAAAA|    13|     0|       0|      13|     AM|third               |night               |       NULL|
# |       14|AAAAAAAAPAAAAAAA|    14|     0|       0|      14|     AM|third               |night               |       NULL|
# |       15|AAAAAAAAABAAAAAA|    15|     0|       0|      15|     AM|third               |night               |       NULL|
# |       16|AAAAAAAABBAAAAAA|    16|     0|       0|      16|     AM|third               |night               |       NULL|
# |       17|AAAAAAAACBAAAAAA|    17|     0|       0|      17|     AM|third               |night               |       NULL|
# |       18|AAAAAAAADBAAAAAA|    18|     0|       0|      18|     AM|third               |night               |       NULL|
# |       19|AAAAAAAAEBAAAAAA|    19|     0|       0|      19|     AM|third               |night               |       NULL|
# +---------+----------------+------+------+--------+--------+-------+--------------------+--------------------+-----------+
# only showing top 20 rows
#
# None
# reason
# +-----------+----------------+--------------------+
# |r_reason_sk|     r_reason_id|       r_reason_desc|
# +-----------+----------------+--------------------+
# |          1|AAAAAAAABAAAAAAA|Package was damag...|
# |          2|AAAAAAAACAAAAAAA|Stopped working  ...|
# |          3|AAAAAAAADAAAAAAA|Did not get it on...|
# |          4|AAAAAAAAEAAAAAAA|Not the product t...|
# |          5|AAAAAAAAFAAAAAAA|Parts missing    ...|
# |          6|AAAAAAAAGAAAAAAA|Does not work wit...|
# |          7|AAAAAAAAHAAAAAAA|Gift exchange    ...|
# |          8|AAAAAAAAIAAAAAAA|Did not like the ...|
# |          9|AAAAAAAAJAAAAAAA|Did not like the ...|
# |         10|AAAAAAAAKAAAAAAA|Did not like the ...|
# |         11|AAAAAAAALAAAAAAA|Did not like the ...|
# |         12|AAAAAAAAMAAAAAAA|No service locati...|
# |         13|AAAAAAAANAAAAAAA|Found a better pr...|
# |         14|AAAAAAAAOAAAAAAA|Found a better ex...|
# |         15|AAAAAAAAPAAAAAAA|Not working any m...|
# |         16|AAAAAAAAABAAAAAA|Did not fit      ...|
# |         17|AAAAAAAABBAAAAAA|Wrong size       ...|
# |         18|AAAAAAAACBAAAAAA|Lost my job      ...|
# |         19|AAAAAAAADBAAAAAA|unauthoized purch...|
# |         20|AAAAAAAAEBAAAAAA|duplicate purchas...|
# +-----------+----------------+--------------------+
# only showing top 20 rows
#
# None
# income_band
# +-----------------+--------------+--------------+
# |ib_income_band_sk|ib_lower_bound|ib_upper_bound|
# +-----------------+--------------+--------------+
# |                1|             0|         10000|
# |                2|         10001|         20000|
# |                3|         20001|         30000|
# |                4|         30001|         40000|
# |                5|         40001|         50000|
# |                6|         50001|         60000|
# |                7|         60001|         70000|
# |                8|         70001|         80000|
# |                9|         80001|         90000|
# |               10|         90001|        100000|
# |               11|        100001|        110000|
# |               12|        110001|        120000|
# |               13|        120001|        130000|
# |               14|        130001|        140000|
# |               15|        140001|        150000|
# |               16|        150001|        160000|
# |               17|        160001|        170000|
# |               18|        170001|        180000|
# |               19|        180001|        190000|
# |               20|        190001|        200000|
# +-----------------+--------------+--------------+
#
# None
# item
# +---------+----------------+----------------+--------------+--------------------+---------------+----------------+----------+--------------------+----------+--------------------+-------------+--------------------+-------------+--------------------+--------------------+--------------------+--------------------+----------+-----------+------------+--------------------+
# |i_item_sk|       i_item_id|i_rec_start_date|i_rec_end_date|         i_item_desc|i_current_price|i_wholesale_cost|i_brand_id|             i_brand|i_class_id|             i_class|i_category_id|          i_category|i_manufact_id|          i_manufact|              i_size|       i_formulation|             i_color|   i_units|i_container|i_manager_id|      i_product_name|
# +---------+----------------+----------------+--------------+--------------------+---------------+----------------+----------+--------------------+----------+--------------------+-------------+--------------------+-------------+--------------------+--------------------+--------------------+--------------------+----------+-----------+------------+--------------------+
# |        1|AAAAAAAABAAAAAAA|      1997-10-27|          NULL|Powers will not g...|          27.02|           23.23|   5003002|exportischolar #2...|         3|pop              ...|            5|Music            ...|           52|ableanti         ...|N/A                 |3663peru009490160959|spring              |Tsp       | Unknown   |           6|ought            ...|
# |        2|AAAAAAAACAAAAAAA|      1997-10-27|    2000-10-26|False opportuniti...|           1.12|            0.38|   1001001|amalgamalg #1    ...|         1|dresses          ...|            1|Women            ...|          294|esen stable      ...|petite              |516steel060826230906|rosy                |Bunch     | Unknown   |          98|able             ...|
# |        3|AAAAAAAACAAAAAAA|      2000-10-27|          NULL|False opportuniti...|           7.11|            0.38|   1001001|brandbrand #4    ...|         7|decor            ...|            7|Home             ...|          294|esen stable      ...|N/A                 |516steel060826230906|sienna              |Cup       | Unknown   |          18|pri              ...|
# |        4|AAAAAAAAEAAAAAAA|      1997-10-27|    1999-10-27|Normal systems wo...|           1.35|            0.85|   3002001|importoexporti #1...|         2|infants          ...|            3|Children         ...|          479|n stationese     ...|extra large         |610157moccasin018327|red                 |Tbl       | Unknown   |          26|ese              ...|
# |        5|AAAAAAAAEAAAAAAA|      1999-10-28|    2001-10-26|Normal systems wo...|           4.00|            1.76|   2002002|importoimporto #2...|         2|shirts           ...|            2|Men              ...|          220|barableable      ...|petite              |42214rosy28066558020|pink                |Cup       | Unknown   |          27|anti             ...|
# |        6|AAAAAAAAEAAAAAAA|      2001-10-27|          NULL|Normal systems wo...|           0.85|            1.76|   2002002|exportiimporto #1...|         3|pants            ...|            2|Men              ...|          212|barableable      ...|large               |42214rosy28066558020|moccasin            |Bundle    | Unknown   |           6|cally            ...|
# |        7|AAAAAAAAHAAAAAAA|      1997-10-27|          NULL|Anxious accounts ...|           9.94|            6.75|   3001002|amalgexporti #2  ...|         1|newborn          ...|            3|Children         ...|          214|eseoughtable     ...|petite              |6moccasin24027188872|spring              |Tsp       | Unknown   |          64|ation            ...|
# |        8|AAAAAAAAIAAAAAAA|      1997-10-27|    2000-10-26|                   F|           2.76|            0.85|   3003001|exportiexporti #1...|         3|toddlers         ...|            3|Children         ...|          630|barprically      ...|extra large         |35123wheat3256343398|turquoise           |Carton    | Unknown   |          25|eing             ...|
# |        9|AAAAAAAAIAAAAAAA|      2000-10-27|          NULL|                   F|           4.46|            0.85|   1004002|edu packamalg #2 ...|         3|swimwear         ...|            1|Women            ...|          630|barprically      ...|medium              |35123wheat3256343398|wheat               |Tbl       | Unknown   |           3|n st             ...|
# |       10|AAAAAAAAKAAAAAAA|      1997-10-27|    1999-10-27|Classical service...|           8.94|            4.11|  10008011|namelessunivamalg...|         8|scanners         ...|           10|Electronics      ...|          350|barantipri       ...|N/A                 |8159007505thistle447|pale                |Tsp       | Unknown   |          34|barought         ...|
# |       11|AAAAAAAAKAAAAAAA|      1999-10-28|    2001-10-26|         Correct, fo|          54.87|            4.11|  10008011|edu packbrand #4 ...|        14|estate           ...|            6|Jewelry          ...|          625|antiablecally    ...|N/A                 |snow1543775706017405|yellow              |Bunch     | Unknown   |          26|oughtought       ...|
# |       12|AAAAAAAAKAAAAAAA|      2001-10-27|          NULL|Corporate, import...|           6.54|            4.11|  10008011|corpnameless #3  ...|        14|furniture        ...|            7|Home             ...|          264|esecallyable     ...|N/A                 |968467777sky92069287|royal               |Tbl       | Unknown   |          19|ableought        ...|
# |       13|AAAAAAAANAAAAAAA|      1997-10-27|          NULL|Hard, private dep...|           8.76|            7.62|   6012006|importobrand #6  ...|        12|costume          ...|            6|Jewelry          ...|          167|ationcallyought  ...|N/A                 |883208731996blue7862|olive               |Bundle    | Unknown   |          51|priought         ...|
# |       14|AAAAAAAAOAAAAAAA|      1997-10-27|    2000-10-26|Teachers carry by...|           1.85|            0.59|   8007005|brandnameless #5 ...|         7|hockey           ...|            8|Sports           ...|          460|barcallyese      ...|N/A                 |1144670162goldenrod2|red                 |Dram      | Unknown   |           6|eseought         ...|
# |       15|AAAAAAAAOAAAAAAA|      2000-10-27|          NULL|Teachers carry by...|           2.57|            0.59|   5002002|importoscholar #2...|         2|country          ...|            5|Music            ...|           86|barcallyese      ...|N/A                 |1144670162goldenrod2|royal               |Pound     | Unknown   |          11|antiought        ...|
# |       16|AAAAAAAAABAAAAAA|      1997-10-27|    1999-10-27|Dominant, christi...|           0.31|            0.14|   1002001|importoamalg #1  ...|         2|fragrances       ...|            1|Women            ...|          117|ationoughtought  ...|large               |36933056603steel7373|bisque              |Lb        | Unknown   |          23|callyought       ...|
# |       17|AAAAAAAAABAAAAAA|      1999-10-28|    2001-10-26|Dominant, christi...|           6.49|            0.14|   1002001|amalgimporto #2  ...|         1|accessories      ...|            2|Men              ...|          117|ationoughtought  ...|extra large         |452645olive281530722|snow                |Dram      | Unknown   |          41|ationought       ...|
# |       18|AAAAAAAAABAAAAAA|      2001-10-27|          NULL|Twin, particular ...|           0.87|            0.48|   1002001|importoamalg #1  ...|         2|fragrances       ...|            1|Women            ...|          117|ationoughtought  ...|medium              |452645olive281530722|rosy                |Carton    | Unknown   |          63|eingought        ...|
# |       19|AAAAAAAADBAAAAAA|      1997-10-27|          NULL|Political parents...|          10.61|            4.77|   2004002|edu packimporto #...|         4|sports-apparel   ...|            2|Men              ...|          364|esecallypri      ...|large               |85seashell1303417084|smoke               |Ton       | Unknown   |          13|n stought        ...|
# |       20|AAAAAAAAEBAAAAAA|      1997-10-27|    2000-10-26|Legal, foreign da...|          29.35|           18.78|   1003001|exportiamalg #1  ...|         3|maternity        ...|            1|Women            ...|          995|antin stn st     ...|extra large         |97245417ivory0043452|tan                 |Gram      | Unknown   |          21|barable          ...|
# +---------+----------------+----------------+--------------+--------------------+---------------+----------------+----------+--------------------+----------+--------------------+-------------+--------------------+-------------+--------------------+--------------------+--------------------+--------------------+----------+-----------+------------+--------------------+
# only showing top 20 rows
#
# None
# store
# +----------+----------------+----------------+--------------+----------------+------------+------------------+-------------+--------------------+----------------+-----------+-----------------+--------------------+----------------+-------------+---------------+------------+--------------+---------------+--------------+---------------+--------------+-------------+-----------------+-------+----------+-------------+------------+----------------+
# |s_store_sk|      s_store_id|s_rec_start_date|s_rec_end_date|s_closed_date_sk|s_store_name|s_number_employees|s_floor_space|             s_hours|       s_manager|s_market_id|s_geography_class|       s_market_desc|s_market_manager|s_division_id|s_division_name|s_company_id|s_company_name|s_street_number| s_street_name|  s_street_type|s_suite_number|       s_city|         s_county|s_state|     s_zip|    s_country|s_gmt_offset|s_tax_precentage|
# +----------+----------------+----------------+--------------+----------------+------------+------------------+-------------+--------------------+----------------+-----------+-----------------+--------------------+----------------+-------------+---------------+------------+--------------+---------------+--------------+---------------+--------------+-------------+-----------------+-------+----------+-------------+------------+----------------+
# |         1|AAAAAAAABAAAAAAA|      1997-03-13|          NULL|         2451189|       ought|               245|      5250760|8AM-4PM             |    William Ward|          2|          Unknown|Enough high areas...| Charles Bartley|            1|        Unknown|           1|       Unknown|            767|       Spring |Wy             |    Suite 250 |Pleasant Hill|   Ziebach County|     SD|53604     |United States|       -6.00|            0.03|
# |         2|AAAAAAAACAAAAAAA|      1997-03-13|    2000-03-12|            NULL|        able|               236|      5285950|8AM-4PM             |     Scott Smith|          8|          Unknown|Parliamentary can...|David Lamontagne|            1|        Unknown|           1|       Unknown|            255|     Sycamore |Dr.            |    Suite 410 |       Midway|   Ziebach County|     SD|51904     |United States|       -6.00|            0.03|
# |         3|AAAAAAAACAAAAAAA|      2000-03-13|          NULL|            NULL|        able|               236|      7557959|8AM-4PM             |     Scott Smith|          7|          Unknown|Impossible, true ...|David Lamontagne|            1|        Unknown|           1|       Unknown|            877|   Park Laurel|Road           |    Suite T   |       Midway|Williamson County|     TN|31904     |United States|       -5.00|            0.03|
# |         4|AAAAAAAAEAAAAAAA|      1997-03-13|    1999-03-13|         2451044|         ese|               218|      9341467|8AM-4PM             |     Edwin Adams|          4|          Unknown|Events would achi...|  Thomas Pollack|            1|        Unknown|           1|       Unknown|             27|         Lake |Ln             |    Suite 260 |Pleasant Hill|Williamson County|     TN|33604     |United States|       -5.00|            0.03|
# |         5|AAAAAAAAEAAAAAAA|      1999-03-14|    2001-03-12|         2450910|        anti|               288|      9078805|8AM-4PM             |     Edwin Adams|          8|          Unknown|Events would achi...|  Thomas Pollack|            1|        Unknown|           1|       Unknown|             27|       Lee 6th|Court          |    Suite 80  |    Riverside|   Ziebach County|     SD|59231     |United States|       -6.00|            0.03|
# |         6|AAAAAAAAEAAAAAAA|      2001-03-13|          NULL|            NULL|       cally|               229|      9026222|8AM-4PM             |     Edwin Adams|         10|          Unknown|Events would achi...|  Thomas Pollack|            1|        Unknown|           1|       Unknown|            220|          6th |Lane           |    Suite 140 |    Oak Grove|   Ziebach County|     SD|58370     |United States|       -6.00|            0.03|
# |         7|AAAAAAAAHAAAAAAA|      1997-03-13|          NULL|            NULL|       ation|               297|      8954883|8AM-4PM             |    David Thomas|          9|          Unknown|     Architects coul|   Thomas Benton|            1|        Unknown|           1|       Unknown|            811|          Lee |Circle         |    Suite T   |    Oak Grove|   Ziebach County|     SD|58370     |United States|       -6.00|            0.01|
# |         8|AAAAAAAAIAAAAAAA|      1997-03-13|    2000-03-12|            NULL|        eing|               278|      6995995|8AM-4PM             |     Brett Yates|          2|          Unknown|Various bars make...|   Dean Morrison|            1|        Unknown|           1|       Unknown|            226|         12th |Lane           |    Suite D   |    Riverside|    Walker County|     AL|39231     |United States|       -6.00|            0.08|
# |         9|AAAAAAAAIAAAAAAA|      2000-03-13|          NULL|            NULL|        eing|               271|      6995995|8AM-4PM             |     Brett Yates|          2|          Unknown|Formal, psycholog...|   Dean Morrison|            1|        Unknown|           1|       Unknown|            226|         Hill |Boulevard      |    Suite 190 |       Midway|    Walker County|     AL|31904     |United States|       -6.00|            0.08|
# |        10|AAAAAAAAKAAAAAAA|      1997-03-13|    1999-03-13|            NULL|         bar|               294|      9294113|8AM-4PM             |  Raymond Jacobs|          8|          Unknown|Little expectatio...|  Michael Wilson|            1|        Unknown|           1|       Unknown|            175|          4th |Court          |    Suite C   |    Oak Grove|Williamson County|     TN|38370     |United States|       -5.00|            0.06|
# |        11|AAAAAAAAKAAAAAAA|      1999-03-14|    2001-03-12|            NULL|       ought|               294|      9294113|8AM-4PM             |  Raymond Jacobs|          6|          Unknown|  Mysterious employe|  Michael Wilson|            1|        Unknown|           1|       Unknown|            175|    Park Green|Court          |    Suite 160 |    Oak Grove|Williamson County|     TN|38370     |United States|       -5.00|            0.11|
# |        12|AAAAAAAAKAAAAAAA|      2001-03-13|          NULL|            NULL|       ought|               294|      5219562|8AM-12AM            | Robert Thompson|          6|          Unknown|    Events develop i|    Dustin Kelly|            1|        Unknown|           1|       Unknown|            337|      College |Boulevard      |    Suite 100 |  Five Points|    Walker County|     AL|38370     |United States|       -5.00|            0.01|
# |        13|AAAAAAAANAAAAAAA|      1997-03-13|          NULL|            NULL|         pri|               219|      8157564|8AM-12AM            |      John Mccoy|          2|          Unknown|As modern fields ...|   Roger Nichols|            1|        Unknown|           1|       Unknown|             84|        First |Cir.           |    Suite 180 |Pleasant Hill|   Ziebach County|     SD|53604     |United States|       -6.00|            0.07|
# |        14|AAAAAAAAOAAAAAAA|      1997-03-13|    2000-03-12|            NULL|         ese|               291|      8724265|8AM-4PM             |   Ricky Nichols|          1|          Unknown|Products demonstr...|    Jamie Dorsey|            1|        Unknown|           1|       Unknown|            408|Washington 1st|Circle         |    Suite 390 |    Oak Grove|   Ziebach County|     SD|58370     |United States|       -6.00|            0.06|
# |        15|AAAAAAAAOAAAAAAA|      2000-03-13|          NULL|            NULL|        anti|               291|      8724265|8AM-4PM             |  Matt Frederick|          1|          Unknown|Products demonstr...| Michael Redding|            1|        Unknown|           1|       Unknown|            408| Franklin Hill|Boulevard      |    Suite 20  |       Midway|Williamson County|     TN|31904     |United States|       -5.00|            0.06|
# |        16|AAAAAAAAABAAAAAA|      1997-03-13|    1999-03-13|            NULL|       cally|               220|      5633347|8AM-12AM            |   Wayne Coleman|          5|          Unknown|Basically raw wor...|    Richard Bell|            1|        Unknown|           1|       Unknown|            588|     View Mill|Court          |    Suite 160 |Pleasant Hill|   Ziebach County|     SD|53604     |United States|       -6.00|            0.08|
# |        17|AAAAAAAAABAAAAAA|      1999-03-14|    2001-03-12|            NULL|       ation|               220|      5633347|8AM-8AM             |Franklin Mcclure|          5|          Unknown|Ostensibly short ...|    Richard Bell|            1|        Unknown|           1|       Unknown|            588|   Washington |Cir.           |    Suite 170 |  Five Points|Williamson County|     TN|53604     |United States|       -6.00|            0.08|
# |        18|AAAAAAAAABAAAAAA|      2001-03-13|          NULL|            NULL|        eing|               256|      7963229|8AM-4PM             |Scott Mclaughlin|          9|          Unknown|Away underlying d...|    Richard Bell|            1|        Unknown|           1|       Unknown|            588|        Sixth |Lane           |    Suite 20  |Pleasant Hill|    Walker County|     AL|53604     |United States|       -6.00|            0.07|
# |        19|AAAAAAAADBAAAAAA|      1997-03-13|          NULL|         2451267|        n st|               289|      8618762|8AM-4PM             |      Alva Abner|          3|          Unknown|Different, lovely...|     David Smith|            1|        Unknown|           1|       Unknown|            240|       Willow |RD             |    Suite 280 |    Riverside|    Walker County|     AL|39231     |United States|       -6.00|            0.01|
# |        20|AAAAAAAAEBAAAAAA|      1997-03-13|    2000-03-12|            NULL|         bar|               278|      7449959|8AM-4PM             |    Brian Norris|          9|          Unknown|Local, high faces...|    Dennis Glass|            1|        Unknown|           1|       Unknown|            200|         Lake |RD             |    Suite 320 |Pleasant Hill|   Ziebach County|     SD|53604     |United States|       -6.00|            0.05|
# ...
# |        2450815|          29485|        2450868|             114601|          797995|            6189|         159583|             114601|          797995|            6189|         159583|                7|                42|             17|             10|     12328|         72|              2|         30|            72.82|        88.84|         71.07|             533.10|           2132.10|              2184.60|          2665.20|     21.32|         0.00|          133.20|    2132.10|            2153.42|             2265.30|                 2286.62|       -52.50|
# |        2450815|          29485|        2450831|             114601|          797995|            6189|         159583|             114601|          797995|            6189|         159583|                7|                85|              1|              8|     61999|        352|              2|         40|            94.56|       277.06|          2.77|           10971.60|            110.80|              3782.40|         11082.40|      2.21|         0.00|          664.80|     110.80|             113.01|              775.60|                  777.81|     -3671.60|
# |        2450815|          29485|        2450839|             114601|          797995|            6189|         159583|             114601|          797995|            6189|         159583|                7|                21|              8|              9|     87505|        231|              2|         40|            25.96|        54.51|         15.80|            1548.40|            632.00|              1038.40|          2180.40|     22.75|       176.96|         1090.00|     455.04|             477.79|             1545.04|                 1567.79|      -583.36|
# |        2450815|          29485|        2450825|             114601|          797995|            6189|         159583|             114601|          797995|            6189|         159583|                7|                89|             20|              3|     64726|        196|              2|         45|             5.95|        12.97|          8.81|             187.20|            396.45|               267.75|           583.65|      3.96|         0.00|           17.10|     396.45|             400.41|              413.55|                  417.51|       128.70|
# |        2450815|          29485|        2450837|             114601|          797995|            6189|         159583|             114601|          797995|            6189|         159583|                7|                31|              7|              6|     19552|        171|              2|         34|            43.69|       105.29|         82.12|             787.78|           2792.08|              1485.46|          3579.86|     55.84|         0.00|          930.58|    2792.08|            2847.92|             3722.66|                 3778.50|      1306.62|
# |        2450815|          29485|        2450822|             114601|          797995|            6189|         159583|             114601|          797995|            6189|         159583|                7|               106|             16|              5|     20356|        223|              2|         59|            78.90|        84.42|         82.73|              99.71|           4881.07|              4655.10|          4980.78|    292.86|         0.00|         1444.32|    4881.07|            5173.93|             6325.39|                 6618.25|       225.97|
# |        2450815|          29485|        2450895|             114601|          797995|            6189|         159583|             114601|          797995|            6189|         159583|                7|                17|             19|              4|      4072|        231|              2|         94|            41.36|       105.88|         50.82|            5175.64|           4777.08|              3887.84|          9952.72|    191.08|         0.00|          497.26|    4777.08|            4968.16|             5274.34|                 5465.42|       889.24|
# |        2450815|          29485|        2450892|             114601|          797995|            6189|         159583|             114601|          797995|            6189|         159583|                7|                65|             18|              2|     17690|        490|              2|         38|            26.96|        51.22|         35.85|             584.06|           1362.30|              1024.48|          1946.36|    108.98|         0.00|          642.20|    1362.30|            1471.28|             2004.50|                 2113.48|       337.82|
# |        2450815|          29485|        2450862|             114601|          797995|            6189|         159583|             114601|          797995|            6189|         159583|                7|               101|             16|             10|     90595|        472|              2|         45|             9.54|        23.37|         21.50|              84.15|            967.50|               429.30|          1051.65|     21.76|       725.62|          294.30|     241.88|             263.64|              536.18|                  557.94|      -187.42|
# |        2450815|          29485|        2450834|             114601|          797995|            6189|         159583|             114601|          797995|            6189|         159583|                7|                99|              5|              8|     16504|        327|              2|         41|            39.04|       108.92|         75.15|            1384.57|           3081.15|              1600.64|          4465.72|    215.68|         0.00|         1964.72|    3081.15|            3296.83|             5045.87|                 5261.55|      1480.51|
# |        2450815|          10687|        2450864|             367572|          437897|            6622|          46147|             367572|          437897|            6622|          46147|                7|                 1|              5|             10|     78758|        270|              3|         99|            75.88|       178.31|        156.91|            2118.60|          15534.09|              7512.12|         17652.69|   1398.06|         0.00|         6884.46|   15534.09|           16932.15|            22418.55|                23816.61|      8021.97|
# |        2450815|          10687|        2450905|             367572|          437897|            6622|          46147|             367572|          437897|            6622|          46147|                7|                 5|             10|             10|     74972|        347|              3|         90|            34.57|        89.53|         68.04|            1934.10|           6123.60|              3111.30|          8057.70|    428.65|         0.00|         1449.90|    6123.60|            6552.25|             7573.50|                 8002.15|      3012.30|
# +---------------+---------------+---------------+-------------------+----------------+----------------+---------------+-------------------+----------------+----------------+---------------+-----------------+------------------+---------------+---------------+----------+-----------+---------------+-----------+-----------------+-------------+--------------+-------------------+------------------+---------------------+-----------------+----------+-------------+----------------+-----------+-------------------+--------------------+------------------------+-------------+
# only showing top 20 rows
#
# None
# store_sales
# [Stage 25:>                                                         (0 + 1) / 1]
# +---------------+---------------+----------+--------------+-----------+-----------+----------+-----------+-----------+----------------+-----------+-----------------+-------------+--------------+-------------------+------------------+---------------------+-----------------+----------+-------------+-----------+-------------------+-------------+
# |ss_sold_date_sk|ss_sold_time_sk|ss_item_sk|ss_customer_sk|ss_cdemo_sk|ss_hdemo_sk|ss_addr_sk|ss_store_sk|ss_promo_sk|ss_ticket_number|ss_quantity|ss_wholesale_cost|ss_list_price|ss_sales_price|ss_ext_discount_amt|ss_ext_sales_price|ss_ext_wholesale_cost|ss_ext_list_price|ss_ext_tax|ss_coupon_amt|ss_net_paid|ss_net_paid_inc_tax|ss_net_profit|
# +---------------+---------------+----------+--------------+-----------+-----------+----------+-----------+-----------+----------------+-----------+-----------------+-------------+--------------+-------------------+------------------+---------------------+-----------------+----------+-------------+-----------+-------------------+-------------+
# |        2451813|          65495|     34435|        167006|     591617|       3428|    174839|         40|         61|               1|         79|            11.41|        18.71|          2.80|              99.54|            221.20|               901.39|          1478.09|      6.08|        99.54|     121.66|             127.74|      -779.73|
# |        2451813|          65495|     18239|        167006|     591617|       3428|    174839|         40|        254|               1|         37|            63.63|       101.17|         41.47|              46.03|           1534.39|              2354.31|          3743.29|     59.53|        46.03|    1488.36|            1547.89|      -865.95|
# |        2451813|          65495|     49325|        167006|     591617|       3428|    174839|         40|        172|               1|         99|            80.52|       137.68|         83.98|               0.00|           8314.02|              7971.48|         13630.32|      0.00|         0.00|    8314.02|            8314.02|       342.54|
# |        2451813|          65495|     57451|        167006|     591617|       3428|    174839|         40|        380|               1|         14|            57.37|        76.30|          6.10|               0.00|             85.40|               803.18|          1068.20|      0.00|         0.00|      85.40|              85.40|      -717.78|
# |        2451813|          65495|     80011|        167006|     591617|       3428|    174839|         40|        236|               1|        100|            25.08|        36.86|          0.73|               0.00|             73.00|              2508.00|          3686.00|      6.57|         0.00|      73.00|              79.57|     -2435.00|
# |        2451813|          65495|      3689|        167006|     591617|       3428|    174839|         40|        363|               1|         91|            93.48|       108.43|         93.24|               0.00|           8484.84|              8506.68|          9867.13|    254.54|         0.00|    8484.84|            8739.38|       -21.84|
# |        2451813|          65495|     68647|        167006|     591617|       3428|    174839|         40|        370|               1|          5|            10.68|        15.91|          6.68|               0.00|             33.40|                53.40|            79.55|      2.33|         0.00|      33.40|              35.73|       -20.00|
# |        2451813|          65495|     27131|        167006|     591617|       3428|    174839|         40|        167|               1|         72|            84.72|       111.83|         61.50|               0.00|           4428.00|              6099.84|          8051.76|    177.12|         0.00|    4428.00|            4605.12|     -1671.84|
# |        2451813|          65495|     78980|        167006|     591617|       3428|    174839|         40|        106|               1|         14|            11.54|        11.77|          0.00|               0.00|              0.00|               161.56|           164.78|      0.00|         0.00|       0.00|               0.00|      -161.56|
# |        2451813|          65495|     66733|        167006|     591617|       3428|    174839|         40|        489|               1|         58|             4.57|         5.34|          3.52|               0.00|            204.16|               265.06|           309.72|      0.00|         0.00|     204.16|             204.16|       -60.90|
# |        2451813|          65495|     14384|        167006|     591617|       3428|    174839|         40|          7|               1|         44|            31.07|        54.99|         24.19|               0.00|           1064.36|              1367.08|          2419.56|     85.14|         0.00|    1064.36|            1149.50|      -302.72|
# |        2451813|          65495|      8425|        167006|     591617|       3428|    174839|         40|        412|               1|         88|            52.41|        63.94|         49.23|               0.00|           4332.24|              4612.08|          5626.72|    259.93|         0.00|    4332.24|            4592.17|      -279.84|
# |        2451813|          65495|     25495|        167006|     591617|       3428|    174839|         40|        142|               1|         50|            67.71|       126.61|         87.36|               0.00|           4368.00|              3385.50|          6330.50|    349.44|         0.00|    4368.00|            4717.44|       982.50|
# |        2451813|          65495|     62486|        167006|     591617|       3428|    174839|         40|        149|               1|         65|            27.16|        52.14|         41.19|               0.00|           2677.35|              1765.40|          3389.10|    214.18|         0.00|    2677.35|            2891.53|       911.95|
# |        2451524|          75316|     81709|        268284|    1712478|       4672|     63266|          4|        237|               2|         65|            93.86|       158.62|         34.89|               0.00|           2267.85|              6100.90|         10310.30|     45.35|         0.00|    2267.85|            2313.20|     -3833.05|
# |        2451524|          75316|     90070|        268284|    1712478|       4672|     63266|          4|        231|               2|         93|            35.87|        49.14|         15.23|               0.00|           1416.39|              3335.91|          4570.02|    113.31|         0.00|    1416.39|            1529.70|     -1919.52|
# |        2451524|          75316|      1928|        268284|    1712478|       4672|     63266|          4|        378|               2|         30|             2.27|         3.83|          1.11|               0.00|             33.30|                68.10|           114.90|      0.00|         0.00|      33.30|              33.30|       -34.80|
# |        2451524|          75316|     82528|        268284|    1712478|       4672|     63266|          4|        360|               2|         58|            53.09|        58.39|          7.59|               0.00|            440.22|              3079.22|          3386.62|      0.00|         0.00|     440.22|             440.22|     -2639.00|
# |           NULL|          75316|     36505|          NULL|       NULL|       4672|      NULL|          4|       NULL|               2|       NULL|            17.12|        19.85|          NULL|               NULL|              NULL|                 NULL|             NULL|     19.07|         NULL|       NULL|             495.84|         NULL|
# |        2451524|          75316|     40382|        268284|    1712478|       4672|     63266|          4|         44|               2|         79|            88.02|       128.50|         69.39|            4549.90|           5481.81|              6953.58|         10151.50|     83.87|      4549.90|     931.91|            1015.78|     -6021.67|
# +---------------+---------------+----------+--------------+-----------+-----------+----------+-----------+-----------+----------------+-----------+-----------------+-------------+--------------+-------------------+------------------+---------------------+-----------------+----------+-------------+-----------+-------------------+-------------+
# only showing top 20 rows
#
# None

# %%
spark.sql("SET spark.sql.yannakakis.countGroupInLeaves = false").show()

# %%
spark.sql("SET spark.sql.yannakakis.enabled = false").show()
spark.sql("SET spark.sql.yannakakis.enabled = true").show()

# %%
spark.sql("SET spark.sql.yannakakis.enabled = false").show()

# %%
spark.sql("SET spark.sql.yannakakis.enabled = true").show()
spark.sql("SET spark.sql.yannakakis.countGroupInLeaves = false").show()

# %%
spark.sql("SET spark.sql.cbo.enabled = true").show()

# %%
spark.sql("ANALYZE TABLE part COMPUTE STATISTICS;").show()

# %%
df = spark.sql("""select sum(ss_quantity) / sum(ss_quantity) from store_sales,store where s_store_sk = ss_store_sk""")
df.show()

df.explain(True)

# %%
df = spark.sql("""select avg(i_current_price) from item, inventory where i_item_sk = inv_item_sk""")
df = spark.sql("""select avg(ss_quantity) from store_sales,store where s_store_sk = ss_store_sk""")
#df = spark.sql("""select avg(ss_list_price) from store_sales,store where s_store_sk = ss_store_sk""")
#df = spark.sql("""select count(isnull(ss_quantity)) from store_sales,store where s_store_sk = ss_store_sk""")
#df = spark.sql("""select count(isnull(i_current_price)) from item, inventory where i_item_sk = inv_item_sk""")
#df = spark.sql("""select sum(if (isnull(ss_quantity), 0, ss_quantity)) from store_sales,store where s_store_sk = ss_store_sk""")

df.show()

df.explain(True)

# %%
def run_query(file):
    with open(file, 'r') as f:
        query = '\n'.join(filter(lambda line: not line.startswith('limit') and not line.startswith('-'), f.readlines()))
        
        print("running query: \n" + query)
        return spark.sql(query)

# %%
df = spark.sql("""
SELECT ps_partkey, count(*) from part, partsupp
WHERE p_partkey = ps_partkey
GROUP BY ps_partkey
""")

df.show()

df.explain(True)

# %%
df = spark.sql("SELECT COUNT(p_size) / COUNT(DISTINCT p_size) FROM part")
df.show()
df = spark.sql("SELECT COUNT(p_retailprice) / COUNT(DISTINCT p_retailprice) FROM part")
df.show()

# %%
df_t1 = spark.createDataFrame([(1,1), (2,1), (2,2), (3,2), (3,3), (4,3), (4,3), (5,2), (5,1), (6,4)], schema=("a","b"))
df_t1.createOrReplaceTempView("t1")
df_t2 = spark.createDataFrame([(1,1), (2,1), (3,2), (3,2), (3,3), (3,3), (4,3), (4,2), (5,1), (6,4)], schema=("c","d"))
df_t2.createOrReplaceTempView("t2")
df_t3 = spark.createDataFrame([(1,1), (2,1), (3,2), (3,2), (3,3), (3,3), (4,3), (4,2), (5,1), (6,4)], schema=("e","f"))
df_t3.createOrReplaceTempView("t3")

query = "select median(a) from t1, t2 where b = c"
#query = "select percentile(a, 0.5, b) from t1, t2 where b = c"
#query = "select median(a) from t1 where EXISTS (SELECT 1 FROM t2 WHERE b = c)"
#query = "select count(*) from t1, t2 where b = c"
#query = "select *a from t1 where EXISTS (SELECT 1 FROM t2 WHERE b = c)"

spark.sql("SET spark.sql.yannakakis.enabled = false").show()

df = spark.sql(query)
df.show()

spark.sql("SET spark.sql.yannakakis.enabled = true").show()

df = spark.sql(query)
df.show()

# %%
spark.conf.set("spark.sql.legacy.setCommandRejectsSparkCoreConfs","false")
#spark.conf.set("spark.executor.cores", "6")
#spark.conf.set("spark.executor.instances", "6")
spark.conf.set("spark.sql.shuffle.partitions", "6")

# %%
import pandas as pd
import time

def benchmark(query):
    df0 = run_query(query)
    df0.show()
    
    spark.sql("SET spark.sql.yannakakis.enabled = true").show()

    start_time = time.time()

    df1 = run_query(query)
    df1.show()
    #df1.explain(True)

    end_time = time.time()
    yannakakis_time = end_time - start_time

    spark.sql("SET spark.sql.yannakakis.enabled = false").show()

    start_time = time.time()

    df2 = run_query(query)
    df2.show()
    #df2.explain(True)

    end_time = time.time()
    ref_time = end_time - start_time
    
    #return [query, ref_time, yannakakis_time]
    return [query, ref_time, yannakakis_time]


queries = ['tpch-kit/dbgen/queries/postgres/2.sql',
           'tpch-kit/dbgen/queries/postgres/11.sql', 
           'tpch-kit/dbgen/queries/postgres/11-hint.sql',
           'median-1.sql',
           'median-2.sql', 
           'median-3.sql', 
           'median-4.sql', 
           'median-5.sql',
            'median-1-hint.sql',
           'median-2-hint.sql', 
           'median-3-hint.sql', 
           'median-4-hint.sql', 
           'median-5-hint.sql']

results = [benchmark(q) for q in queries]

df = pd.DataFrame(results, columns = ['query', 'ref_time', 'yannakakis_time'])

print(df)

df.to_csv("results.csv")
    

#print(f'row count: {df1.count()} vs. {df2.count()}' )
    #print(f'time ref: {ref_time}\ntime yannakakis: {yannakakis_time}')

# %%
#spark.conf.set("spark.sql.legacy.setCommandRejectsSparkCoreConfs","false")
#spark.conf.set("spark.executor.cores", "1")
#spark.conf.set("spark.executor.instances", "1")
spark.conf.set("spark.sql.shuffle.partitions", "1")

# %%
## Compare result
import time
#query = 'tpch-kit/dbgen/queries/postgres/2.sql'
#query = 'tpch-kit/dbgen/queries/postgres/13.sql'
#query = 'count-3.sql'
#query = 'tpch-kit/dbgen/queries/postgres/11.sql'
#query = '11-simple.sql'
query = 'median-2-hint.sql'
#query = 'tpch-kit/dbgen/queries/postgres/7.sql'
#query = '13-simple.sql'
query = 'dsb-queries/agg_queries/query013.sql'
query = 'tpcds-queries/query16-mod.sql'

spark.sql("SET spark.sql.yannakakis.enabled = true").show()

start_time = time.time()

df1 = run_query(query)
df1.show()
df1.explain(mode="extended")

end_time = time.time()
yannakakis_time = end_time - start_time

spark.sql("SET spark.sql.yannakakis.enabled = false").show()

start_time = time.time()

df2 = run_query(query)
df2.show()
df2.explain(mode="extended")

end_time = time.time()
ref_time = end_time - start_time

#print(f'row count: {df1.count()} vs. {df2.count()}' )
print(f'time ref: {ref_time}\ntime yannakakis: {yannakakis_time}')
# Out:
# +--------------------+-----+
# |                 key|value|
# +--------------------+-----+
# |spark.sql.yannaka...| true|
# +--------------------+-----+
#
# running query:
# SELECT
#
#          Count(DISTINCT cs_order_number) AS `order count` ,
#
#          Sum(cs_ext_ship_cost)           AS `total shipping cost` ,
#
#          Sum(cs_net_profit)              AS `total net profit`
#
# FROM     catalog_sales cs1 ,
#
#          date_dim ,
#
#          customer_address ,
#
#          call_center
#
# WHERE    d_date BETWEEN '2002-3-01' AND      (
#
#                   Cast('2002-3-01' AS DATE) + INTERVAL '60' day)
#
# AND      cs1.cs_ship_date_sk = d_date_sk
#
# AND      cs1.cs_ship_addr_sk = ca_address_sk
#
# AND      ca_state = 'IA'
#
# AND      cs1.cs_call_center_sk = cc_call_center_sk
#
# AND      cc_county IN ('Williamson County',
#
#                        'Williamson County',
#
#                        'Williamson County',
#
#                        'Williamson County',
#
#                        'Williamson County' )
#
# AND      EXISTS
#
#          (
#
#                 SELECT *
#
#                 FROM   catalog_sales cs2
#
#                 WHERE  cs1.cs_order_number = cs2.cs_order_number
#
#                 AND    cs1.cs_warehouse_sk <> cs2.cs_warehouse_sk)
#
# AND      NOT EXISTS
#
#          (
#
#                 SELECT *
#
#                 FROM   catalog_returns cr1
#
#                 WHERE  cs1.cs_order_number = cr1.cr_order_number)
#
# ;
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: applying yannakakis rewriting to join: Aggregate [toprettystring(count(distinct cs_order_number#2393), Some(Etc/UTC)) AS toprettystring(order count)#2982, toprettystring(sum(cs_ext_ship_cost#2404), Some(Etc/UTC)) AS toprettystring(total shipping cost)#2983, toprettystring(sum(cs_net_profit#2409), Some(Etc/UTC)) AS toprettystring(total net profit)#2984]
# +- Project [cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409]
#    +- Join Inner, (cs_call_center_sk#2387 = cc_call_center_sk#938)
#       :- Project [cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409]
#       :  +- Join Inner, (cs_ship_addr_sk#2386 = ca_address_sk#49)
#       :     :- Project [cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409]
#       :     :  +- Join Inner, (cs_ship_date_sk#2378 = d_date_sk#194)
#       :     :     :- Project [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409]
#       :     :     :  +- Filter (((exists#2937 [cs_order_number#2393 && cs_warehouse_sk#2390 && (cs_order_number#2393 = cs_order_number#2956) && NOT (cs_warehouse_sk#2390 = cs_warehouse_sk#2953)] AND NOT exists#2938 [cs_order_number#2393 && (cs_order_number#2393 = cr_order_number#1879)]) AND isnotnull(cs_ship_date_sk#2378)) AND (isnotnull(cs_ship_addr_sk#2386) AND isnotnull(cs_call_center_sk#2387)))
#       :     :     :     :  :- Relation [cs_sold_date_sk#2939,cs_sold_time_sk#2940,cs_ship_date_sk#2941,cs_bill_customer_sk#2942,cs_bill_cdemo_sk#2943,cs_bill_hdemo_sk#2944,cs_bill_addr_sk#2945,cs_ship_customer_sk#2946,cs_ship_cdemo_sk#2947,cs_ship_hdemo_sk#2948,cs_ship_addr_sk#2949,cs_call_center_sk#2950,cs_catalog_page_sk#2951,cs_ship_mode_sk#2952,cs_warehouse_sk#2953,cs_item_sk#2954,cs_promo_sk#2955,cs_order_number#2956,cs_quantity#2957,cs_wholesale_cost#2958,cs_list_price#2959,cs_sales_price#2960,cs_ext_discount_amt#2961,cs_ext_sales_price#2962,... 10 more fields] JDBCRelation(catalog_sales) [numPartitions=1]
#       :     :     :     :  +- Relation [cr_returned_date_sk#1863,cr_returned_time_sk#1864,cr_item_sk#1865,cr_refunded_customer_sk#1866,cr_refunded_cdemo_sk#1867,cr_refunded_hdemo_sk#1868,cr_refunded_addr_sk#1869,cr_returning_customer_sk#1870,cr_returning_cdemo_sk#1871,cr_returning_hdemo_sk#1872,cr_returning_addr_sk#1873,cr_call_center_sk#1874,cr_catalog_page_sk#1875,cr_ship_mode_sk#1876,cr_warehouse_sk#1877,cr_reason_sk#1878,cr_order_number#1879,cr_return_quantity#1880,cr_return_amount#1881,cr_return_tax#1882,cr_return_amt_inc_tax#1883,cr_fee#1884,cr_return_ship_cost#1885,cr_refunded_cash#1886,... 3 more fields] JDBCRelation(catalog_returns) [numPartitions=1]
#       :     :     :     +- Relation [cs_sold_date_sk#2376,cs_sold_time_sk#2377,cs_ship_date_sk#2378,cs_bill_customer_sk#2379,cs_bill_cdemo_sk#2380,cs_bill_hdemo_sk#2381,cs_bill_addr_sk#2382,cs_ship_customer_sk#2383,cs_ship_cdemo_sk#2384,cs_ship_hdemo_sk#2385,cs_ship_addr_sk#2386,cs_call_center_sk#2387,cs_catalog_page_sk#2388,cs_ship_mode_sk#2389,cs_warehouse_sk#2390,cs_item_sk#2391,cs_promo_sk#2392,cs_order_number#2393,cs_quantity#2394,cs_wholesale_cost#2395,cs_list_price#2396,cs_sales_price#2397,cs_ext_discount_amt#2398,cs_ext_sales_price#2399,... 10 more fields] JDBCRelation(catalog_sales) [numPartitions=1]
#       :     :     +- Project [d_date_sk#194]
#       :     :        +- Filter ((isnotnull(d_date#196) AND ((d_date#196 >= 2002-03-01) AND (d_date#196 <= 2002-04-30))) AND isnotnull(d_date_sk#194))
#       :     :           +- Relation [d_date_sk#194,d_date_id#195,d_date#196,d_month_seq#197,d_week_seq#198,d_quarter_seq#199,d_year#200,d_dow#201,d_moy#202,d_dom#203,d_qoy#204,d_fy_year#205,d_fy_quarter_seq#206,d_fy_week_seq#207,d_day_name#208,d_quarter_name#209,d_holiday#210,d_weekend#211,d_following_holiday#212,d_first_dom#213,d_last_dom#214,d_same_day_ly#215,d_same_day_lq#216,d_current_day#217,... 4 more fields] JDBCRelation(date_dim) [numPartitions=1]
#       :     +- Project [ca_address_sk#49]
#       :        +- Filter ((staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, ca_state#57, 2, true, false, true) = IA) AND isnotnull(ca_address_sk#49))
#       :           +- Relation [ca_address_sk#49,ca_address_id#50,ca_street_number#51,ca_street_name#52,ca_street_type#53,ca_suite_number#54,ca_city#55,ca_county#56,ca_state#57,ca_zip#58,ca_country#59,ca_gmt_offset#60,ca_location_type#61] JDBCRelation(customer_address) [numPartitions=1]
#       +- Project [cc_call_center_sk#938]
#          +- Filter ((isnotnull(cc_county#963) AND (cc_county#963 = Williamson County)) AND isnotnull(cc_call_center_sk#938))
#             +- Relation [cc_call_center_sk#938,cc_call_center_id#939,cc_rec_start_date#940,cc_rec_end_date#941,cc_closed_date_sk#942,cc_open_date_sk#943,cc_name#944,cc_class#945,cc_employees#946,cc_sq_ft#947,cc_hours#948,cc_manager#949,cc_mkt_id#950,cc_mkt_class#951,cc_mkt_desc#952,cc_market_manager#953,cc_division#954,cc_division_name#955,cc_company#956,cc_company_name#957,cc_street_number#958,cc_street_name#959,cc_street_type#960,cc_suite_number#961,... 7 more fields] JDBCRelation(call_center) [numPartitions=1]
#
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg(project(join))
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: items: List(Project [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409]
# +- Filter (((exists#2937 [cs_order_number#2393 && cs_warehouse_sk#2390 && (cs_order_number#2393 = cs_order_number#2956) && NOT (cs_warehouse_sk#2390 = cs_warehouse_sk#2953)] AND NOT exists#2938 [cs_order_number#2393 && (cs_order_number#2393 = cr_order_number#1879)]) AND isnotnull(cs_ship_date_sk#2378)) AND (isnotnull(cs_ship_addr_sk#2386) AND isnotnull(cs_call_center_sk#2387)))
#    :  :- Relation [cs_sold_date_sk#2939,cs_sold_time_sk#2940,cs_ship_date_sk#2941,cs_bill_customer_sk#2942,cs_bill_cdemo_sk#2943,cs_bill_hdemo_sk#2944,cs_bill_addr_sk#2945,cs_ship_customer_sk#2946,cs_ship_cdemo_sk#2947,cs_ship_hdemo_sk#2948,cs_ship_addr_sk#2949,cs_call_center_sk#2950,cs_catalog_page_sk#2951,cs_ship_mode_sk#2952,cs_warehouse_sk#2953,cs_item_sk#2954,cs_promo_sk#2955,cs_order_number#2956,cs_quantity#2957,cs_wholesale_cost#2958,cs_list_price#2959,cs_sales_price#2960,cs_ext_discount_amt#2961,cs_ext_sales_price#2962,... 10 more fields] JDBCRelation(catalog_sales) [numPartitions=1]
#    :  +- Relation [cr_returned_date_sk#1863,cr_returned_time_sk#1864,cr_item_sk#1865,cr_refunded_customer_sk#1866,cr_refunded_cdemo_sk#1867,cr_refunded_hdemo_sk#1868,cr_refunded_addr_sk#1869,cr_returning_customer_sk#1870,cr_returning_cdemo_sk#1871,cr_returning_hdemo_sk#1872,cr_returning_addr_sk#1873,cr_call_center_sk#1874,cr_catalog_page_sk#1875,cr_ship_mode_sk#1876,cr_warehouse_sk#1877,cr_reason_sk#1878,cr_order_number#1879,cr_return_quantity#1880,cr_return_amount#1881,cr_return_tax#1882,cr_return_amt_inc_tax#1883,cr_fee#1884,cr_return_ship_cost#1885,cr_refunded_cash#1886,... 3 more fields] JDBCRelation(catalog_returns) [numPartitions=1]
#    +- Relation [cs_sold_date_sk#2376,cs_sold_time_sk#2377,cs_ship_date_sk#2378,cs_bill_customer_sk#2379,cs_bill_cdemo_sk#2380,cs_bill_hdemo_sk#2381,cs_bill_addr_sk#2382,cs_ship_customer_sk#2383,cs_ship_cdemo_sk#2384,cs_ship_hdemo_sk#2385,cs_ship_addr_sk#2386,cs_call_center_sk#2387,cs_catalog_page_sk#2388,cs_ship_mode_sk#2389,cs_warehouse_sk#2390,cs_item_sk#2391,cs_promo_sk#2392,cs_order_number#2393,cs_quantity#2394,cs_wholesale_cost#2395,cs_list_price#2396,cs_sales_price#2397,cs_ext_discount_amt#2398,cs_ext_sales_price#2399,... 10 more fields] JDBCRelation(catalog_sales) [numPartitions=1]
# , Project [d_date_sk#194]
# +- Filter ((isnotnull(d_date#196) AND ((d_date#196 >= 2002-03-01) AND (d_date#196 <= 2002-04-30))) AND isnotnull(d_date_sk#194))
#    +- Relation [d_date_sk#194,d_date_id#195,d_date#196,d_month_seq#197,d_week_seq#198,d_quarter_seq#199,d_year#200,d_dow#201,d_moy#202,d_dom#203,d_qoy#204,d_fy_year#205,d_fy_quarter_seq#206,d_fy_week_seq#207,d_day_name#208,d_quarter_name#209,d_holiday#210,d_weekend#211,d_following_holiday#212,d_first_dom#213,d_last_dom#214,d_same_day_ly#215,d_same_day_lq#216,d_current_day#217,... 4 more fields] JDBCRelation(date_dim) [numPartitions=1]
# , Project [ca_address_sk#49]
# +- Filter ((staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, ca_state#57, 2, true, false, true) = IA) AND isnotnull(ca_address_sk#49))
#    +- Relation [ca_address_sk#49,ca_address_id#50,ca_street_number#51,ca_street_name#52,ca_street_type#53,ca_suite_number#54,ca_city#55,ca_county#56,ca_state#57,ca_zip#58,ca_country#59,ca_gmt_offset#60,ca_location_type#61] JDBCRelation(customer_address) [numPartitions=1]
# , Project [cc_call_center_sk#938]
# +- Filter ((isnotnull(cc_county#963) AND (cc_county#963 = Williamson County)) AND isnotnull(cc_call_center_sk#938))
#    +- Relation [cc_call_center_sk#938,cc_call_center_id#939,cc_rec_start_date#940,cc_rec_end_date#941,cc_closed_date_sk#942,cc_open_date_sk#943,cc_name#944,cc_class#945,cc_employees#946,cc_sq_ft#947,cc_hours#948,cc_manager#949,cc_mkt_id#950,cc_mkt_class#951,cc_mkt_desc#952,cc_market_manager#953,cc_division#954,cc_division_name#955,cc_company#956,cc_company_name#957,cc_street_number#958,cc_street_name#959,cc_street_type#960,cc_suite_number#961,... 7 more fields] JDBCRelation(call_center) [numPartitions=1]
# )
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: conditions: Set((cs_ship_date_sk#2378 = d_date_sk#194), (cs_ship_addr_sk#2386 = ca_address_sk#49), (cs_call_center_sk#2387 = cc_call_center_sk#938))
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg: toprettystring(count(distinct cs_order_number#2393), Some(Etc/UTC)) AS toprettystring(order count)#2982
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is 0MA: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is counting: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is sum: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is non-agg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg: toprettystring(sum(cs_ext_ship_cost#2404), Some(Etc/UTC)) AS toprettystring(total shipping cost)#2983
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is 0MA: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is sum: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is non-agg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg: toprettystring(sum(cs_net_profit#2409), Some(Etc/UTC)) AS toprettystring(total net profit)#2984
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is 0MA: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is sum: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is non-agg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: aggregate attributes: {cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409}
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: groupingExpressions: List()
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: group attributes: {}
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: counting aggregates: List(toprettystring(count(distinct cs_order_number#2393), Some(Etc/UTC)) AS toprettystring(order count)#2982)
# 23/10/25 14:37:34 WARN Hypergraph: equivalence classes: Set(Set(cs_ship_date_sk#2378, d_date_sk#194), Set(cs_ship_addr_sk#2386, ca_address_sk#49), Set(cs_call_center_sk#2387, cc_call_center_sk#938))
# 23/10/25 14:37:34 WARN Hypergraph: vertex to attribute mapping: Map(cs_ship_addr_sk#2386 -> Set(cs_ship_addr_sk#2386, ca_address_sk#49), cs_ship_date_sk#2378 -> Set(cs_ship_date_sk#2378, d_date_sk#194), cs_call_center_sk#2387 -> Set(cs_call_center_sk#2387, cc_call_center_sk#938))
# 23/10/25 14:37:34 WARN Hypergraph: attribute to vertex mapping: Map(ExprId(194,b837b423-1d1f-448f-bcb3-56d0dafeafeb) -> cs_ship_date_sk#2378, ExprId(938,b837b423-1d1f-448f-bcb3-56d0dafeafeb) -> cs_call_center_sk#2387, ExprId(49,b837b423-1d1f-448f-bcb3-56d0dafeafeb) -> cs_ship_addr_sk#2386, ExprId(2387,b837b423-1d1f-448f-bcb3-56d0dafeafeb) -> cs_call_center_sk#2387, ExprId(2378,b837b423-1d1f-448f-bcb3-56d0dafeafeb) -> cs_ship_date_sk#2378, ExprId(2386,b837b423-1d1f-448f-bcb3-56d0dafeafeb) -> cs_ship_addr_sk#2386)
# 23/10/25 14:37:34 WARN Hypergraph: join item: Project [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409]
# +- Filter (((exists#2937 [cs_order_number#2393 && cs_warehouse_sk#2390 && (cs_order_number#2393 = cs_order_number#2956) && NOT (cs_warehouse_sk#2390 = cs_warehouse_sk#2953)] AND NOT exists#2938 [cs_order_number#2393 && (cs_order_number#2393 = cr_order_number#1879)]) AND isnotnull(cs_ship_date_sk#2378)) AND (isnotnull(cs_ship_addr_sk#2386) AND isnotnull(cs_call_center_sk#2387)))
#    :  :- Relation [cs_sold_date_sk#2939,cs_sold_time_sk#2940,cs_ship_date_sk#2941,cs_bill_customer_sk#2942,cs_bill_cdemo_sk#2943,cs_bill_hdemo_sk#2944,cs_bill_addr_sk#2945,cs_ship_customer_sk#2946,cs_ship_cdemo_sk#2947,cs_ship_hdemo_sk#2948,cs_ship_addr_sk#2949,cs_call_center_sk#2950,cs_catalog_page_sk#2951,cs_ship_mode_sk#2952,cs_warehouse_sk#2953,cs_item_sk#2954,cs_promo_sk#2955,cs_order_number#2956,cs_quantity#2957,cs_wholesale_cost#2958,cs_list_price#2959,cs_sales_price#2960,cs_ext_discount_amt#2961,cs_ext_sales_price#2962,... 10 more fields] JDBCRelation(catalog_sales) [numPartitions=1]
#    :  +- Relation [cr_returned_date_sk#1863,cr_returned_time_sk#1864,cr_item_sk#1865,cr_refunded_customer_sk#1866,cr_refunded_cdemo_sk#1867,cr_refunded_hdemo_sk#1868,cr_refunded_addr_sk#1869,cr_returning_customer_sk#1870,cr_returning_cdemo_sk#1871,cr_returning_hdemo_sk#1872,cr_returning_addr_sk#1873,cr_call_center_sk#1874,cr_catalog_page_sk#1875,cr_ship_mode_sk#1876,cr_warehouse_sk#1877,cr_reason_sk#1878,cr_order_number#1879,cr_return_quantity#1880,cr_return_amount#1881,cr_return_tax#1882,cr_return_amt_inc_tax#1883,cr_fee#1884,cr_return_ship_cost#1885,cr_refunded_cash#1886,... 3 more fields] JDBCRelation(catalog_returns) [numPartitions=1]
#    +- Relation [cs_sold_date_sk#2376,cs_sold_time_sk#2377,cs_ship_date_sk#2378,cs_bill_customer_sk#2379,cs_bill_cdemo_sk#2380,cs_bill_hdemo_sk#2381,cs_bill_addr_sk#2382,cs_ship_customer_sk#2383,cs_ship_cdemo_sk#2384,cs_ship_hdemo_sk#2385,cs_ship_addr_sk#2386,cs_call_center_sk#2387,cs_catalog_page_sk#2388,cs_ship_mode_sk#2389,cs_warehouse_sk#2390,cs_item_sk#2391,cs_promo_sk#2392,cs_order_number#2393,cs_quantity#2394,cs_wholesale_cost#2395,cs_list_price#2396,cs_sales_price#2397,cs_ext_discount_amt#2398,cs_ext_sales_price#2399,... 10 more fields] JDBCRelation(catalog_sales) [numPartitions=1]
#
# 23/10/25 14:37:34 WARN Hypergraph: join item: Project [d_date_sk#194]
# +- Filter ((isnotnull(d_date#196) AND ((d_date#196 >= 2002-03-01) AND (d_date#196 <= 2002-04-30))) AND isnotnull(d_date_sk#194))
#    +- Relation [d_date_sk#194,d_date_id#195,d_date#196,d_month_seq#197,d_week_seq#198,d_quarter_seq#199,d_year#200,d_dow#201,d_moy#202,d_dom#203,d_qoy#204,d_fy_year#205,d_fy_quarter_seq#206,d_fy_week_seq#207,d_day_name#208,d_quarter_name#209,d_holiday#210,d_weekend#211,d_following_holiday#212,d_first_dom#213,d_last_dom#214,d_same_day_ly#215,d_same_day_lq#216,d_current_day#217,... 4 more fields] JDBCRelation(date_dim) [numPartitions=1]
#
# 23/10/25 14:37:34 WARN Hypergraph: join item: Project [ca_address_sk#49]
# +- Filter ((staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, ca_state#57, 2, true, false, true) = IA) AND isnotnull(ca_address_sk#49))
#    +- Relation [ca_address_sk#49,ca_address_id#50,ca_street_number#51,ca_street_name#52,ca_street_type#53,ca_suite_number#54,ca_city#55,ca_county#56,ca_state#57,ca_zip#58,ca_country#59,ca_gmt_offset#60,ca_location_type#61] JDBCRelation(customer_address) [numPartitions=1]
#
# 23/10/25 14:37:34 WARN Hypergraph: join item: Project [cc_call_center_sk#938]
# +- Filter ((isnotnull(cc_county#963) AND (cc_county#963 = Williamson County)) AND isnotnull(cc_call_center_sk#938))
#    +- Relation [cc_call_center_sk#938,cc_call_center_id#939,cc_rec_start_date#940,cc_rec_end_date#941,cc_closed_date_sk#942,cc_open_date_sk#943,cc_name#944,cc_class#945,cc_employees#946,cc_sq_ft#947,cc_hours#948,cc_manager#949,cc_mkt_id#950,cc_mkt_class#951,cc_mkt_desc#952,cc_market_manager#953,cc_division#954,cc_division_name#955,cc_company#956,cc_company_name#957,cc_street_number#958,cc_street_name#959,cc_street_type#960,cc_suite_number#961,... 7 more fields] JDBCRelation(call_center) [numPartitions=1]
#
# 23/10/25 14:37:34 WARN Hypergraph: hyperedges: Set(E2(cs_ship_date_sk#2378), E1(cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387), E3(cs_ship_addr_sk#2386), E4(cs_call_center_sk#2387))
# 23/10/25 14:37:34 WARN Hypergraph: gyo edge: E4(cs_call_center_sk#2387)
# 23/10/25 14:37:34 WARN Hypergraph: supersets: Set(E1(cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387))
# 23/10/25 14:37:34 WARN Hypergraph: gyo edge: E1(cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387)
# 23/10/25 14:37:34 WARN Hypergraph: supersets: Set()
# 23/10/25 14:37:34 WARN Hypergraph: parentNode: TreeNode(Set(E1(cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387)))[Set({cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409})] [[parent: false]]
#
# 23/10/25 14:37:34 WARN Hypergraph: subsets: Set(TreeNode(Set(E2(cs_ship_date_sk#2378)))[Set({d_date_sk#194})] [[parent: false]]
# , TreeNode(Set(E4(cs_call_center_sk#2387)))[Set({cc_call_center_sk#938})] [[parent: false]]
# , TreeNode(Set(E3(cs_ship_addr_sk#2386)))[Set({ca_address_sk#49})] [[parent: false]]
# )
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: join tree:
# TreeNode(Set(E1(cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387)))[Set({cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409})] [[parent: false]]
# -- TreeNode(Set(E2(cs_ship_date_sk#2378)))[Set({d_date_sk#194})] [[parent: true]]
#
# -- TreeNode(Set(E4(cs_call_center_sk#2387)))[Set({cc_call_center_sk#938})] [[parent: true]]
#
# -- TreeNode(Set(E3(cs_ship_addr_sk#2386)))[Set({ca_address_sk#49})] [[parent: true]]
#
# 23/10/25 14:37:34 WARN HTNode: aggAttributes: {cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409}
# 23/10/25 14:37:34 WARN HTNode: nodeAttributes: {cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409}
# 23/10/25 14:37:34 WARN HTNode: found subset in:
# TreeNode(Set(E1(cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387)))[Set({cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409})] [[parent: false]]
# -- TreeNode(Set(E2(cs_ship_date_sk#2378)))[Set({d_date_sk#194})] [[parent: true]]
#
# -- TreeNode(Set(E4(cs_call_center_sk#2387)))[Set({cc_call_center_sk#938})] [[parent: true]]
#
# -- TreeNode(Set(E3(cs_ship_addr_sk#2386)))[Set({ca_address_sk#49})] [[parent: true]]
#
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: rerooted:
# TreeNode(Set(E1(cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387)))[Set({cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409})] [[parent: false]]
# -- TreeNode(Set(E2(cs_ship_date_sk#2378)))[Set({d_date_sk#194})] [[parent: true]]
#
# -- TreeNode(Set(E4(cs_call_center_sk#2387)))[Set({cc_call_center_sk#938})] [[parent: true]]
#
# -- TreeNode(Set(E3(cs_ship_addr_sk#2386)))[Set({ca_address_sk#49})] [[parent: true]]
#
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: star counting aggregates: List()
# 23/10/25 14:37:34 WARN HTNode: keyRefs: List()
# 23/10/25 14:37:34 WARN HTNode: edge: E1(cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387)
# 23/10/25 14:37:34 WARN HTNode: overlapping vertices: Set((cs_ship_date_sk#2378,d_date_sk#194))
# 23/10/25 14:37:34 WARN HTNode: can semi join: false
# 23/10/25 14:37:34 WARN HTNode: join output: List(cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, c#2988L, d_date_sk#194, c#2989L)
# 23/10/25 14:37:34 WARN HTNode: keyRefs: List()
# 23/10/25 14:37:34 WARN HTNode: edge: E1(cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387)
# 23/10/25 14:37:34 WARN HTNode: overlapping vertices: Set((cs_call_center_sk#2387,cc_call_center_sk#938))
# 23/10/25 14:37:34 WARN HTNode: can semi join: false
# 23/10/25 14:37:34 WARN HTNode: join output: List(c#2997L, cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, cc_call_center_sk#938, c#2995L)
# 23/10/25 14:37:34 WARN HTNode: keyRefs: List()
# 23/10/25 14:37:34 WARN HTNode: edge: E1(cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387)
# 23/10/25 14:37:34 WARN HTNode: overlapping vertices: Set((cs_ship_addr_sk#2386,ca_address_sk#49))
# 23/10/25 14:37:34 WARN HTNode: can semi join: false
# 23/10/25 14:37:34 WARN HTNode: join output: List(c#3003L, cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, ca_address_sk#49, c#3001L)
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: new aggregate: Aggregate
# +- Project [cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, c#3006L]
#    +- Project [(cast(c#3003L as bigint) * c#3001L) AS c#3006L, c#3003L, cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, ca_address_sk#49, c#3001L]
#       +- Join Inner, (cs_ship_addr_sk#2386 = cast(ca_address_sk#49 as int))
#          :- Aggregate [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409], [sum(c#3000L) AS c#3003L, cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409]
#          :  +- Project [(cast(c#2997L as bigint) * c#2995L) AS c#3000L, c#2997L, cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, cc_call_center_sk#938, c#2995L]
#          :     +- Join Inner, (cs_call_center_sk#2387 = cast(cc_call_center_sk#938 as int))
#          :        :- Aggregate [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409], [sum(c#2994L) AS c#2997L, cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409]
#          :        :  +- Project [(cast(c#2988L as bigint) * c#2989L) AS c#2994L, cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, c#2988L, d_date_sk#194, c#2989L]
#          :        :     +- Join Inner, (cs_ship_date_sk#2378 = cast(d_date_sk#194 as int))
#          :        :        :- Project [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, 1 AS c#2988L]
#          :        :        :  +- Project [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409]
#          :        :        :     +- Filter (((exists#2937 [cs_order_number#2393 && cs_warehouse_sk#2390 && (cs_order_number#2393 = cs_order_number#2956) && NOT (cs_warehouse_sk#2390 = cs_warehouse_sk#2953)] AND NOT exists#2938 [cs_order_number#2393 && (cs_order_number#2393 = cr_order_number#1879)]) AND isnotnull(cs_ship_date_sk#2378)) AND (isnotnull(cs_ship_addr_sk#2386) AND isnotnull(cs_call_center_sk#2387)))
#          :        :        :        :  :- Relation [cs_sold_date_sk#2939,cs_sold_time_sk#2940,cs_ship_date_sk#2941,cs_bill_customer_sk#2942,cs_bill_cdemo_sk#2943,cs_bill_hdemo_sk#2944,cs_bill_addr_sk#2945,cs_ship_customer_sk#2946,cs_ship_cdemo_sk#2947,cs_ship_hdemo_sk#2948,cs_ship_addr_sk#2949,cs_call_center_sk#2950,cs_catalog_page_sk#2951,cs_ship_mode_sk#2952,cs_warehouse_sk#2953,cs_item_sk#2954,cs_promo_sk#2955,cs_order_number#2956,cs_quantity#2957,cs_wholesale_cost#2958,cs_list_price#2959,cs_sales_price#2960,cs_ext_discount_amt#2961,cs_ext_sales_price#2962,... 10 more fields] JDBCRelation(catalog_sales) [numPartitions=1]
#          :        :        :        :  +- Relation [cr_returned_date_sk#1863,cr_returned_time_sk#1864,cr_item_sk#1865,cr_refunded_customer_sk#1866,cr_refunded_cdemo_sk#1867,cr_refunded_hdemo_sk#1868,cr_refunded_addr_sk#1869,cr_returning_customer_sk#1870,cr_returning_cdemo_sk#1871,cr_returning_hdemo_sk#1872,cr_returning_addr_sk#1873,cr_call_center_sk#1874,cr_catalog_page_sk#1875,cr_ship_mode_sk#1876,cr_warehouse_sk#1877,cr_reason_sk#1878,cr_order_number#1879,cr_return_quantity#1880,cr_return_amount#1881,cr_return_tax#1882,cr_return_amt_inc_tax#1883,cr_fee#1884,cr_return_ship_cost#1885,cr_refunded_cash#1886,... 3 more fields] JDBCRelation(catalog_returns) [numPartitions=1]
#          :        :        :        +- Relation [cs_sold_date_sk#2376,cs_sold_time_sk#2377,cs_ship_date_sk#2378,cs_bill_customer_sk#2379,cs_bill_cdemo_sk#2380,cs_bill_hdemo_sk#2381,cs_bill_addr_sk#2382,cs_ship_customer_sk#2383,cs_ship_cdemo_sk#2384,cs_ship_hdemo_sk#2385,cs_ship_addr_sk#2386,cs_call_center_sk#2387,cs_catalog_page_sk#2388,cs_ship_mode_sk#2389,cs_warehouse_sk#2390,cs_item_sk#2391,cs_promo_sk#2392,cs_order_number#2393,cs_quantity#2394,cs_wholesale_cost#2395,cs_list_price#2396,cs_sales_price#2397,cs_ext_discount_amt#2398,cs_ext_sales_price#2399,... 10 more fields] JDBCRelation(catalog_sales) [numPartitions=1]
#          :        :        +- Project [d_date_sk#194, 1 AS c#2989L]
#          :        :           +- Project [d_date_sk#194]
#          :        :              +- Filter ((isnotnull(d_date#196) AND ((d_date#196 >= 2002-03-01) AND (d_date#196 <= 2002-04-30))) AND isnotnull(d_date_sk#194))
#          :        :                 +- Relation [d_date_sk#194,d_date_id#195,d_date#196,d_month_seq#197,d_week_seq#198,d_quarter_seq#199,d_year#200,d_dow#201,d_moy#202,d_dom#203,d_qoy#204,d_fy_year#205,d_fy_quarter_seq#206,d_fy_week_seq#207,d_day_name#208,d_quarter_name#209,d_holiday#210,d_weekend#211,d_following_holiday#212,d_first_dom#213,d_last_dom#214,d_same_day_ly#215,d_same_day_lq#216,d_current_day#217,... 4 more fields] JDBCRelation(date_dim) [numPartitions=1]
#          :        +- Project [cc_call_center_sk#938, 1 AS c#2995L]
#          :           +- Project [cc_call_center_sk#938]
#          :              +- Filter ((isnotnull(cc_county#963) AND (cc_county#963 = Williamson County)) AND isnotnull(cc_call_center_sk#938))
#          :                 +- Relation [cc_call_center_sk#938,cc_call_center_id#939,cc_rec_start_date#940,cc_rec_end_date#941,cc_closed_date_sk#942,cc_open_date_sk#943,cc_name#944,cc_class#945,cc_employees#946,cc_sq_ft#947,cc_hours#948,cc_manager#949,cc_mkt_id#950,cc_mkt_class#951,cc_mkt_desc#952,cc_market_manager#953,cc_division#954,cc_division_name#955,cc_company#956,cc_company_name#957,cc_street_number#958,cc_street_name#959,cc_street_type#960,cc_suite_number#961,... 7 more fields] JDBCRelation(call_center) [numPartitions=1]
#          +- Project [ca_address_sk#49, 1 AS c#3001L]
#             +- Project [ca_address_sk#49]
#                +- Filter ((staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, ca_state#57, 2, true, false, true) = IA) AND isnotnull(ca_address_sk#49))
#                   +- Relation [ca_address_sk#49,ca_address_id#50,ca_street_number#51,ca_street_name#52,ca_street_type#53,ca_suite_number#54,ca_city#55,ca_county#56,ca_state#57,ca_zip#58,ca_country#59,ca_gmt_offset#60,ca_location_type#61] JDBCRelation(customer_address) [numPartitions=1]
#
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: applying yannakakis rewriting to join: Aggregate [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409], [sum(c#3000L) AS c#3003L, cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409]
# +- Project [(cast(c#2997L as bigint) * c#2995L) AS c#3000L, c#2997L, cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, cc_call_center_sk#938, c#2995L]
#    +- Join Inner, (cs_call_center_sk#2387 = cast(cc_call_center_sk#938 as int))
#       :- Aggregate [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409], [sum(c#2994L) AS c#2997L, cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409]
#       :  +- Project [(cast(c#2988L as bigint) * c#2989L) AS c#2994L, cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, c#2988L, d_date_sk#194, c#2989L]
#       :     +- Join Inner, (cs_ship_date_sk#2378 = cast(d_date_sk#194 as int))
#       :        :- Project [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, 1 AS c#2988L]
#       :        :  +- Project [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409]
#       :        :     +- Filter (((exists#2937 [cs_order_number#2393 && cs_warehouse_sk#2390 && (cs_order_number#2393 = cs_order_number#2956) && NOT (cs_warehouse_sk#2390 = cs_warehouse_sk#2953)] AND NOT exists#2938 [cs_order_number#2393 && (cs_order_number#2393 = cr_order_number#1879)]) AND isnotnull(cs_ship_date_sk#2378)) AND (isnotnull(cs_ship_addr_sk#2386) AND isnotnull(cs_call_center_sk#2387)))
#       :        :        :  :- Relation [cs_sold_date_sk#2939,cs_sold_time_sk#2940,cs_ship_date_sk#2941,cs_bill_customer_sk#2942,cs_bill_cdemo_sk#2943,cs_bill_hdemo_sk#2944,cs_bill_addr_sk#2945,cs_ship_customer_sk#2946,cs_ship_cdemo_sk#2947,cs_ship_hdemo_sk#2948,cs_ship_addr_sk#2949,cs_call_center_sk#2950,cs_catalog_page_sk#2951,cs_ship_mode_sk#2952,cs_warehouse_sk#2953,cs_item_sk#2954,cs_promo_sk#2955,cs_order_number#2956,cs_quantity#2957,cs_wholesale_cost#2958,cs_list_price#2959,cs_sales_price#2960,cs_ext_discount_amt#2961,cs_ext_sales_price#2962,... 10 more fields] JDBCRelation(catalog_sales) [numPartitions=1]
#       :        :        :  +- Relation [cr_returned_date_sk#1863,cr_returned_time_sk#1864,cr_item_sk#1865,cr_refunded_customer_sk#1866,cr_refunded_cdemo_sk#1867,cr_refunded_hdemo_sk#1868,cr_refunded_addr_sk#1869,cr_returning_customer_sk#1870,cr_returning_cdemo_sk#1871,cr_returning_hdemo_sk#1872,cr_returning_addr_sk#1873,cr_call_center_sk#1874,cr_catalog_page_sk#1875,cr_ship_mode_sk#1876,cr_warehouse_sk#1877,cr_reason_sk#1878,cr_order_number#1879,cr_return_quantity#1880,cr_return_amount#1881,cr_return_tax#1882,cr_return_amt_inc_tax#1883,cr_fee#1884,cr_return_ship_cost#1885,cr_refunded_cash#1886,... 3 more fields] JDBCRelation(catalog_returns) [numPartitions=1]
#       :        :        +- Relation [cs_sold_date_sk#2376,cs_sold_time_sk#2377,cs_ship_date_sk#2378,cs_bill_customer_sk#2379,cs_bill_cdemo_sk#2380,cs_bill_hdemo_sk#2381,cs_bill_addr_sk#2382,cs_ship_customer_sk#2383,cs_ship_cdemo_sk#2384,cs_ship_hdemo_sk#2385,cs_ship_addr_sk#2386,cs_call_center_sk#2387,cs_catalog_page_sk#2388,cs_ship_mode_sk#2389,cs_warehouse_sk#2390,cs_item_sk#2391,cs_promo_sk#2392,cs_order_number#2393,cs_quantity#2394,cs_wholesale_cost#2395,cs_list_price#2396,cs_sales_price#2397,cs_ext_discount_amt#2398,cs_ext_sales_price#2399,... 10 more fields] JDBCRelation(catalog_sales) [numPartitions=1]
#       :        +- Project [d_date_sk#194, 1 AS c#2989L]
#       :           +- Project [d_date_sk#194]
#       :              +- Filter ((isnotnull(d_date#196) AND ((d_date#196 >= 2002-03-01) AND (d_date#196 <= 2002-04-30))) AND isnotnull(d_date_sk#194))
#       :                 +- Relation [d_date_sk#194,d_date_id#195,d_date#196,d_month_seq#197,d_week_seq#198,d_quarter_seq#199,d_year#200,d_dow#201,d_moy#202,d_dom#203,d_qoy#204,d_fy_year#205,d_fy_quarter_seq#206,d_fy_week_seq#207,d_day_name#208,d_quarter_name#209,d_holiday#210,d_weekend#211,d_following_holiday#212,d_first_dom#213,d_last_dom#214,d_same_day_ly#215,d_same_day_lq#216,d_current_day#217,... 4 more fields] JDBCRelation(date_dim) [numPartitions=1]
#       +- Project [cc_call_center_sk#938, 1 AS c#2995L]
#          +- Project [cc_call_center_sk#938]
#             +- Filter ((isnotnull(cc_county#963) AND (cc_county#963 = Williamson County)) AND isnotnull(cc_call_center_sk#938))
#                +- Relation [cc_call_center_sk#938,cc_call_center_id#939,cc_rec_start_date#940,cc_rec_end_date#941,cc_closed_date_sk#942,cc_open_date_sk#943,cc_name#944,cc_class#945,cc_employees#946,cc_sq_ft#947,cc_hours#948,cc_manager#949,cc_mkt_id#950,cc_mkt_class#951,cc_mkt_desc#952,cc_market_manager#953,cc_division#954,cc_division_name#955,cc_company#956,cc_company_name#957,cc_street_number#958,cc_street_name#959,cc_street_type#960,cc_suite_number#961,... 7 more fields] JDBCRelation(call_center) [numPartitions=1]
#
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg(project(join))
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: items: List(Aggregate [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409], [sum(c#2994L) AS c#2997L, cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409]
# +- Project [(cast(c#2988L as bigint) * c#2989L) AS c#2994L, cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, c#2988L, d_date_sk#194, c#2989L]
#    +- Join Inner, (cs_ship_date_sk#2378 = cast(d_date_sk#194 as int))
#       :- Project [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, 1 AS c#2988L]
#       :  +- Project [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409]
#       :     +- Filter (((exists#2937 [cs_order_number#2393 && cs_warehouse_sk#2390 && (cs_order_number#2393 = cs_order_number#2956) && NOT (cs_warehouse_sk#2390 = cs_warehouse_sk#2953)] AND NOT exists#2938 [cs_order_number#2393 && (cs_order_number#2393 = cr_order_number#1879)]) AND isnotnull(cs_ship_date_sk#2378)) AND (isnotnull(cs_ship_addr_sk#2386) AND isnotnull(cs_call_center_sk#2387)))
#       :        :  :- Relation [cs_sold_date_sk#2939,cs_sold_time_sk#2940,cs_ship_date_sk#2941,cs_bill_customer_sk#2942,cs_bill_cdemo_sk#2943,cs_bill_hdemo_sk#2944,cs_bill_addr_sk#2945,cs_ship_customer_sk#2946,cs_ship_cdemo_sk#2947,cs_ship_hdemo_sk#2948,cs_ship_addr_sk#2949,cs_call_center_sk#2950,cs_catalog_page_sk#2951,cs_ship_mode_sk#2952,cs_warehouse_sk#2953,cs_item_sk#2954,cs_promo_sk#2955,cs_order_number#2956,cs_quantity#2957,cs_wholesale_cost#2958,cs_list_price#2959,cs_sales_price#2960,cs_ext_discount_amt#2961,cs_ext_sales_price#2962,... 10 more fields] JDBCRelation(catalog_sales) [numPartitions=1]
#       :        :  +- Relation [cr_returned_date_sk#1863,cr_returned_time_sk#1864,cr_item_sk#1865,cr_refunded_customer_sk#1866,cr_refunded_cdemo_sk#1867,cr_refunded_hdemo_sk#1868,cr_refunded_addr_sk#1869,cr_returning_customer_sk#1870,cr_returning_cdemo_sk#1871,cr_returning_hdemo_sk#1872,cr_returning_addr_sk#1873,cr_call_center_sk#1874,cr_catalog_page_sk#1875,cr_ship_mode_sk#1876,cr_warehouse_sk#1877,cr_reason_sk#1878,cr_order_number#1879,cr_return_quantity#1880,cr_return_amount#1881,cr_return_tax#1882,cr_return_amt_inc_tax#1883,cr_fee#1884,cr_return_ship_cost#1885,cr_refunded_cash#1886,... 3 more fields] JDBCRelation(catalog_returns) [numPartitions=1]
#       :        +- Relation [cs_sold_date_sk#2376,cs_sold_time_sk#2377,cs_ship_date_sk#2378,cs_bill_customer_sk#2379,cs_bill_cdemo_sk#2380,cs_bill_hdemo_sk#2381,cs_bill_addr_sk#2382,cs_ship_customer_sk#2383,cs_ship_cdemo_sk#2384,cs_ship_hdemo_sk#2385,cs_ship_addr_sk#2386,cs_call_center_sk#2387,cs_catalog_page_sk#2388,cs_ship_mode_sk#2389,cs_warehouse_sk#2390,cs_item_sk#2391,cs_promo_sk#2392,cs_order_number#2393,cs_quantity#2394,cs_wholesale_cost#2395,cs_list_price#2396,cs_sales_price#2397,cs_ext_discount_amt#2398,cs_ext_sales_price#2399,... 10 more fields] JDBCRelation(catalog_sales) [numPartitions=1]
#       +- Project [d_date_sk#194, 1 AS c#2989L]
#          +- Project [d_date_sk#194]
#             +- Filter ((isnotnull(d_date#196) AND ((d_date#196 >= 2002-03-01) AND (d_date#196 <= 2002-04-30))) AND isnotnull(d_date_sk#194))
#                +- Relation [d_date_sk#194,d_date_id#195,d_date#196,d_month_seq#197,d_week_seq#198,d_quarter_seq#199,d_year#200,d_dow#201,d_moy#202,d_dom#203,d_qoy#204,d_fy_year#205,d_fy_quarter_seq#206,d_fy_week_seq#207,d_day_name#208,d_quarter_name#209,d_holiday#210,d_weekend#211,d_following_holiday#212,d_first_dom#213,d_last_dom#214,d_same_day_ly#215,d_same_day_lq#216,d_current_day#217,... 4 more fields] JDBCRelation(date_dim) [numPartitions=1]
# , Project [cc_call_center_sk#938, 1 AS c#2995L]
# +- Project [cc_call_center_sk#938]
#    +- Filter ((isnotnull(cc_county#963) AND (cc_county#963 = Williamson County)) AND isnotnull(cc_call_center_sk#938))
#       +- Relation [cc_call_center_sk#938,cc_call_center_id#939,cc_rec_start_date#940,cc_rec_end_date#941,cc_closed_date_sk#942,cc_open_date_sk#943,cc_name#944,cc_class#945,cc_employees#946,cc_sq_ft#947,cc_hours#948,cc_manager#949,cc_mkt_id#950,cc_mkt_class#951,cc_mkt_desc#952,cc_market_manager#953,cc_division#954,cc_division_name#955,cc_company#956,cc_company_name#957,cc_street_number#958,cc_street_name#959,cc_street_type#960,cc_suite_number#961,... 7 more fields] JDBCRelation(call_center) [numPartitions=1]
# )
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: conditions: Set((cs_call_center_sk#2387 = cast(cc_call_center_sk#938 as int)))
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg: sum(c#3000L) AS c#3003L
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is 0MA: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is sum: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is non-agg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg: cs_ship_date_sk#2378
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is 0MA: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is sum: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is non-agg: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg: cs_ship_addr_sk#2386
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is 0MA: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is sum: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is non-agg: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg: cs_call_center_sk#2387
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is 0MA: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is sum: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is non-agg: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg: cs_order_number#2393
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is 0MA: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is sum: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is non-agg: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg: cs_ext_ship_cost#2404
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is 0MA: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is sum: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is non-agg: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg: cs_net_profit#2409
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is 0MA: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is sum: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is non-agg: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: aggregate attributes: {c#3000L, cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409}
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: groupingExpressions: Vector(cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409)
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: group attributes: {cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409}
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: counting aggregates: List()
# 23/10/25 14:37:34 WARN Hypergraph: equivalence classes: Set(Set(cs_call_center_sk#2387, cc_call_center_sk#938))
# 23/10/25 14:37:34 WARN Hypergraph: vertex to attribute mapping: Map(cs_call_center_sk#2387 -> Set(cs_call_center_sk#2387, cc_call_center_sk#938))
# 23/10/25 14:37:34 WARN Hypergraph: attribute to vertex mapping: Map(ExprId(938,b837b423-1d1f-448f-bcb3-56d0dafeafeb) -> cs_call_center_sk#2387, ExprId(2387,b837b423-1d1f-448f-bcb3-56d0dafeafeb) -> cs_call_center_sk#2387)
# 23/10/25 14:37:34 WARN Hypergraph: join item: Aggregate [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409], [sum(c#2994L) AS c#2997L, cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409]
# +- Project [(cast(c#2988L as bigint) * c#2989L) AS c#2994L, cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, c#2988L, d_date_sk#194, c#2989L]
#    +- Join Inner, (cs_ship_date_sk#2378 = cast(d_date_sk#194 as int))
#       :- Project [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, 1 AS c#2988L]
#       :  +- Project [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409]
#       :     +- Filter (((exists#2937 [cs_order_number#2393 && cs_warehouse_sk#2390 && (cs_order_number#2393 = cs_order_number#2956) && NOT (cs_warehouse_sk#2390 = cs_warehouse_sk#2953)] AND NOT exists#2938 [cs_order_number#2393 && (cs_order_number#2393 = cr_order_number#1879)]) AND isnotnull(cs_ship_date_sk#2378)) AND (isnotnull(cs_ship_addr_sk#2386) AND isnotnull(cs_call_center_sk#2387)))
#       :        :  :- Relation [cs_sold_date_sk#2939,cs_sold_time_sk#2940,cs_ship_date_sk#2941,cs_bill_customer_sk#2942,cs_bill_cdemo_sk#2943,cs_bill_hdemo_sk#2944,cs_bill_addr_sk#2945,cs_ship_customer_sk#2946,cs_ship_cdemo_sk#2947,cs_ship_hdemo_sk#2948,cs_ship_addr_sk#2949,cs_call_center_sk#2950,cs_catalog_page_sk#2951,cs_ship_mode_sk#2952,cs_warehouse_sk#2953,cs_item_sk#2954,cs_promo_sk#2955,cs_order_number#2956,cs_quantity#2957,cs_wholesale_cost#2958,cs_list_price#2959,cs_sales_price#2960,cs_ext_discount_amt#2961,cs_ext_sales_price#2962,... 10 more fields] JDBCRelation(catalog_sales) [numPartitions=1]
#       :        :  +- Relation [cr_returned_date_sk#1863,cr_returned_time_sk#1864,cr_item_sk#1865,cr_refunded_customer_sk#1866,cr_refunded_cdemo_sk#1867,cr_refunded_hdemo_sk#1868,cr_refunded_addr_sk#1869,cr_returning_customer_sk#1870,cr_returning_cdemo_sk#1871,cr_returning_hdemo_sk#1872,cr_returning_addr_sk#1873,cr_call_center_sk#1874,cr_catalog_page_sk#1875,cr_ship_mode_sk#1876,cr_warehouse_sk#1877,cr_reason_sk#1878,cr_order_number#1879,cr_return_quantity#1880,cr_return_amount#1881,cr_return_tax#1882,cr_return_amt_inc_tax#1883,cr_fee#1884,cr_return_ship_cost#1885,cr_refunded_cash#1886,... 3 more fields] JDBCRelation(catalog_returns) [numPartitions=1]
#       :        +- Relation [cs_sold_date_sk#2376,cs_sold_time_sk#2377,cs_ship_date_sk#2378,cs_bill_customer_sk#2379,cs_bill_cdemo_sk#2380,cs_bill_hdemo_sk#2381,cs_bill_addr_sk#2382,cs_ship_customer_sk#2383,cs_ship_cdemo_sk#2384,cs_ship_hdemo_sk#2385,cs_ship_addr_sk#2386,cs_call_center_sk#2387,cs_catalog_page_sk#2388,cs_ship_mode_sk#2389,cs_warehouse_sk#2390,cs_item_sk#2391,cs_promo_sk#2392,cs_order_number#2393,cs_quantity#2394,cs_wholesale_cost#2395,cs_list_price#2396,cs_sales_price#2397,cs_ext_discount_amt#2398,cs_ext_sales_price#2399,... 10 more fields] JDBCRelation(catalog_sales) [numPartitions=1]
#       +- Project [d_date_sk#194, 1 AS c#2989L]
#          +- Project [d_date_sk#194]
# ...
#       :        +- Relation [cs_sold_date_sk#2376,cs_sold_time_sk#2377,cs_ship_date_sk#2378,cs_bill_customer_sk#2379,cs_bill_cdemo_sk#2380,cs_bill_hdemo_sk#2381,cs_bill_addr_sk#2382,cs_ship_customer_sk#2383,cs_ship_cdemo_sk#2384,cs_ship_hdemo_sk#2385,cs_ship_addr_sk#2386,cs_call_center_sk#2387,cs_catalog_page_sk#2388,cs_ship_mode_sk#2389,cs_warehouse_sk#2390,cs_item_sk#2391,cs_promo_sk#2392,cs_order_number#2393,cs_quantity#2394,cs_wholesale_cost#2395,cs_list_price#2396,cs_sales_price#2397,cs_ext_discount_amt#2398,cs_ext_sales_price#2399,... 10 more fields] JDBCRelation(catalog_sales) [numPartitions=1]
#       +- Project [d_date_sk#194, 1 AS c#2989L]
#          +- Project [d_date_sk#194]
#             +- Filter ((isnotnull(d_date#196) AND ((d_date#196 >= 2002-03-01) AND (d_date#196 <= 2002-04-30))) AND isnotnull(d_date_sk#194))
#                +- Relation [d_date_sk#194,d_date_id#195,d_date#196,d_month_seq#197,d_week_seq#198,d_quarter_seq#199,d_year#200,d_dow#201,d_moy#202,d_dom#203,d_qoy#204,d_fy_year#205,d_fy_quarter_seq#206,d_fy_week_seq#207,d_day_name#208,d_quarter_name#209,d_holiday#210,d_weekend#211,d_following_holiday#212,d_first_dom#213,d_last_dom#214,d_same_day_ly#215,d_same_day_lq#216,d_current_day#217,... 4 more fields] JDBCRelation(date_dim) [numPartitions=1]
#
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg(project(join))
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: items: List(Project [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, 1 AS c#2988L]
# +- Project [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409]
#    +- Filter (((exists#2937 [cs_order_number#2393 && cs_warehouse_sk#2390 && (cs_order_number#2393 = cs_order_number#2956) && NOT (cs_warehouse_sk#2390 = cs_warehouse_sk#2953)] AND NOT exists#2938 [cs_order_number#2393 && (cs_order_number#2393 = cr_order_number#1879)]) AND isnotnull(cs_ship_date_sk#2378)) AND (isnotnull(cs_ship_addr_sk#2386) AND isnotnull(cs_call_center_sk#2387)))
#       :  :- Relation [cs_sold_date_sk#2939,cs_sold_time_sk#2940,cs_ship_date_sk#2941,cs_bill_customer_sk#2942,cs_bill_cdemo_sk#2943,cs_bill_hdemo_sk#2944,cs_bill_addr_sk#2945,cs_ship_customer_sk#2946,cs_ship_cdemo_sk#2947,cs_ship_hdemo_sk#2948,cs_ship_addr_sk#2949,cs_call_center_sk#2950,cs_catalog_page_sk#2951,cs_ship_mode_sk#2952,cs_warehouse_sk#2953,cs_item_sk#2954,cs_promo_sk#2955,cs_order_number#2956,cs_quantity#2957,cs_wholesale_cost#2958,cs_list_price#2959,cs_sales_price#2960,cs_ext_discount_amt#2961,cs_ext_sales_price#2962,... 10 more fields] JDBCRelation(catalog_sales) [numPartitions=1]
#       :  +- Relation [cr_returned_date_sk#1863,cr_returned_time_sk#1864,cr_item_sk#1865,cr_refunded_customer_sk#1866,cr_refunded_cdemo_sk#1867,cr_refunded_hdemo_sk#1868,cr_refunded_addr_sk#1869,cr_returning_customer_sk#1870,cr_returning_cdemo_sk#1871,cr_returning_hdemo_sk#1872,cr_returning_addr_sk#1873,cr_call_center_sk#1874,cr_catalog_page_sk#1875,cr_ship_mode_sk#1876,cr_warehouse_sk#1877,cr_reason_sk#1878,cr_order_number#1879,cr_return_quantity#1880,cr_return_amount#1881,cr_return_tax#1882,cr_return_amt_inc_tax#1883,cr_fee#1884,cr_return_ship_cost#1885,cr_refunded_cash#1886,... 3 more fields] JDBCRelation(catalog_returns) [numPartitions=1]
#       +- Relation [cs_sold_date_sk#2376,cs_sold_time_sk#2377,cs_ship_date_sk#2378,cs_bill_customer_sk#2379,cs_bill_cdemo_sk#2380,cs_bill_hdemo_sk#2381,cs_bill_addr_sk#2382,cs_ship_customer_sk#2383,cs_ship_cdemo_sk#2384,cs_ship_hdemo_sk#2385,cs_ship_addr_sk#2386,cs_call_center_sk#2387,cs_catalog_page_sk#2388,cs_ship_mode_sk#2389,cs_warehouse_sk#2390,cs_item_sk#2391,cs_promo_sk#2392,cs_order_number#2393,cs_quantity#2394,cs_wholesale_cost#2395,cs_list_price#2396,cs_sales_price#2397,cs_ext_discount_amt#2398,cs_ext_sales_price#2399,... 10 more fields] JDBCRelation(catalog_sales) [numPartitions=1]
# , Project [d_date_sk#194, 1 AS c#2989L]
# +- Project [d_date_sk#194]
#    +- Filter ((isnotnull(d_date#196) AND ((d_date#196 >= 2002-03-01) AND (d_date#196 <= 2002-04-30))) AND isnotnull(d_date_sk#194))
#       +- Relation [d_date_sk#194,d_date_id#195,d_date#196,d_month_seq#197,d_week_seq#198,d_quarter_seq#199,d_year#200,d_dow#201,d_moy#202,d_dom#203,d_qoy#204,d_fy_year#205,d_fy_quarter_seq#206,d_fy_week_seq#207,d_day_name#208,d_quarter_name#209,d_holiday#210,d_weekend#211,d_following_holiday#212,d_first_dom#213,d_last_dom#214,d_same_day_ly#215,d_same_day_lq#216,d_current_day#217,... 4 more fields] JDBCRelation(date_dim) [numPartitions=1]
# )
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: conditions: Set((cs_ship_date_sk#2378 = cast(d_date_sk#194 as int)))
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg: sum(c#2994L) AS c#2997L
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is 0MA: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is sum: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is non-agg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg: cs_ship_date_sk#2378
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is 0MA: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is sum: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is non-agg: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg: cs_ship_addr_sk#2386
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is 0MA: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is sum: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is non-agg: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg: cs_call_center_sk#2387
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is 0MA: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is sum: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is non-agg: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg: cs_order_number#2393
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is 0MA: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is sum: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is non-agg: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg: cs_ext_ship_cost#2404
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is 0MA: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is sum: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is non-agg: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: agg: cs_net_profit#2409
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is 0MA: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is sum: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: is non-agg: true
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: aggregate attributes: {c#2994L, cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409}
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: groupingExpressions: Vector(cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409)
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: group attributes: {cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409}
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: counting aggregates: List()
# 23/10/25 14:37:34 WARN Hypergraph: equivalence classes: Set(Set(cs_ship_date_sk#2378, d_date_sk#194))
# 23/10/25 14:37:34 WARN Hypergraph: vertex to attribute mapping: Map(cs_ship_date_sk#2378 -> Set(cs_ship_date_sk#2378, d_date_sk#194))
# 23/10/25 14:37:34 WARN Hypergraph: attribute to vertex mapping: Map(ExprId(194,b837b423-1d1f-448f-bcb3-56d0dafeafeb) -> cs_ship_date_sk#2378, ExprId(2378,b837b423-1d1f-448f-bcb3-56d0dafeafeb) -> cs_ship_date_sk#2378)
# 23/10/25 14:37:34 WARN Hypergraph: join item: Project [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, 1 AS c#2988L]
# +- Project [cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409]
#    +- Filter (((exists#2937 [cs_order_number#2393 && cs_warehouse_sk#2390 && (cs_order_number#2393 = cs_order_number#2956) && NOT (cs_warehouse_sk#2390 = cs_warehouse_sk#2953)] AND NOT exists#2938 [cs_order_number#2393 && (cs_order_number#2393 = cr_order_number#1879)]) AND isnotnull(cs_ship_date_sk#2378)) AND (isnotnull(cs_ship_addr_sk#2386) AND isnotnull(cs_call_center_sk#2387)))
#       :  :- Relation [cs_sold_date_sk#2939,cs_sold_time_sk#2940,cs_ship_date_sk#2941,cs_bill_customer_sk#2942,cs_bill_cdemo_sk#2943,cs_bill_hdemo_sk#2944,cs_bill_addr_sk#2945,cs_ship_customer_sk#2946,cs_ship_cdemo_sk#2947,cs_ship_hdemo_sk#2948,cs_ship_addr_sk#2949,cs_call_center_sk#2950,cs_catalog_page_sk#2951,cs_ship_mode_sk#2952,cs_warehouse_sk#2953,cs_item_sk#2954,cs_promo_sk#2955,cs_order_number#2956,cs_quantity#2957,cs_wholesale_cost#2958,cs_list_price#2959,cs_sales_price#2960,cs_ext_discount_amt#2961,cs_ext_sales_price#2962,... 10 more fields] JDBCRelation(catalog_sales) [numPartitions=1]
#       :  +- Relation [cr_returned_date_sk#1863,cr_returned_time_sk#1864,cr_item_sk#1865,cr_refunded_customer_sk#1866,cr_refunded_cdemo_sk#1867,cr_refunded_hdemo_sk#1868,cr_refunded_addr_sk#1869,cr_returning_customer_sk#1870,cr_returning_cdemo_sk#1871,cr_returning_hdemo_sk#1872,cr_returning_addr_sk#1873,cr_call_center_sk#1874,cr_catalog_page_sk#1875,cr_ship_mode_sk#1876,cr_warehouse_sk#1877,cr_reason_sk#1878,cr_order_number#1879,cr_return_quantity#1880,cr_return_amount#1881,cr_return_tax#1882,cr_return_amt_inc_tax#1883,cr_fee#1884,cr_return_ship_cost#1885,cr_refunded_cash#1886,... 3 more fields] JDBCRelation(catalog_returns) [numPartitions=1]
#       +- Relation [cs_sold_date_sk#2376,cs_sold_time_sk#2377,cs_ship_date_sk#2378,cs_bill_customer_sk#2379,cs_bill_cdemo_sk#2380,cs_bill_hdemo_sk#2381,cs_bill_addr_sk#2382,cs_ship_customer_sk#2383,cs_ship_cdemo_sk#2384,cs_ship_hdemo_sk#2385,cs_ship_addr_sk#2386,cs_call_center_sk#2387,cs_catalog_page_sk#2388,cs_ship_mode_sk#2389,cs_warehouse_sk#2390,cs_item_sk#2391,cs_promo_sk#2392,cs_order_number#2393,cs_quantity#2394,cs_wholesale_cost#2395,cs_list_price#2396,cs_sales_price#2397,cs_ext_discount_amt#2398,cs_ext_sales_price#2399,... 10 more fields] JDBCRelation(catalog_sales) [numPartitions=1]
#
# 23/10/25 14:37:34 WARN Hypergraph: join item: Project [d_date_sk#194, 1 AS c#2989L]
# +- Project [d_date_sk#194]
#    +- Filter ((isnotnull(d_date#196) AND ((d_date#196 >= 2002-03-01) AND (d_date#196 <= 2002-04-30))) AND isnotnull(d_date_sk#194))
#       +- Relation [d_date_sk#194,d_date_id#195,d_date#196,d_month_seq#197,d_week_seq#198,d_quarter_seq#199,d_year#200,d_dow#201,d_moy#202,d_dom#203,d_qoy#204,d_fy_year#205,d_fy_quarter_seq#206,d_fy_week_seq#207,d_day_name#208,d_quarter_name#209,d_holiday#210,d_weekend#211,d_following_holiday#212,d_first_dom#213,d_last_dom#214,d_same_day_ly#215,d_same_day_lq#216,d_current_day#217,... 4 more fields] JDBCRelation(date_dim) [numPartitions=1]
#
# 23/10/25 14:37:34 WARN Hypergraph: hyperedges: Set(E1(cs_ship_date_sk#2378), E2(cs_ship_date_sk#2378))
# 23/10/25 14:37:34 WARN Hypergraph: gyo edge: E1(cs_ship_date_sk#2378)
# 23/10/25 14:37:34 WARN Hypergraph: supersets: Set()
# 23/10/25 14:37:34 WARN Hypergraph: parentNode: TreeNode(Set(E1(cs_ship_date_sk#2378)))[Set({cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, c#2988L})] [[parent: false]]
#
# 23/10/25 14:37:34 WARN Hypergraph: subsets: Set(TreeNode(Set(E2(cs_ship_date_sk#2378)))[Set({d_date_sk#194, c#2989L})] [[parent: false]]
# )
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: join tree:
# TreeNode(Set(E1(cs_ship_date_sk#2378)))[Set({cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, c#2988L})] [[parent: false]]
# -- TreeNode(Set(E2(cs_ship_date_sk#2378)))[Set({d_date_sk#194, c#2989L})] [[parent: true]]
#
# 23/10/25 14:37:34 WARN HTNode: aggAttributes: {c#2994L, cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409}
# 23/10/25 14:37:34 WARN HTNode: nodeAttributes: {cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409, c#2988L}
# 23/10/25 14:37:34 WARN HTNode: aggAttributes: {c#2994L, cs_ship_date_sk#2378, cs_ship_addr_sk#2386, cs_call_center_sk#2387, cs_order_number#2393, cs_ext_ship_cost#2404, cs_net_profit#2409}
# 23/10/25 14:37:34 WARN HTNode: nodeAttributes: {d_date_sk#194, c#2989L}
# 23/10/25 14:37:34 WARN RewriteJoinsAsSemijoins: query is not 0MA
# ---------------------------------------------------------------------------
# SparkRuntimeException                     Traceback (most recent call last)
# /tmp/ipykernel_148381/2971890032.py in <module>
#      17
#      18 df1 = run_query(query)
# ---> 19 df1.show()
#      20 df1.explain(mode="extended")
#      21
#
# ~/.local/lib/python3.10/site-packages/pyspark/sql/dataframe.py in show(self, n, truncate, vertical)
#     927
#     928         if isinstance(truncate, bool) and truncate:
# --> 929             print(self._jdf.showString(n, 20, vertical))
#     930         else:
#     931             try:
#
# ~/.local/lib/python3.10/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1320
#    1321         answer = self.gateway_client.send_command(command)
# -> 1322         return_value = get_return_value(
#    1323             answer, self.gateway_client, self.target_id, self.name)
#    1324
#
# ~/.local/lib/python3.10/site-packages/pyspark/errors/exceptions/captured.py in deco(*a, **kw)
#     183                 # Hide where the exception came from that shows a non-Pythonic
#     184                 # JVM exception message.
# --> 185                 raise converted from None
#     186             else:
#     187                 raise
#
# SparkRuntimeException: Error while decoding: java.lang.NullPointerException: Cannot invoke "org.apache.spark.unsafe.types.UTF8String.toString()" because "<local3>" is null
# createexternalrow(input[0, string, false].toString, input[1, string, false].toString, input[2, string, false].toString, StructField(toprettystring(order count),StringType,false), StructField(toprettystring(total shipping cost),StringType,false), StructField(toprettystring(total net profit),StringType,false)).
