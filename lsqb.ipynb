# %%
from pyspark.sql import SparkSession
import os

# %%
spark = SparkSession.builder \
        .appName("app") \
        .config("spark.driver.memory", "45g") \
        .config("spark.executor.memory", "45g") \
        .config("spark.jars", "postgresql-42.3.3.jar") \
        .getOrCreate()
#spark.sparkContext.setLogLevel("DEBUG")
# Out:
# 23/10/24 12:48:25 WARN Utils: Your hostname, server-rennweg resolves to a loopback address: 127.0.1.1; using 192.168.1.196 instead (on interface enp5s0f1)
# 23/10/24 12:48:25 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 23/10/24 12:48:25 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
spark.sparkContext.setLogLevel("WARN") # ALL, DEBUG, WARN,
#spark.sparkContext.setLogLevel("ALL") # ALL, DEBUG, WARN,

# %%
username = os.environ.get('USERNAME', 'lsqb')
password = os.environ.get('PASSWORD', 'lsqb')
dbname = os.environ.get('DBNAME', 'lsqb')
dbhost = os.environ.get('DBHOST', 'localhost')

df_tables = spark.read.format("jdbc") \
    .option("url", f'jdbc:postgresql://{dbhost}:5432/{dbname}') \
    .option("driver", "org.postgresql.Driver") \
    .option("dbtable", "information_schema.tables") \
    .option("user", username) \
    .option("password", password) \
    .load()

for idx, row in df_tables.toPandas().iterrows():
        if row.table_schema == 'public':
            table_name = row.table_name
            df = spark.read.format("jdbc") \
                .option("url", f'jdbc:postgresql://{dbhost}:5432/{dbname}') \
                .option("driver", "org.postgresql.Driver") \
                .option("dbtable", table_name) \
                .option("user", username) \
                .option("password", password) \
                .load()
    
            print(table_name)
            print(df.show())
            df.createOrReplaceTempView(table_name)
# Out:
# company
# +---------+---------------------+
# |companyid|islocatedin_countryid|
# +---------+---------------------+
# |        0|                   59|
# |        1|                   59|
# |        2|                   59|
# |        3|                   59|
# |        4|                   59|
# |        5|                   59|
# |        6|                   59|
# |        7|                   60|
# |        8|                   60|
# |        9|                   60|
# |       10|                   60|
# |       11|                   60|
# |       12|                    2|
# |       13|                    2|
# |       14|                    2|
# |       15|                    2|
# |       16|                    2|
# |       17|                    2|
# |       18|                    2|
# |       19|                    2|
# +---------+---------------------+
# only showing top 20 rows
#
# None
# university
# +------------+------------------+
# |universityid|islocatedin_cityid|
# +------------+------------------+
# |        1575|               957|
# |        1576|               951|
# |        1577|               954|
# |        1578|               952|
# |        1579|               772|
# |        1580|               956|
# |        1581|               953|
# |        1582|               955|
# |        1583|               955|
# |        1584|               959|
# |        1585|               955|
# |        1586|               958|
# |        1587|               955|
# |        1588|               953|
# |        1589|               955|
# |        1590|               955|
# |        1591|               955|
# |        1592|               955|
# |        1593|               955|
# |        1594|               959|
# +------------+------------------+
# only showing top 20 rows
#
# None
# continent
# +-----------+
# |continentid|
# +-----------+
# |       1454|
# |       1455|
# |       1456|
# |       1457|
# |       1458|
# |       1459|
# +-----------+
#
# None
# country
# +---------+--------------------+
# |countryid|ispartof_continentid|
# +---------+--------------------+
# |        0|                1454|
# |        1|                1454|
# |        2|                1455|
# |        3|                1456|
# |        4|                1454|
# |        5|                1457|
# |        6|                1456|
# |        7|                1456|
# |        8|                1455|
# |        9|                1456|
# |       10|                1456|
# |       11|                1458|
# |       12|                1458|
# |       13|                1456|
# |       14|                1456|
# |       15|                1458|
# |       16|                1454|
# |       17|                1454|
# |       18|                1454|
# |       19|                1454|
# +---------+--------------------+
# only showing top 20 rows
#
# None
# city
# +------+------------------+
# |cityid|ispartof_countryid|
# +------+------------------+
# |   111|                 0|
# |   112|                 0|
# |   113|                 0|
# |   114|                 0|
# |   115|                 0|
# |   116|                 0|
# |   117|                 0|
# |   118|                 0|
# |   119|                 0|
# |   120|                 0|
# |   121|                 0|
# |   122|                 0|
# |   123|                 0|
# |   124|                 0|
# |   125|                 0|
# |   126|                 0|
# |   127|                 0|
# |   128|                 0|
# |   129|                 0|
# |   130|                 0|
# +------+------------------+
# only showing top 20 rows
#
# None
# tag
# +-----+------------------+
# |tagid|hastype_tagclassid|
# +-----+------------------+
# |    0|               349|
# |    1|               211|
# |    2|                98|
# |    3|               336|
# |    4|               336|
# |    5|               336|
# |    6|               193|
# |    7|                82|
# |    8|                88|
# |    9|               211|
# |   10|                57|
# |   11|                94|
# |   12|                59|
# |   13|                59|
# |   14|                59|
# |   15|               349|
# |   16|                59|
# |   17|                59|
# |   18|                59|
# |   19|                59|
# +-----+------------------+
# only showing top 20 rows
#
# None
# tagclass
# +----------+-----------------------+
# |tagclassid|issubclassof_tagclassid|
# +----------+-----------------------+
# |       349|                    211|
# |       211|                    239|
# |       239|                      0|
# |         0|                   NULL|
# |        98|                    211|
# |       336|                    155|
# |       155|                    211|
# |       193|                    109|
# |       109|                    211|
# |        82|                    211|
# |        88|                    250|
# |       250|                    211|
# |        57|                     95|
# |        95|                    211|
# |        94|                    211|
# |        59|                    149|
# |       149|                    211|
# |        74|                    149|
# |       115|                    250|
# |        37|                    149|
# +----------+-----------------------+
# only showing top 20 rows
#
# None
# forum
# +-------------+---------------------+
# |      forumid|hasmoderator_personid|
# +-------------+---------------------+
# |            0|                  183|
# |1924145348609|                  183|
# | 549755813890|                  183|
# |1924145348611|                  183|
# |2199023255556|                  183|
# | 962072674309|                  183|
# |1099511627782|                  183|
# | 962072674311|                  183|
# |1924145348616|                  183|
# | 962072674313|                  183|
# |1786706395146|                  183|
# | 412316860427|                  183|
# | 687194767372|                  183|
# | 824633720845|                  183|
# |1099511627790|                  183|
# |1374389534735|                  183|
# |2199023255568|                  183|
# | 687194767377|                  183|
# | 962072674322|                  183|
# |1649267441683|                  183|
# +-------------+---------------------+
# only showing top 20 rows
#
# None
# comment
# +-------------+-------------------+---------------------+--------------+-----------------+
# |    commentid|hascreator_personid|islocatedin_countryid|replyof_postid|replyof_commentid|
# +-------------+-------------------+---------------------+--------------+-----------------+
# |1786708895207|     13194139538306|                   57|          NULL|    1649269941733|
# |1511830988264|      8796093025657|                   96|          NULL|    1511830988257|
# |2336464709097|     37383395346869|                   91|          NULL|    1511830988257|
# |2199025755627|     19791209302493|                   49| 1786708895210|             NULL|
# |1786708895212|      6597069772839|                   53| 1786708895210|             NULL|
# |1786708895213|      2199023259253|                    1| 1786708895210|             NULL|
# |2336464709102|               8410|                    4|          NULL|    1786708895212|
# |1786708895215|               9043|                   81|          NULL|    1786708895212|
# |1786708895216|     15393162790992|                   96| 1786708895210|             NULL|
# |1924147848689|     24189255818790|                   61| 1786708895210|             NULL|
# |1786708895218|      6597069774032|                   55|          NULL|    1786708895212|
# |1786708895219|     13194139538306|                   57|          NULL|    1786708895218|
# |1786708895220|     28587302330467|                   56|          NULL|    1786708895213|
# |1649269941750|     24189255814382|                   59|  962075174389|             NULL|
# |2061586802167|     13194139540646|                   98|  962075174389|             NULL|
# |2336464709112|               8410|                    4|          NULL|    2061586802167|
# |2199025755641|     30786325583469|                   80|  962075174389|             NULL|
# |1236953081338|               5252|                   58|  962075174389|             NULL|
# | 962075174395|      4398046517420|                   56|  962075174389|             NULL|
# |2199025755644|     30786325581274|                   56|          NULL|    2061586802167|
# +-------------+-------------------+---------------------+--------------+-----------------+
# only showing top 20 rows
#
# None
# post
# +-------------+-------------------+-------------------+---------------------+
# |       postid|hascreator_personid|forum_containerofid|islocatedin_countryid|
# +-------------+-------------------+-------------------+---------------------+
# |1236950581248|                183|                  0|                   58|
# |            3|                183|                  0|                   52|
# | 549755813894|                183|       549755813890|                   52|
# | 549755813895|                183|       549755813890|                   52|
# | 549755813896|                183|       549755813890|                   52|
# | 549755813897|                183|       549755813890|                   52|
# | 549755813898|                183|       549755813890|                   52|
# | 549755813899|                183|       549755813890|                   52|
# | 549755813900|                183|       549755813890|                   52|
# | 549755813901|                183|       549755813890|                   52|
# | 549755813902|                183|       549755813890|                   52|
# | 549755813903|                183|       549755813890|                   52|
# | 549755813904|                183|       549755813890|                   52|
# | 549755813905|                183|       549755813890|                   52|
# | 549755813906|                183|       549755813890|                   23|
# | 549755813907|                183|       549755813890|                   52|
# | 549755813908|                183|       549755813890|                   52|
# | 549755813909|                183|       549755813890|                   52|
# | 549755813910|                183|       549755813890|                   52|
# | 549755813911|                183|       549755813890|                   52|
# +-------------+-------------------+-------------------+---------------------+
# only showing top 20 rows
#
# None
# person
# +--------------+------------------+
# |      personid|islocatedin_cityid|
# +--------------+------------------+
# |26388279068012|               874|
# | 6597069772072|               573|
# |17592186049596|              1224|
# |24189255813996|               526|
# |32985348833336|              1086|
# |24189255820196|               849|
# |21990232565548|              1224|
# |35184372089372|               370|
# |          6400|              1212|
# |28587302322944|              1011|
# |37383395346664|               503|
# |24189255817928|              1415|
# |26388279067812|               590|
# |17592186047652|              1261|
# | 8796093023432|               236|
# | 6597069774500|              1264|
# | 8796093026468|              1355|
# |35184372089840|               170|
# |10995116280704|               347|
# |28587302325464|               368|
# +--------------+------------------+
# only showing top 20 rows
#
# None
# comment_hastag_tag
# +-------------+-----+
# |    commentid|tagid|
# +-------------+-----+
# |1511828488547| 2028|
# |1511828488550| 2031|
# |1786706395496| 2031|
# |1786706395496| 9076|
# |1511828488555|  139|
# |1511828488555| 2860|
# |1511828488558| 2031|
# |1511828488558| 2086|
# |1786706395504| 4944|
# |2061584302449| 9295|
# |2336462209397|  139|
# |2336462209397| 6984|
# |2336462209398|  139|
# |2336462209398| 6984|
# |2336462209398| 7079|
# |2336462209402| 2830|
# |2061584302459| 2956|
# |2336462209408| 2785|
# |2336462209408| 6984|
# |2336462209408| 7079|
# +-------------+-----+
# only showing top 20 rows
#
# None
# post_hastag_tag
# +-------------+-----+
# |       postid|tagid|
# +-------------+-----+
# |1236950581248|  277|
# |1236950581248| 2778|
# |            3|  277|
# | 962072674656|  139|
# |1511828488564|  139|
# |1511828488564| 9036|
# |1511828488584|  139|
# |1236950581660|  139|
# |1511828488624|  139|
# | 962072674756|  139|
# | 962072674756|  410|
# |1924145349080|  139|
# | 274877907436|  139|
# | 687194767872| 1937|
# | 687194767872| 9061|
# | 687194767872|11479|
# | 687194767880|  413|
# | 687194767880| 1506|
# | 687194767880| 2901|
# | 687194767880| 5132|
# +-------------+-----+
# only showing top 20 rows
#
# None
# forum_hasmember_person
# [Stage 14:>                                                         (0 + 1) / 1]
# +-------------+--------------+
# |      forumid|      personid|
# +-------------+--------------+
# |            0|         10349|
# |            0|15393162791403|
# |            0|19791209306158|
# |1924145348609|         10349|
# |1924145348609|15393162791403|
# |1924145348609|19791209306158|
# | 549755813890|         10349|
# | 549755813890|15393162791403|
# |1924145348611|         10349|
# |1924145348611|15393162791403|
# |1924145348611|19791209306158|
# |2199023255556|         10349|
# |2199023255556|15393162791403|
# |2199023255556|19791209306158|
# | 962072674309|         10349|
# | 962072674309|19791209306158|
# |1099511627782|         10349|
# |1099511627782|15393162791403|
# |1099511627782|19791209306158|
# | 962072674311|         10349|
# +-------------+--------------+
# only showing top 20 rows
#
# None
# forum_hastag_tag
# +-------------+-----+
# |      forumid|tagid|
# +-------------+-----+
# |            0|  277|
# |            0|  448|
# |            0| 1930|
# |            0| 2045|
# |            0| 2778|
# |            0| 2826|
# |            0| 5095|
# |            0| 5116|
# |            0| 5147|
# |            0| 5364|
# |            0| 5957|
# |            0| 7001|
# |            0| 7088|
# |            0| 7514|
# |            0| 7790|
# |            0| 9012|
# |            0|12115|
# |1924145348609| 5147|
# | 549755813890| 2778|
# |1924145348611| 5147|
# +-------------+-----+
# only showing top 20 rows
#
# None
# person_hasinterest_tag
# +--------------+-----+
# |      personid|tagid|
# +--------------+-----+
# |26388279068012|  470|
# |26388279068012| 1178|
# |26388279068012| 1424|
# |26388279068012| 1545|
# |26388279068012| 1764|
# |26388279068012| 1995|
# |26388279068012| 2020|
# |26388279068012| 2073|
# |26388279068012| 2121|
# |26388279068012| 2793|
# |26388279068012| 2849|
# |26388279068012| 2947|
# |26388279068012| 3045|
# |26388279068012| 6400|
# |26388279068012| 6931|
# |26388279068012| 6933|
# |26388279068012| 7542|
# |26388279068012|13070|
# |26388279068012|15807|
# | 6597069772072| 1444|
# +--------------+-----+
# only showing top 20 rows
#
# None
# person_likes_comment
# +--------------+-------------+
# |      personid|    commentid|
# +--------------+-------------+
# |10995116281902|2061584302498|
# |15393162799448|2199023255973|
# |15393162791403|1511828488625|
# |15393162799448|1511828488625|
# |17592186051872|1511828488625|
# |19791209305864|1511828488625|
# |21990232563252|1511828488625|
# |21990232566466|1511828488625|
# |          3470|2336462209533|
# | 4398046517420|2336462209533|
# |10995116281902|2336462209533|
# |15393162791403|2336462209533|
# |15393162799448|2336462209533|
# |17592186051872|2336462209533|
# |19791209305864|2336462209533|
# |21990232563252|2336462209533|
# |21990232566466|2336462209533|
# |24189255815615|2336462209533|
# |24189255817581|2336462209533|
# |32985348841016|2336462209533|
# +--------------+-------------+
# only showing top 20 rows
#
# None
# person_likes_post
# +--------------+-------------+
# |      personid|       postid|
# +--------------+-------------+
# |         10349| 549755813898|
# |         10349| 549755813900|
# |15393162791403|1924145348639|
# |         10349|1924145348643|
# |15393162791403|1924145348643|
# |19791209306158|1924145348643|
# |15393162791403|1924145348644|
# |15393162791403|2199023255594|
# |15393162791403|2199023255597|
# |         10349|1099511627825|
# |         10349|1924145348683|
# |         10349|1924145348692|
# |15393162791403|1786706395228|
# |15393162791403|1786706395235|
# |15393162791403|1786706395241|
# |19791209306158|1786706395241|
# |         10349| 687194767480|
# |         10349|1099511627911|
# |         10349|1099511627920|
# |         10349|1374389534872|
# +--------------+-------------+
# only showing top 20 rows
#
# None
# person_studyat_university
# +--------------+------------+
# |      personid|universityid|
# +--------------+------------+
# |26388279068012|        6805|
# | 6597069772072|        1854|
# |17592186049596|        5147|
# |24189255813996|        4973|
# |32985348833336|        2452|
# |24189255820196|        5984|
# |21990232565548|        5144|
# |35184372089372|        2207|
# |28587302322944|        1955|
# |37383395346664|        2213|
# |24189255817928|        6620|
# |26388279067812|        1854|
# |17592186047652|        5235|
# | 8796093023432|        3015|
# | 6597069774500|        5235|
# |35184372089840|        3006|
# |10995116280704|        2248|
# |28587302325464|        2209|
# |26388279075872|        1981|
# |26388279067500|        2948|
# +--------------+------------+
# only showing top 20 rows
#
# None
# person_workat_company
# +--------------+---------+
# |      personid|companyid|
# +--------------+---------+
# |26388279068012|     1442|
# |26388279068012|     1509|
# |26388279068012|     1551|
# | 6597069772072|      161|
# | 6597069772072|      151|
# | 6597069772072|      185|
# |17592186049596|      809|
# |17592186049596|      812|
# |17592186049596|      813|
# |24189255813996|      730|
# |24189255813996|      733|
# |24189255813996|      734|
# |32985348833336|      300|
# |21990232565548|      810|
# |21990232565548|      811|
# |35184372089372|      917|
# |35184372089372|      918|
# |35184372089372|      921|
# |          6400|      770|
# |          6400|      760|
# +--------------+---------+
# only showing top 20 rows
#
# None
# person_knows_person
# +--------------+--------------+
# |     person1id|     person2id|
# +--------------+--------------+
# |26388279068012|26388279070147|
# |26388279068012|28587302329901|
# |26388279068012|28587302332864|
# |26388279068012|32985348835002|
# |26388279068012|32985348837712|
# |26388279068012|32985348839886|
# |26388279068012|32985348840224|
# |26388279068012|32985348841246|
# |26388279068012|32985348841555|
# |26388279068012|32985348841879|
# |26388279068012|32985348843333|
# |26388279068012|32985348843901|
# |26388279068012|37383395352030|
# | 6597069772072|10995116285514|
# | 6597069772072|17592186051788|
# | 6597069772072|21990232561742|
# | 6597069772072|26388279070147|
# | 6597069772072|30786325588189|
# | 6597069772072|35184372092025|
# | 6597069772072|37383395346298|
# +--------------+--------------+
# only showing top 20 rows
#
# None
# message
# [Stage 22:>                                                         (0 + 1) / 1]
# +-------------+
# |    messageid|
# +-------------+
# |1786708895207|
# |1511830988264|
# |2336464709097|
# |2199025755627|
# |1786708895212|
# |1786708895213|
# |2336464709102|
# |1786708895215|
# |1786708895216|
# |1924147848689|
# |1786708895218|
# |1786708895219|
# |1786708895220|
# |1649269941750|
# |2061586802167|
# |2336464709112|
# |2199025755641|
# |1236953081338|
# | 962075174395|
# |2199025755644|
# +-------------+
# only showing top 20 rows
#
# None
# comment_replyof_message
# [Stage 23:>                                                         (0 + 1) / 1]
# +-------------+---------------+
# |    commentid|parentmessageid|
# +-------------+---------------+
# |2199025755627|  1786708895210|
# |1786708895212|  1786708895210|
# |1786708895213|  1786708895210|
# |1786708895216|  1786708895210|
# |1924147848689|  1786708895210|
# |1649269941750|   962075174389|
# |2061586802167|   962075174389|
# |2199025755641|   962075174389|
# |1236953081338|   962075174389|
# | 962075174395|   962075174389|
# |1649269941759|   962075174389|
# |1374392034817|  1099514127872|
# |2061586802178|  1099514127872|
# |2336464709123|  1099514127872|
# |1924147848708|  1099514127872|
# |2199025755653|  1099514127872|
# |2061586802183|  1099514127872|
# |1099514127880|  1099514127872|
# |1786708895244|  1786708895243|
# |1786708895245|  1786708895243|
# +-------------+---------------+
# only showing top 20 rows
#
# None
# message_hascreator_person
# +-------------+-------------------+
# |    messageid|hascreator_personid|
# +-------------+-------------------+
# |1786708895207|     13194139538306|
# |1511830988264|      8796093025657|
# |2336464709097|     37383395346869|
# |2199025755627|     19791209302493|
# |1786708895212|      6597069772839|
# |1786708895213|      2199023259253|
# |2336464709102|               8410|
# |1786708895215|               9043|
# |1786708895216|     15393162790992|
# |1924147848689|     24189255818790|
# |1786708895218|      6597069774032|
# |1786708895219|     13194139538306|
# |1786708895220|     28587302330467|
# |1649269941750|     24189255814382|
# |2061586802167|     13194139540646|
# |2336464709112|               8410|
# |2199025755641|     30786325583469|
# |1236953081338|               5252|
# | 962075174395|      4398046517420|
# |2199025755644|     30786325581274|
# +-------------+-------------------+
# only showing top 20 rows
#
# None
# message_hastag_tag
# [Stage 25:>                                                         (0 + 1) / 1]
# +-------------+-----+
# |    messageid|tagid|
# +-------------+-----+
# |1511828488547| 2028|
# |1511828488550| 2031|
# |1786706395496| 2031|
# |1786706395496| 9076|
# |1511828488555|  139|
# |1511828488555| 2860|
# |1511828488558| 2031|
# |1511828488558| 2086|
# |1786706395504| 4944|
# |2061584302449| 9295|
# |2336462209397|  139|
# |2336462209397| 6984|
# |2336462209398|  139|
# |2336462209398| 6984|
# |2336462209398| 7079|
# |2336462209402| 2830|
# |2061584302459| 2956|
# |2336462209408| 2785|
# |2336462209408| 6984|
# |2336462209408| 7079|
# +-------------+-----+
# only showing top 20 rows
#
# None
# message_islocatedin_country
# +-------------+---------------------+
# |    messageid|islocatedin_countryid|
# +-------------+---------------------+
# |1786708895207|                   57|
# |1511830988264|                   96|
# |2336464709097|                   91|
# |2199025755627|                   49|
# |1786708895212|                   53|
# |1786708895213|                    1|
# |2336464709102|                    4|
# |1786708895215|                   81|
# |1786708895216|                   96|
# |1924147848689|                   61|
# |1786708895218|                   55|
# |1786708895219|                   57|
# |1786708895220|                   56|
# |1649269941750|                   59|
# |2061586802167|                   98|
# |2336464709112|                    4|
# |2199025755641|                   80|
# |1236953081338|                   58|
# | 962075174395|                   56|
# |2199025755644|                   56|
# +-------------+---------------------+
# only showing top 20 rows
#
# None
# person_likes_message
# +--------------+-------------+
# |      personid|    messageid|
# +--------------+-------------+
# |10995116281902|2061584302498|
# |15393162799448|2199023255973|
# |15393162791403|1511828488625|
# |15393162799448|1511828488625|
# |17592186051872|1511828488625|
# |19791209305864|1511828488625|
# |21990232563252|1511828488625|
# |21990232566466|1511828488625|
# |          3470|2336462209533|
# | 4398046517420|2336462209533|
# |10995116281902|2336462209533|
# |15393162791403|2336462209533|
# |15393162799448|2336462209533|
# |17592186051872|2336462209533|
# |19791209305864|2336462209533|
# |21990232563252|2336462209533|
# |21990232566466|2336462209533|
# |24189255815615|2336462209533|
# |24189255817581|2336462209533|
# |32985348841016|2336462209533|
# +--------------+-------------+
# only showing top 20 rows
#
# None
# [Stage 27:>                                                         (0 + 1) / 1]

# %%
spark.sql("SET spark.sql.yannakakis.countGroupInLeaves = false").show()

# %%
spark.sql("SET spark.sql.yannakakis.enabled = false").show()
spark.sql("SET spark.sql.yannakakis.enabled = true").show()

# %%
spark.sql("SET spark.sql.yannakakis.enabled = false").show()

# %%
spark.sql("SET spark.sql.yannakakis.enabled = true").show()
spark.sql("SET spark.sql.yannakakis.countGroupInLeaves = false").show()

# %%
spark.sql("SET spark.sql.cbo.enabled = true").show()

# %%
spark.sql("ANALYZE TABLE part COMPUTE STATISTICS;").show()

# %%
df = spark.sql("""select count(*) from patents p1, patents p2, patents p3 where p1.toNode = p2.fromNode AND p2.toNode = p3.fromNode""")
df.show()

df.explain(True)

# %%
df = spark.sql("""select avg(i_current_price) from item, inventory where i_item_sk = inv_item_sk""")
df = spark.sql("""select avg(ss_quantity) from store_sales,store where s_store_sk = ss_store_sk""")
#df = spark.sql("""select avg(ss_list_price) from store_sales,store where s_store_sk = ss_store_sk""")
#df = spark.sql("""select count(isnull(ss_quantity)) from store_sales,store where s_store_sk = ss_store_sk""")
#df = spark.sql("""select count(isnull(i_current_price)) from item, inventory where i_item_sk = inv_item_sk""")
#df = spark.sql("""select sum(if (isnull(ss_quantity), 0, ss_quantity)) from store_sales,store where s_store_sk = ss_store_sk""")

df.show()

df.explain(True)

# %%
def run_query(file):
    with open(file, 'r') as f:
        query = '\n'.join(filter(lambda line: not line.startswith('limit') and not line.startswith('-'), f.readlines()))
        
        print("running query: \n" + query)
        return spark.sql(query)

# %%
df = spark.sql("""
SELECT ps_partkey, count(*) from part, partsupp
WHERE p_partkey = ps_partkey
GROUP BY ps_partkey
""")

df.show()

df.explain(True)

# %%
df = spark.sql("SELECT COUNT(p_size) / COUNT(DISTINCT p_size) FROM part")
df.show()
df = spark.sql("SELECT COUNT(p_retailprice) / COUNT(DISTINCT p_retailprice) FROM part")
df.show()

# %%
df_t1 = spark.createDataFrame([(1,1), (2,1), (2,2), (3,2), (3,3), (4,3), (4,3), (5,2), (5,1), (6,4)], schema=("a","b"))
df_t1.createOrReplaceTempView("t1")
df_t2 = spark.createDataFrame([(1,1), (2,1), (3,2), (3,2), (3,3), (3,3), (4,3), (4,2), (5,1), (6,4)], schema=("c","d"))
df_t2.createOrReplaceTempView("t2")
df_t3 = spark.createDataFrame([(1,1), (2,1), (3,2), (3,2), (3,3), (3,3), (4,3), (4,2), (5,1), (6,4)], schema=("e","f"))
df_t3.createOrReplaceTempView("t3")

query = "select median(a) from t1, t2 where b = c"
#query = "select percentile(a, 0.5, b) from t1, t2 where b = c"
#query = "select median(a) from t1 where EXISTS (SELECT 1 FROM t2 WHERE b = c)"
#query = "select count(*) from t1, t2 where b = c"
#query = "select *a from t1 where EXISTS (SELECT 1 FROM t2 WHERE b = c)"

spark.sql("SET spark.sql.yannakakis.enabled = false").show()

df = spark.sql(query)
df.show()

spark.sql("SET spark.sql.yannakakis.enabled = true").show()

df = spark.sql(query)
df.show()

# %%
spark.conf.set("spark.sql.legacy.setCommandRejectsSparkCoreConfs","false")
#spark.conf.set("spark.executor.cores", "6")
#spark.conf.set("spark.executor.instances", "6")
spark.conf.set("spark.sql.shuffle.partitions", "6")

# %%
import pandas as pd
import time

def benchmark(query):    
    spark.sql("SET spark.sql.yannakakis.enabled = true").show()

    start_time = time.time()

    df1 = run_query(query)
    df1.show()
    #df1.explain(True)

    end_time = time.time()
    yannakakis_time = end_time - start_time

    spark.sql("SET spark.sql.yannakakis.enabled = false").show()

    start_time = time.time()

    df2 = run_query(query)
    df2.show()
    #df2.explain(True)

    end_time = time.time()
    ref_time = end_time - start_time
    
    #return [query, ref_time, yannakakis_time]
    return [query, ref_time, yannakakis_time]


queries = ['lsqb/sql/q1.sql', 'lsqb/sql/q3.sql', 'lsqb/sql/q4.sql']

results = [benchmark(q) for q in queries]

df = pd.DataFrame(results, columns = ['query', 'ref_time', 'yannakakis_time'])

print(df)

df.to_csv("results.csv")
    

#print(f'row count: {df1.count()} vs. {df2.count()}' )
    #print(f'time ref: {ref_time}\ntime yannakakis: {yannakakis_time}')
# Out:
# +--------------------+-----+
# |                 key|value|
# +--------------------+-----+
# |spark.sql.yannaka...| true|
# +--------------------+-----+
#
# running query:
# SELECT count(*)
#
# FROM Country
#
# JOIN City
#
#   ON City.isPartOf_CountryId = Country.CountryId
#
# JOIN Person
#
#   ON Person.isLocatedIn_CityId = City.CityId
#
# JOIN Forum_hasMember_Person
#
#   ON Forum_hasMember_Person.PersonId = Person.PersonId
#
# JOIN Forum
#
#   ON Forum.ForumId = Forum_hasMember_Person.ForumId
#
# JOIN Post
#
#   ON Post.Forum_containerOfId = Forum.ForumId
#
# JOIN Comment
#
#   ON Comment.replyOf_PostId = Post.PostId
#
# JOIN Comment_hasTag_Tag
#
#   ON Comment_hasTag_Tag.CommentId = Comment.CommentId
#
# JOIN Tag
#
#   ON Tag.TagId = Comment_hasTag_Tag.TagId
#
# JOIN TagClass
#
#   ON Tag.hasType_TagClassId = TagClass.TagClassId;
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: applying yannakakis rewriting to join: Aggregate [toprettystring(count(1), Some(Etc/UTC)) AS toprettystring(count(1))#416]
# +- Project
#    +- Join Inner, (hasType_TagClassId#84L = TagClassId#96L)
#       :- Project [hastype_tagclassid#84L]
#       :  +- Join Inner, (TagId#83L = TagId#192L)
#       :     :- Project [tagid#192L]
#       :     :  +- Join Inner, (CommentId#191L = CommentId#122L)
#       :     :     :- Project [commentid#122L]
#       :     :     :  +- Join Inner, (replyOf_PostId#125L = PostId#153L)
#       :     :     :     :- Project [postid#153L]
#       :     :     :     :  +- Join Inner, (Forum_containerOfId#155L = ForumId#109L)
#       :     :     :     :     :- Project [forumid#109L]
#       :     :     :     :     :  +- Join Inner, (ForumId#109L = ForumId#217L)
#       :     :     :     :     :     :- Project [forumid#217L]
#       :     :     :     :     :     :  +- Join Inner, (PersonId#218L = PersonId#178L)
#       :     :     :     :     :     :     :- Project [personid#178L]
#       :     :     :     :     :     :     :  +- Join Inner, (isLocatedIn_CityId#179L = CityId#70L)
#       :     :     :     :     :     :     :     :- Project [cityid#70L]
#       :     :     :     :     :     :     :     :  +- Join Inner, (isPartOf_CountryId#71L = CountryId#57L)
#       :     :     :     :     :     :     :     :     :- Project [countryid#57L]
#       :     :     :     :     :     :     :     :     :  +- Filter isnotnull(CountryId#57L)
#       :     :     :     :     :     :     :     :     :     +- Relation [countryid#57L,ispartof_continentid#58L] JDBCRelation(country) [numPartitions=1]
#       :     :     :     :     :     :     :     :     +- Filter (isnotnull(isPartOf_CountryId#71L) AND isnotnull(CityId#70L))
#       :     :     :     :     :     :     :     :        +- Relation [cityid#70L,ispartof_countryid#71L] JDBCRelation(city) [numPartitions=1]
#       :     :     :     :     :     :     :     +- Filter (isnotnull(isLocatedIn_CityId#179L) AND isnotnull(PersonId#178L))
#       :     :     :     :     :     :     :        +- Relation [personid#178L,islocatedin_cityid#179L] JDBCRelation(person) [numPartitions=1]
#       :     :     :     :     :     :     +- Filter (isnotnull(PersonId#218L) AND isnotnull(ForumId#217L))
#       :     :     :     :     :     :        +- Relation [forumid#217L,personid#218L] JDBCRelation(forum_hasmember_person) [numPartitions=1]
#       :     :     :     :     :     +- Project [forumid#109L]
#       :     :     :     :     :        +- Filter isnotnull(ForumId#109L)
#       :     :     :     :     :           +- Relation [forumid#109L,hasmoderator_personid#110L] JDBCRelation(forum) [numPartitions=1]
#       :     :     :     :     +- Project [postid#153L, forum_containerofid#155L]
#       :     :     :     :        +- Filter (isnotnull(Forum_containerOfId#155L) AND isnotnull(PostId#153L))
#       :     :     :     :           +- Relation [postid#153L,hascreator_personid#154L,forum_containerofid#155L,islocatedin_countryid#156L] JDBCRelation(post) [numPartitions=1]
#       :     :     :     +- Project [commentid#122L, replyof_postid#125L]
#       :     :     :        +- Filter (isnotnull(replyOf_PostId#125L) AND isnotnull(CommentId#122L))
#       :     :     :           +- Relation [commentid#122L,hascreator_personid#123L,islocatedin_countryid#124L,replyof_postid#125L,replyof_commentid#126L] JDBCRelation(comment) [numPartitions=1]
#       :     :     +- Filter (isnotnull(CommentId#191L) AND isnotnull(TagId#192L))
#       :     :        +- Relation [commentid#191L,tagid#192L] JDBCRelation(comment_hastag_tag) [numPartitions=1]
#       :     +- Filter (isnotnull(TagId#83L) AND isnotnull(hasType_TagClassId#84L))
#       :        +- Relation [tagid#83L,hastype_tagclassid#84L] JDBCRelation(tag) [numPartitions=1]
#       +- Project [tagclassid#96L]
#          +- Filter isnotnull(TagClassId#96L)
#             +- Relation [tagclassid#96L,issubclassof_tagclassid#97L] JDBCRelation(tagclass) [numPartitions=1]
#
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: agg(project(join))
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: items: List(Project [countryid#57L]
# +- Filter isnotnull(CountryId#57L)
#    +- Relation [countryid#57L,ispartof_continentid#58L] JDBCRelation(country) [numPartitions=1]
# , Filter (isnotnull(isPartOf_CountryId#71L) AND isnotnull(CityId#70L))
# +- Relation [cityid#70L,ispartof_countryid#71L] JDBCRelation(city) [numPartitions=1]
# , Filter (isnotnull(isLocatedIn_CityId#179L) AND isnotnull(PersonId#178L))
# +- Relation [personid#178L,islocatedin_cityid#179L] JDBCRelation(person) [numPartitions=1]
# , Filter (isnotnull(PersonId#218L) AND isnotnull(ForumId#217L))
# +- Relation [forumid#217L,personid#218L] JDBCRelation(forum_hasmember_person) [numPartitions=1]
# , Project [forumid#109L]
# +- Filter isnotnull(ForumId#109L)
#    +- Relation [forumid#109L,hasmoderator_personid#110L] JDBCRelation(forum) [numPartitions=1]
# , Project [postid#153L, forum_containerofid#155L]
# +- Filter (isnotnull(Forum_containerOfId#155L) AND isnotnull(PostId#153L))
#    +- Relation [postid#153L,hascreator_personid#154L,forum_containerofid#155L,islocatedin_countryid#156L] JDBCRelation(post) [numPartitions=1]
# , Project [commentid#122L, replyof_postid#125L]
# +- Filter (isnotnull(replyOf_PostId#125L) AND isnotnull(CommentId#122L))
#    +- Relation [commentid#122L,hascreator_personid#123L,islocatedin_countryid#124L,replyof_postid#125L,replyof_commentid#126L] JDBCRelation(comment) [numPartitions=1]
# , Filter (isnotnull(CommentId#191L) AND isnotnull(TagId#192L))
# +- Relation [commentid#191L,tagid#192L] JDBCRelation(comment_hastag_tag) [numPartitions=1]
# , Filter (isnotnull(TagId#83L) AND isnotnull(hasType_TagClassId#84L))
# +- Relation [tagid#83L,hastype_tagclassid#84L] JDBCRelation(tag) [numPartitions=1]
# , Project [tagclassid#96L]
# +- Filter isnotnull(TagClassId#96L)
#    +- Relation [tagclassid#96L,issubclassof_tagclassid#97L] JDBCRelation(tagclass) [numPartitions=1]
# )
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: conditions: Set((isPartOf_CountryId#71L = CountryId#57L), (isLocatedIn_CityId#179L = CityId#70L), (PersonId#218L = PersonId#178L), (ForumId#109L = ForumId#217L), (Forum_containerOfId#155L = ForumId#109L), (replyOf_PostId#125L = PostId#153L), (CommentId#191L = CommentId#122L), (TagId#83L = TagId#192L), (hasType_TagClassId#84L = TagClassId#96L))
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: agg: toprettystring(count(1), Some(Etc/UTC)) AS toprettystring(count(1))#416
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is 0MA: false
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is counting: true
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is sum: false
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is non-agg: false
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: aggregate attributes: {}
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: groupingExpressions: List()
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: group attributes: {}
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: counting aggregates: List(toprettystring(count(1), Some(Etc/UTC)) AS toprettystring(count(1))#416)
# 23/10/24 12:48:44 WARN Hypergraph: equivalence classes: Set(Set(isPartOf_CountryId#71L, CountryId#57L), Set(replyOf_PostId#125L, PostId#153L), Set(CommentId#191L, CommentId#122L), Set(TagId#83L, TagId#192L), Set(hasType_TagClassId#84L, TagClassId#96L), Set(Forum_containerOfId#155L, ForumId#109L, ForumId#217L), Set(PersonId#218L, PersonId#178L), Set(isLocatedIn_CityId#179L, CityId#70L))
# 23/10/24 12:48:44 WARN Hypergraph: vertex to attribute mapping: Map(PersonId#218L -> Set(PersonId#218L, PersonId#178L), Forum_containerOfId#155L -> Set(Forum_containerOfId#155L, ForumId#109L, ForumId#217L), replyOf_PostId#125L -> Set(replyOf_PostId#125L, PostId#153L), isPartOf_CountryId#71L -> Set(isPartOf_CountryId#71L, CountryId#57L), isLocatedIn_CityId#179L -> Set(isLocatedIn_CityId#179L, CityId#70L), CommentId#191L -> Set(CommentId#191L, CommentId#122L), hasType_TagClassId#84L -> Set(hasType_TagClassId#84L, TagClassId#96L), TagId#83L -> Set(TagId#83L, TagId#192L))
# 23/10/24 12:48:44 WARN Hypergraph: attribute to vertex mapping: Map(ExprId(218,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> PersonId#218L, ExprId(191,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> CommentId#191L, ExprId(83,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> TagId#83L, ExprId(155,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> Forum_containerOfId#155L, ExprId(122,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> CommentId#191L, ExprId(125,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> replyOf_PostId#125L, ExprId(71,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> isPartOf_CountryId#71L, ExprId(178,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> PersonId#218L, ExprId(109,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> Forum_containerOfId#155L, ExprId(217,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> Forum_containerOfId#155L, ExprId(70,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> isLocatedIn_CityId#179L, ExprId(192,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> TagId#83L, ExprId(96,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> hasType_TagClassId#84L, ExprId(153,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> replyOf_PostId#125L, ExprId(57,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> isPartOf_CountryId#71L, ExprId(84,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> hasType_TagClassId#84L, ExprId(179,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> isLocatedIn_CityId#179L)
# 23/10/24 12:48:44 WARN Hypergraph: join item: Project [countryid#57L]
# +- Filter isnotnull(CountryId#57L)
#    +- Relation [countryid#57L,ispartof_continentid#58L] JDBCRelation(country) [numPartitions=1]
#
# 23/10/24 12:48:44 WARN Hypergraph: join item: Filter (isnotnull(isPartOf_CountryId#71L) AND isnotnull(CityId#70L))
# +- Relation [cityid#70L,ispartof_countryid#71L] JDBCRelation(city) [numPartitions=1]
#
# 23/10/24 12:48:44 WARN Hypergraph: join item: Filter (isnotnull(isLocatedIn_CityId#179L) AND isnotnull(PersonId#178L))
# +- Relation [personid#178L,islocatedin_cityid#179L] JDBCRelation(person) [numPartitions=1]
#
# 23/10/24 12:48:44 WARN Hypergraph: join item: Filter (isnotnull(PersonId#218L) AND isnotnull(ForumId#217L))
# +- Relation [forumid#217L,personid#218L] JDBCRelation(forum_hasmember_person) [numPartitions=1]
#
# 23/10/24 12:48:44 WARN Hypergraph: join item: Project [forumid#109L]
# +- Filter isnotnull(ForumId#109L)
#    +- Relation [forumid#109L,hasmoderator_personid#110L] JDBCRelation(forum) [numPartitions=1]
#
# 23/10/24 12:48:44 WARN Hypergraph: join item: Project [postid#153L, forum_containerofid#155L]
# +- Filter (isnotnull(Forum_containerOfId#155L) AND isnotnull(PostId#153L))
#    +- Relation [postid#153L,hascreator_personid#154L,forum_containerofid#155L,islocatedin_countryid#156L] JDBCRelation(post) [numPartitions=1]
#
# 23/10/24 12:48:44 WARN Hypergraph: join item: Project [commentid#122L, replyof_postid#125L]
# +- Filter (isnotnull(replyOf_PostId#125L) AND isnotnull(CommentId#122L))
#    +- Relation [commentid#122L,hascreator_personid#123L,islocatedin_countryid#124L,replyof_postid#125L,replyof_commentid#126L] JDBCRelation(comment) [numPartitions=1]
#
# 23/10/24 12:48:44 WARN Hypergraph: join item: Filter (isnotnull(CommentId#191L) AND isnotnull(TagId#192L))
# +- Relation [commentid#191L,tagid#192L] JDBCRelation(comment_hastag_tag) [numPartitions=1]
#
# 23/10/24 12:48:44 WARN Hypergraph: join item: Filter (isnotnull(TagId#83L) AND isnotnull(hasType_TagClassId#84L))
# +- Relation [tagid#83L,hastype_tagclassid#84L] JDBCRelation(tag) [numPartitions=1]
#
# 23/10/24 12:48:44 WARN Hypergraph: join item: Project [tagclassid#96L]
# +- Filter isnotnull(TagClassId#96L)
#    +- Relation [tagclassid#96L,issubclassof_tagclassid#97L] JDBCRelation(tagclass) [numPartitions=1]
#
# 23/10/24 12:48:44 WARN Hypergraph: hyperedges: Set(E7(CommentId#191L, replyOf_PostId#125L), E5(Forum_containerOfId#155L), E1(isPartOf_CountryId#71L), E3(PersonId#218L, isLocatedIn_CityId#179L), E10(hasType_TagClassId#84L), E9(TagId#83L, hasType_TagClassId#84L), E8(CommentId#191L, TagId#83L), E4(Forum_containerOfId#155L, PersonId#218L), E2(isLocatedIn_CityId#179L, isPartOf_CountryId#71L), E6(replyOf_PostId#125L, Forum_containerOfId#155L))
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E6(replyOf_PostId#125L, Forum_containerOfId#155L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: parentNode: TreeNode(Set(E6(replyOf_PostId#125L, Forum_containerOfId#155L)))[Set({postid#153L, forum_containerofid#155L})] [[parent: false]]
#
# 23/10/24 12:48:44 WARN Hypergraph: subsets: Set(TreeNode(Set(E5(Forum_containerOfId#155L)))[Set({forumid#109L})] [[parent: false]]
# )
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E7(CommentId#191L, replyOf_PostId#125L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: parentNode: TreeNode(Set(E7(CommentId#191L, replyOf_PostId#125L)))[Set({commentid#122L, replyof_postid#125L})] [[parent: false]]
#
# 23/10/24 12:48:44 WARN Hypergraph: subsets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E1(isPartOf_CountryId#71L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set(E2(isLocatedIn_CityId#179L, isPartOf_CountryId#71L))
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E9(TagId#83L, hasType_TagClassId#84L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: parentNode: TreeNode(Set(E9(TagId#83L, hasType_TagClassId#84L)))[Set({tagid#83L, hastype_tagclassid#84L})] [[parent: false]]
#
# 23/10/24 12:48:44 WARN Hypergraph: subsets: Set(TreeNode(Set(E10(hasType_TagClassId#84L)))[Set({tagclassid#96L})] [[parent: false]]
# )
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E3(PersonId#218L, isLocatedIn_CityId#179L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: parentNode: TreeNode(Set(E3(PersonId#218L, isLocatedIn_CityId#179L)))[Set({personid#178L, islocatedin_cityid#179L})] [[parent: false]]
#
# 23/10/24 12:48:44 WARN Hypergraph: subsets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E4(Forum_containerOfId#155L, PersonId#218L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: parentNode: TreeNode(Set(E4(Forum_containerOfId#155L, PersonId#218L)))[Set({forumid#217L, personid#218L})] [[parent: false]]
#
# 23/10/24 12:48:44 WARN Hypergraph: subsets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E2(isLocatedIn_CityId#179L, isPartOf_CountryId#71L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: parentNode: TreeNode(Set(E2(isLocatedIn_CityId#179L, isPartOf_CountryId#71L)))[Set({cityid#70L, ispartof_countryid#71L})] [[parent: false]]
#
# 23/10/24 12:48:44 WARN Hypergraph: subsets: Set(TreeNode(Set(E1(isPartOf_CountryId#71L)))[Set({countryid#57L})] [[parent: false]]
# )
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E8(CommentId#191L, TagId#83L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: parentNode: TreeNode(Set(E8(CommentId#191L, TagId#83L)))[Set({commentid#191L, tagid#192L})] [[parent: false]]
#
# 23/10/24 12:48:44 WARN Hypergraph: subsets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E3(PersonId#218L, isLocatedIn_CityId#179L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: parentNode: TreeNode(Set(E3(PersonId#218L, isLocatedIn_CityId#179L)))[Set({personid#178L, islocatedin_cityid#179L})] [[parent: false]]
#
# 23/10/24 12:48:44 WARN Hypergraph: subsets: Set(TreeNode(Set(E2(isLocatedIn_CityId#179L, isPartOf_CountryId#71L)))[Set({cityid#70L, ispartof_countryid#71L})] [[parent: false]]
# -- TreeNode(Set(E1(isPartOf_CountryId#71L)))[Set({countryid#57L})] [[parent: true]]
# )
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E6(replyOf_PostId#125L, Forum_containerOfId#155L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: parentNode: TreeNode(Set(E6(replyOf_PostId#125L, Forum_containerOfId#155L)))[Set({postid#153L, forum_containerofid#155L})] [[parent: false]]
# -- TreeNode(Set(E5(Forum_containerOfId#155L)))[Set({forumid#109L})] [[parent: true]]
#
# 23/10/24 12:48:44 WARN Hypergraph: subsets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E4(Forum_containerOfId#155L, PersonId#218L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: parentNode: TreeNode(Set(E4(Forum_containerOfId#155L, PersonId#218L)))[Set({forumid#217L, personid#218L})] [[parent: false]]
#
# 23/10/24 12:48:44 WARN Hypergraph: subsets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E8(CommentId#191L, TagId#83L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: parentNode: TreeNode(Set(E8(CommentId#191L, TagId#83L)))[Set({commentid#191L, tagid#192L})] [[parent: false]]
#
# 23/10/24 12:48:44 WARN Hypergraph: subsets: Set(TreeNode(Set(E9(TagId#83L, hasType_TagClassId#84L)))[Set({tagid#83L, hastype_tagclassid#84L})] [[parent: false]]
# -- TreeNode(Set(E10(hasType_TagClassId#84L)))[Set({tagclassid#96L})] [[parent: true]]
# )
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E7(CommentId#191L, replyOf_PostId#125L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: parentNode: TreeNode(Set(E7(CommentId#191L, replyOf_PostId#125L)))[Set({commentid#122L, replyof_postid#125L})] [[parent: false]]
#
# 23/10/24 12:48:44 WARN Hypergraph: subsets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E7(CommentId#191L, replyOf_PostId#125L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: parentNode: TreeNode(Set(E7(CommentId#191L, replyOf_PostId#125L)))[Set({commentid#122L, replyof_postid#125L})] [[parent: false]]
#
# 23/10/24 12:48:44 WARN Hypergraph: subsets: Set(TreeNode(Set(E8(CommentId#191L, TagId#83L)))[Set({commentid#191L, tagid#192L})] [[parent: false]]
# -- TreeNode(Set(E9(TagId#83L, hasType_TagClassId#84L)))[Set({tagid#83L, hastype_tagclassid#84L})] [[parent: true]]
# -- -- TreeNode(Set(E10(hasType_TagClassId#84L)))[Set({tagclassid#96L})] [[parent: true]]
# )
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E3(PersonId#218L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set(E4(Forum_containerOfId#155L, PersonId#218L))
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E6(replyOf_PostId#125L, Forum_containerOfId#155L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: parentNode: TreeNode(Set(E6(replyOf_PostId#125L, Forum_containerOfId#155L)))[Set({postid#153L, forum_containerofid#155L})] [[parent: false]]
# -- TreeNode(Set(E5(Forum_containerOfId#155L)))[Set({forumid#109L})] [[parent: true]]
#
# 23/10/24 12:48:44 WARN Hypergraph: subsets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E4(Forum_containerOfId#155L, PersonId#218L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: parentNode: TreeNode(Set(E4(Forum_containerOfId#155L, PersonId#218L)))[Set({forumid#217L, personid#218L})] [[parent: false]]
#
# 23/10/24 12:48:44 WARN Hypergraph: subsets: Set(TreeNode(Set(E3(PersonId#218L, isLocatedIn_CityId#179L)))[Set({personid#178L, islocatedin_cityid#179L})] [[parent: false]]
# -- TreeNode(Set(E2(isLocatedIn_CityId#179L, isPartOf_CountryId#71L)))[Set({cityid#70L, ispartof_countryid#71L})] [[parent: true]]
# -- -- TreeNode(Set(E1(isPartOf_CountryId#71L)))[Set({countryid#57L})] [[parent: true]]
# )
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E7(replyOf_PostId#125L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set(E6(replyOf_PostId#125L, Forum_containerOfId#155L))
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E4(Forum_containerOfId#155L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set(E6(replyOf_PostId#125L, Forum_containerOfId#155L))
# 23/10/24 12:48:44 WARN Hypergraph: gyo edge: E6(replyOf_PostId#125L, Forum_containerOfId#155L)
# 23/10/24 12:48:44 WARN Hypergraph: supersets: Set()
# 23/10/24 12:48:44 WARN Hypergraph: parentNode: TreeNode(Set(E6(replyOf_PostId#125L, Forum_containerOfId#155L)))[Set({postid#153L, forum_containerofid#155L})] [[parent: false]]
# -- TreeNode(Set(E5(Forum_containerOfId#155L)))[Set({forumid#109L})] [[parent: true]]
#
# 23/10/24 12:48:44 WARN Hypergraph: subsets: Set(TreeNode(Set(E7(CommentId#191L, replyOf_PostId#125L)))[Set({commentid#122L, replyof_postid#125L})] [[parent: false]]
# -- TreeNode(Set(E8(CommentId#191L, TagId#83L)))[Set({commentid#191L, tagid#192L})] [[parent: true]]
# -- -- TreeNode(Set(E9(TagId#83L, hasType_TagClassId#84L)))[Set({tagid#83L, hastype_tagclassid#84L})] [[parent: true]]
# -- -- -- TreeNode(Set(E10(hasType_TagClassId#84L)))[Set({tagclassid#96L})] [[parent: true]]
# , TreeNode(Set(E4(Forum_containerOfId#155L, PersonId#218L)))[Set({forumid#217L, personid#218L})] [[parent: false]]
# -- TreeNode(Set(E3(PersonId#218L, isLocatedIn_CityId#179L)))[Set({personid#178L, islocatedin_cityid#179L})] [[parent: true]]
# -- -- TreeNode(Set(E2(isLocatedIn_CityId#179L, isPartOf_CountryId#71L)))[Set({cityid#70L, ispartof_countryid#71L})] [[parent: true]]
# -- -- -- TreeNode(Set(E1(isPartOf_CountryId#71L)))[Set({countryid#57L})] [[parent: true]]
# )
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: join tree:
# TreeNode(Set(E6(replyOf_PostId#125L, Forum_containerOfId#155L)))[Set({postid#153L, forum_containerofid#155L})] [[parent: false]]
# -- TreeNode(Set(E5(Forum_containerOfId#155L)))[Set({forumid#109L})] [[parent: true]]
#
# -- TreeNode(Set(E7(CommentId#191L, replyOf_PostId#125L)))[Set({commentid#122L, replyof_postid#125L})] [[parent: true]]
# -- -- TreeNode(Set(E8(CommentId#191L, TagId#83L)))[Set({commentid#191L, tagid#192L})] [[parent: true]]
# -- -- -- TreeNode(Set(E9(TagId#83L, hasType_TagClassId#84L)))[Set({tagid#83L, hastype_tagclassid#84L})] [[parent: true]]
# -- -- -- -- TreeNode(Set(E10(hasType_TagClassId#84L)))[Set({tagclassid#96L})] [[parent: true]]
#
# -- TreeNode(Set(E4(Forum_containerOfId#155L, PersonId#218L)))[Set({forumid#217L, personid#218L})] [[parent: true]]
# -- -- TreeNode(Set(E3(PersonId#218L, isLocatedIn_CityId#179L)))[Set({personid#178L, islocatedin_cityid#179L})] [[parent: true]]
# -- -- -- TreeNode(Set(E2(isLocatedIn_CityId#179L, isPartOf_CountryId#71L)))[Set({cityid#70L, ispartof_countryid#71L})] [[parent: true]]
# -- -- -- -- TreeNode(Set(E1(isPartOf_CountryId#71L)))[Set({countryid#57L})] [[parent: true]]
#
# 23/10/24 12:48:44 WARN HTNode: aggAttributes: {}
# 23/10/24 12:48:44 WARN HTNode: nodeAttributes: {postid#153L, forum_containerofid#155L}
# 23/10/24 12:48:44 WARN HTNode: found subset in:
# TreeNode(Set(E6(replyOf_PostId#125L, Forum_containerOfId#155L)))[Set({postid#153L, forum_containerofid#155L})] [[parent: false]]
# -- TreeNode(Set(E5(Forum_containerOfId#155L)))[Set({forumid#109L})] [[parent: true]]
#
# -- TreeNode(Set(E7(CommentId#191L, replyOf_PostId#125L)))[Set({commentid#122L, replyof_postid#125L})] [[parent: true]]
# -- -- TreeNode(Set(E8(CommentId#191L, TagId#83L)))[Set({commentid#191L, tagid#192L})] [[parent: true]]
# -- -- -- TreeNode(Set(E9(TagId#83L, hasType_TagClassId#84L)))[Set({tagid#83L, hastype_tagclassid#84L})] [[parent: true]]
# -- -- -- -- TreeNode(Set(E10(hasType_TagClassId#84L)))[Set({tagclassid#96L})] [[parent: true]]
#
# -- TreeNode(Set(E4(Forum_containerOfId#155L, PersonId#218L)))[Set({forumid#217L, personid#218L})] [[parent: true]]
# -- -- TreeNode(Set(E3(PersonId#218L, isLocatedIn_CityId#179L)))[Set({personid#178L, islocatedin_cityid#179L})] [[parent: true]]
# -- -- -- TreeNode(Set(E2(isLocatedIn_CityId#179L, isPartOf_CountryId#71L)))[Set({cityid#70L, ispartof_countryid#71L})] [[parent: true]]
# -- -- -- -- TreeNode(Set(E1(isPartOf_CountryId#71L)))[Set({countryid#57L})] [[parent: true]]
#
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: rerooted:
# TreeNode(Set(E6(replyOf_PostId#125L, Forum_containerOfId#155L)))[Set({postid#153L, forum_containerofid#155L})] [[parent: false]]
# -- TreeNode(Set(E5(Forum_containerOfId#155L)))[Set({forumid#109L})] [[parent: true]]
#
# -- TreeNode(Set(E7(CommentId#191L, replyOf_PostId#125L)))[Set({commentid#122L, replyof_postid#125L})] [[parent: true]]
# -- -- TreeNode(Set(E8(CommentId#191L, TagId#83L)))[Set({commentid#191L, tagid#192L})] [[parent: true]]
# -- -- -- TreeNode(Set(E9(TagId#83L, hasType_TagClassId#84L)))[Set({tagid#83L, hastype_tagclassid#84L})] [[parent: true]]
# -- -- -- -- TreeNode(Set(E10(hasType_TagClassId#84L)))[Set({tagclassid#96L})] [[parent: true]]
#
# -- TreeNode(Set(E4(Forum_containerOfId#155L, PersonId#218L)))[Set({forumid#217L, personid#218L})] [[parent: true]]
# -- -- TreeNode(Set(E3(PersonId#218L, isLocatedIn_CityId#179L)))[Set({personid#178L, islocatedin_cityid#179L})] [[parent: true]]
# -- -- -- TreeNode(Set(E2(isLocatedIn_CityId#179L, isPartOf_CountryId#71L)))[Set({cityid#70L, ispartof_countryid#71L})] [[parent: true]]
# -- -- -- -- TreeNode(Set(E1(isPartOf_CountryId#71L)))[Set({countryid#57L})] [[parent: true]]
#
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: star counting aggregates: List(toprettystring(count(1), Some(Etc/UTC)) AS toprettystring(count(1))#416)
# 23/10/24 12:48:44 WARN HTNode: keyRefs: List()
# 23/10/24 12:48:44 WARN HTNode: edge: E6(replyOf_PostId#125L, Forum_containerOfId#155L)
# 23/10/24 12:48:44 WARN HTNode: overlapping vertices: Set((forum_containerofid#155L,forumid#109L))
# 23/10/24 12:48:44 WARN HTNode: can semi join: false
# 23/10/24 12:48:44 WARN HTNode: join output: List(postid#153L, forum_containerofid#155L, c#418L, forumid#109L, c#419L)
# 23/10/24 12:48:44 WARN HTNode: keyRefs: List()
# 23/10/24 12:48:44 WARN HTNode: edge: E9(TagId#83L, hasType_TagClassId#84L)
# 23/10/24 12:48:44 WARN HTNode: overlapping vertices: Set((hastype_tagclassid#84L,tagclassid#96L))
# 23/10/24 12:48:44 WARN HTNode: can semi join: false
# 23/10/24 12:48:44 WARN HTNode: join output: List(tagid#83L, hastype_tagclassid#84L, c#427L, tagclassid#96L, c#428L)
# 23/10/24 12:48:44 WARN HTNode: keyRefs: List()
# 23/10/24 12:48:44 WARN HTNode: edge: E8(CommentId#191L, TagId#83L)
# 23/10/24 12:48:44 WARN HTNode: overlapping vertices: Set((tagid#192L,tagid#83L))
# 23/10/24 12:48:44 WARN HTNode: can semi join: false
# 23/10/24 12:48:44 WARN HTNode: join output: List(commentid#191L, tagid#192L, c#426L, c#437L, tagid#83L)
# 23/10/24 12:48:44 WARN HTNode: keyRefs: List()
# 23/10/24 12:48:44 WARN HTNode: edge: E7(CommentId#191L, replyOf_PostId#125L)
# 23/10/24 12:48:44 WARN HTNode: overlapping vertices: Set((commentid#122L,commentid#191L))
# 23/10/24 12:48:44 WARN HTNode: can semi join: false
# 23/10/24 12:48:44 WARN HTNode: join output: List(commentid#122L, replyof_postid#125L, c#425L, c#442L, commentid#191L)
# 23/10/24 12:48:44 WARN HTNode: keyRefs: List()
# 23/10/24 12:48:44 WARN HTNode: edge: E6(replyOf_PostId#125L, Forum_containerOfId#155L)
# 23/10/24 12:48:44 WARN HTNode: overlapping vertices: Set((postid#153L,replyof_postid#125L))
# 23/10/24 12:48:44 WARN HTNode: can semi join: false
# 23/10/24 12:48:44 WARN HTNode: join output: List(c#445L, postid#153L, forum_containerofid#155L, c#447L, replyof_postid#125L)
# 23/10/24 12:48:44 WARN HTNode: keyRefs: List()
# 23/10/24 12:48:44 WARN HTNode: edge: E2(isLocatedIn_CityId#179L, isPartOf_CountryId#71L)
# 23/10/24 12:48:44 WARN HTNode: overlapping vertices: Set((ispartof_countryid#71L,countryid#57L))
# 23/10/24 12:48:44 WARN HTNode: can semi join: false
# 23/10/24 12:48:44 WARN HTNode: join output: List(cityid#70L, ispartof_countryid#71L, c#451L, countryid#57L, c#452L)
# 23/10/24 12:48:44 WARN HTNode: keyRefs: List()
# 23/10/24 12:48:44 WARN HTNode: edge: E3(PersonId#218L, isLocatedIn_CityId#179L)
# 23/10/24 12:48:44 WARN HTNode: overlapping vertices: Set((islocatedin_cityid#179L,cityid#70L))
# 23/10/24 12:48:44 WARN HTNode: can semi join: false
# 23/10/24 12:48:44 WARN HTNode: join output: List(personid#178L, islocatedin_cityid#179L, c#450L, c#461L, cityid#70L)
# 23/10/24 12:48:44 WARN HTNode: keyRefs: List()
# 23/10/24 12:48:44 WARN HTNode: edge: E4(Forum_containerOfId#155L, PersonId#218L)
# 23/10/24 12:48:44 WARN HTNode: overlapping vertices: Set((personid#218L,personid#178L))
# 23/10/24 12:48:44 WARN HTNode: can semi join: false
# 23/10/24 12:48:44 WARN HTNode: join output: List(forumid#217L, personid#218L, c#449L, c#466L, personid#178L)
# 23/10/24 12:48:44 WARN HTNode: keyRefs: List()
# 23/10/24 12:48:44 WARN HTNode: edge: E6(replyOf_PostId#125L, Forum_containerOfId#155L)
# 23/10/24 12:48:44 WARN HTNode: overlapping vertices: Set((forum_containerofid#155L,forumid#217L))
# 23/10/24 12:48:44 WARN HTNode: can semi join: false
# 23/10/24 12:48:44 WARN HTNode: join output: List(c#469L, postid#153L, forum_containerofid#155L, c#471L, forumid#217L)
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: new aggregate: Aggregate [toprettystring(sum(c#472L), Some(Etc/UTC)) AS toprettystring(count(1))#416]
# +- Project [c#472L]
#    +- Project [(cast(c#469L as bigint) * c#471L) AS c#472L, c#469L, postid#153L, forum_containerofid#155L, c#471L, forumid#217L]
#       +- Join Inner, (forum_containerofid#155L = cast(forumid#217L as bigint))
#          :- Aggregate [postid#153L, forum_containerofid#155L], [sum(c#448L) AS c#469L, postid#153L, forum_containerofid#155L]
#          :  +- Project [(cast(c#445L as bigint) * c#447L) AS c#448L, c#445L, postid#153L, forum_containerofid#155L, c#447L, replyof_postid#125L]
#          :     +- Join Inner, (postid#153L = cast(replyof_postid#125L as bigint))
#          :        :- Aggregate [postid#153L, forum_containerofid#155L], [sum(c#424L) AS c#445L, postid#153L, forum_containerofid#155L]
#          :        :  +- Project [(cast(c#418L as bigint) * c#419L) AS c#424L, postid#153L, forum_containerofid#155L, c#418L, forumid#109L, c#419L]
#          :        :     +- Join Inner, (forum_containerofid#155L = cast(forumid#109L as bigint))
#          :        :        :- Project [postid#153L, forum_containerofid#155L, 1 AS c#418L]
#          :        :        :  +- Project [postid#153L, forum_containerofid#155L]
#          :        :        :     +- Filter (isnotnull(Forum_containerOfId#155L) AND isnotnull(PostId#153L))
#          :        :        :        +- Relation [postid#153L,hascreator_personid#154L,forum_containerofid#155L,islocatedin_countryid#156L] JDBCRelation(post) [numPartitions=1]
#          :        :        +- Project [forumid#109L, 1 AS c#419L]
#          :        :           +- Project [forumid#109L]
#          :        :              +- Filter isnotnull(ForumId#109L)
#          :        :                 +- Relation [forumid#109L,hasmoderator_personid#110L] JDBCRelation(forum) [numPartitions=1]
#          :        +- Aggregate [replyof_postid#125L], [sum(c#443L) AS c#447L, replyof_postid#125L]
#          :           +- Project [(cast(c#425L as bigint) * c#442L) AS c#443L, commentid#122L, replyof_postid#125L, c#425L, c#442L, commentid#191L]
#          :              +- Join Inner, (commentid#122L = cast(commentid#191L as bigint))
#          :                 :- Project [commentid#122L, replyof_postid#125L, 1 AS c#425L]
#          :                 :  +- Project [commentid#122L, replyof_postid#125L]
#          :                 :     +- Filter (isnotnull(replyOf_PostId#125L) AND isnotnull(CommentId#122L))
#          :                 :        +- Relation [commentid#122L,hascreator_personid#123L,islocatedin_countryid#124L,replyof_postid#125L,replyof_commentid#126L] JDBCRelation(comment) [numPartitions=1]
#          :                 +- Aggregate [commentid#191L], [sum(c#438L) AS c#442L, commentid#191L]
#          :                    +- Project [(cast(c#426L as bigint) * c#437L) AS c#438L, commentid#191L, tagid#192L, c#426L, c#437L, tagid#83L]
#          :                       +- Join Inner, (tagid#192L = cast(tagid#83L as bigint))
#          :                          :- Project [commentid#191L, tagid#192L, 1 AS c#426L]
#          :                          :  +- Filter (isnotnull(CommentId#191L) AND isnotnull(TagId#192L))
#          :                          :     +- Relation [commentid#191L,tagid#192L] JDBCRelation(comment_hastag_tag) [numPartitions=1]
#          :                          +- Aggregate [tagid#83L], [sum(c#433L) AS c#437L, tagid#83L]
#          :                             +- Project [(cast(c#427L as bigint) * c#428L) AS c#433L, tagid#83L, hastype_tagclassid#84L, c#427L, tagclassid#96L, c#428L]
#          :                                +- Join Inner, (hastype_tagclassid#84L = cast(tagclassid#96L as bigint))
#          :                                   :- Project [tagid#83L, hastype_tagclassid#84L, 1 AS c#427L]
#          :                                   :  +- Filter (isnotnull(TagId#83L) AND isnotnull(hasType_TagClassId#84L))
#          :                                   :     +- Relation [tagid#83L,hastype_tagclassid#84L] JDBCRelation(tag) [numPartitions=1]
#          :                                   +- Project [tagclassid#96L, 1 AS c#428L]
#          :                                      +- Project [tagclassid#96L]
#          :                                         +- Filter isnotnull(TagClassId#96L)
#          :                                            +- Relation [tagclassid#96L,issubclassof_tagclassid#97L] JDBCRelation(tagclass) [numPartitions=1]
#          +- Aggregate [forumid#217L], [sum(c#467L) AS c#471L, forumid#217L]
#             +- Project [(cast(c#449L as bigint) * c#466L) AS c#467L, forumid#217L, personid#218L, c#449L, c#466L, personid#178L]
#                +- Join Inner, (personid#218L = cast(personid#178L as bigint))
#                   :- Project [forumid#217L, personid#218L, 1 AS c#449L]
#                   :  +- Filter (isnotnull(PersonId#218L) AND isnotnull(ForumId#217L))
#                   :     +- Relation [forumid#217L,personid#218L] JDBCRelation(forum_hasmember_person) [numPartitions=1]
#                   +- Aggregate [personid#178L], [sum(c#462L) AS c#466L, personid#178L]
#                      +- Project [(cast(c#450L as bigint) * c#461L) AS c#462L, personid#178L, islocatedin_cityid#179L, c#450L, c#461L, cityid#70L]
#                         +- Join Inner, (islocatedin_cityid#179L = cast(cityid#70L as bigint))
#                            :- Project [personid#178L, islocatedin_cityid#179L, 1 AS c#450L]
#                            :  +- Filter (isnotnull(isLocatedIn_CityId#179L) AND isnotnull(PersonId#178L))
#                            :     +- Relation [personid#178L,islocatedin_cityid#179L] JDBCRelation(person) [numPartitions=1]
#                            +- Aggregate [cityid#70L], [sum(c#457L) AS c#461L, cityid#70L]
#                               +- Project [(cast(c#451L as bigint) * c#452L) AS c#457L, cityid#70L, ispartof_countryid#71L, c#451L, countryid#57L, c#452L]
#                                  +- Join Inner, (ispartof_countryid#71L = cast(countryid#57L as bigint))
#                                     :- Project [cityid#70L, ispartof_countryid#71L, 1 AS c#451L]
#                                     :  +- Filter (isnotnull(isPartOf_CountryId#71L) AND isnotnull(CityId#70L))
#                                     :     +- Relation [cityid#70L,ispartof_countryid#71L] JDBCRelation(city) [numPartitions=1]
#                                     +- Project [countryid#57L, 1 AS c#452L]
#                                        +- Project [countryid#57L]
#                                           +- Filter isnotnull(CountryId#57L)
#                                              +- Relation [countryid#57L,ispartof_continentid#58L] JDBCRelation(country) [numPartitions=1]
#
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: applying yannakakis rewriting to join: Aggregate [postid#153L, forum_containerofid#155L], [sum(c#448L) AS c#469L, postid#153L, forum_containerofid#155L]
# +- Project [(cast(c#445L as bigint) * c#447L) AS c#448L, c#445L, postid#153L, forum_containerofid#155L, c#447L, replyof_postid#125L]
#    +- Join Inner, (postid#153L = cast(replyof_postid#125L as bigint))
#       :- Aggregate [postid#153L, forum_containerofid#155L], [sum(c#424L) AS c#445L, postid#153L, forum_containerofid#155L]
#       :  +- Project [(cast(c#418L as bigint) * c#419L) AS c#424L, postid#153L, forum_containerofid#155L, c#418L, forumid#109L, c#419L]
#       :     +- Join Inner, (forum_containerofid#155L = cast(forumid#109L as bigint))
#       :        :- Project [postid#153L, forum_containerofid#155L, 1 AS c#418L]
#       :        :  +- Project [postid#153L, forum_containerofid#155L]
#       :        :     +- Filter (isnotnull(Forum_containerOfId#155L) AND isnotnull(PostId#153L))
#       :        :        +- Relation [postid#153L,hascreator_personid#154L,forum_containerofid#155L,islocatedin_countryid#156L] JDBCRelation(post) [numPartitions=1]
#       :        +- Project [forumid#109L, 1 AS c#419L]
#       :           +- Project [forumid#109L]
#       :              +- Filter isnotnull(ForumId#109L)
#       :                 +- Relation [forumid#109L,hasmoderator_personid#110L] JDBCRelation(forum) [numPartitions=1]
#       +- Aggregate [replyof_postid#125L], [sum(c#443L) AS c#447L, replyof_postid#125L]
#          +- Project [(cast(c#425L as bigint) * c#442L) AS c#443L, commentid#122L, replyof_postid#125L, c#425L, c#442L, commentid#191L]
#             +- Join Inner, (commentid#122L = cast(commentid#191L as bigint))
#                :- Project [commentid#122L, replyof_postid#125L, 1 AS c#425L]
#                :  +- Project [commentid#122L, replyof_postid#125L]
#                :     +- Filter (isnotnull(replyOf_PostId#125L) AND isnotnull(CommentId#122L))
#                :        +- Relation [commentid#122L,hascreator_personid#123L,islocatedin_countryid#124L,replyof_postid#125L,replyof_commentid#126L] JDBCRelation(comment) [numPartitions=1]
#                +- Aggregate [commentid#191L], [sum(c#438L) AS c#442L, commentid#191L]
#                   +- Project [(cast(c#426L as bigint) * c#437L) AS c#438L, commentid#191L, tagid#192L, c#426L, c#437L, tagid#83L]
#                      +- Join Inner, (tagid#192L = cast(tagid#83L as bigint))
#                         :- Project [commentid#191L, tagid#192L, 1 AS c#426L]
#                         :  +- Filter (isnotnull(CommentId#191L) AND isnotnull(TagId#192L))
#                         :     +- Relation [commentid#191L,tagid#192L] JDBCRelation(comment_hastag_tag) [numPartitions=1]
#                         +- Aggregate [tagid#83L], [sum(c#433L) AS c#437L, tagid#83L]
#                            +- Project [(cast(c#427L as bigint) * c#428L) AS c#433L, tagid#83L, hastype_tagclassid#84L, c#427L, tagclassid#96L, c#428L]
#                               +- Join Inner, (hastype_tagclassid#84L = cast(tagclassid#96L as bigint))
#                                  :- Project [tagid#83L, hastype_tagclassid#84L, 1 AS c#427L]
#                                  :  +- Filter (isnotnull(TagId#83L) AND isnotnull(hasType_TagClassId#84L))
#                                  :     +- Relation [tagid#83L,hastype_tagclassid#84L] JDBCRelation(tag) [numPartitions=1]
#                                  +- Project [tagclassid#96L, 1 AS c#428L]
#                                     +- Project [tagclassid#96L]
#                                        +- Filter isnotnull(TagClassId#96L)
#                                           +- Relation [tagclassid#96L,issubclassof_tagclassid#97L] JDBCRelation(tagclass) [numPartitions=1]
#
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: agg(project(join))
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: items: List(Aggregate [postid#153L, forum_containerofid#155L], [sum(c#424L) AS c#445L, postid#153L, forum_containerofid#155L]
# +- Project [(cast(c#418L as bigint) * c#419L) AS c#424L, postid#153L, forum_containerofid#155L, c#418L, forumid#109L, c#419L]
#    +- Join Inner, (forum_containerofid#155L = cast(forumid#109L as bigint))
#       :- Project [postid#153L, forum_containerofid#155L, 1 AS c#418L]
#       :  +- Project [postid#153L, forum_containerofid#155L]
#       :     +- Filter (isnotnull(Forum_containerOfId#155L) AND isnotnull(PostId#153L))
#       :        +- Relation [postid#153L,hascreator_personid#154L,forum_containerofid#155L,islocatedin_countryid#156L] JDBCRelation(post) [numPartitions=1]
#       +- Project [forumid#109L, 1 AS c#419L]
#          +- Project [forumid#109L]
#             +- Filter isnotnull(ForumId#109L)
#                +- Relation [forumid#109L,hasmoderator_personid#110L] JDBCRelation(forum) [numPartitions=1]
# , Aggregate [replyof_postid#125L], [sum(c#443L) AS c#447L, replyof_postid#125L]
# +- Project [(cast(c#425L as bigint) * c#442L) AS c#443L, commentid#122L, replyof_postid#125L, c#425L, c#442L, commentid#191L]
#    +- Join Inner, (commentid#122L = cast(commentid#191L as bigint))
#       :- Project [commentid#122L, replyof_postid#125L, 1 AS c#425L]
#       :  +- Project [commentid#122L, replyof_postid#125L]
#       :     +- Filter (isnotnull(replyOf_PostId#125L) AND isnotnull(CommentId#122L))
#       :        +- Relation [commentid#122L,hascreator_personid#123L,islocatedin_countryid#124L,replyof_postid#125L,replyof_commentid#126L] JDBCRelation(comment) [numPartitions=1]
#       +- Aggregate [commentid#191L], [sum(c#438L) AS c#442L, commentid#191L]
#          +- Project [(cast(c#426L as bigint) * c#437L) AS c#438L, commentid#191L, tagid#192L, c#426L, c#437L, tagid#83L]
#             +- Join Inner, (tagid#192L = cast(tagid#83L as bigint))
#                :- Project [commentid#191L, tagid#192L, 1 AS c#426L]
#                :  +- Filter (isnotnull(CommentId#191L) AND isnotnull(TagId#192L))
#                :     +- Relation [commentid#191L,tagid#192L] JDBCRelation(comment_hastag_tag) [numPartitions=1]
#                +- Aggregate [tagid#83L], [sum(c#433L) AS c#437L, tagid#83L]
#                   +- Project [(cast(c#427L as bigint) * c#428L) AS c#433L, tagid#83L, hastype_tagclassid#84L, c#427L, tagclassid#96L, c#428L]
#                      +- Join Inner, (hastype_tagclassid#84L = cast(tagclassid#96L as bigint))
#                         :- Project [tagid#83L, hastype_tagclassid#84L, 1 AS c#427L]
#                         :  +- Filter (isnotnull(TagId#83L) AND isnotnull(hasType_TagClassId#84L))
#                         :     +- Relation [tagid#83L,hastype_tagclassid#84L] JDBCRelation(tag) [numPartitions=1]
#                         +- Project [tagclassid#96L, 1 AS c#428L]
#                            +- Project [tagclassid#96L]
#                               +- Filter isnotnull(TagClassId#96L)
#                                  +- Relation [tagclassid#96L,issubclassof_tagclassid#97L] JDBCRelation(tagclass) [numPartitions=1]
# )
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: conditions: Set((postid#153L = cast(replyof_postid#125L as bigint)))
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: agg: sum(c#448L) AS c#469L
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is 0MA: false
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is sum: true
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is non-agg: false
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: agg: postid#153L
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is 0MA: true
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is sum: false
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is non-agg: true
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: agg: forum_containerofid#155L
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is 0MA: true
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is sum: false
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: is non-agg: true
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: aggregate attributes: {c#448L, postid#153L, forum_containerofid#155L}
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: groupingExpressions: Vector(postid#153L, forum_containerofid#155L)
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: group attributes: {postid#153L, forum_containerofid#155L}
# 23/10/24 12:48:44 WARN RewriteJoinsAsSemijoins: counting aggregates: List()
# 23/10/24 12:48:44 WARN Hypergraph: equivalence classes: Set(Set(postid#153L, replyof_postid#125L))
# 23/10/24 12:48:44 WARN Hypergraph: vertex to attribute mapping: Map(postid#153L -> Set(postid#153L, replyof_postid#125L))
# 23/10/24 12:48:44 WARN Hypergraph: attribute to vertex mapping: Map(ExprId(125,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> postid#153L, ExprId(153,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> postid#153L)
# 23/10/24 12:48:44 WARN Hypergraph: join item: Aggregate [postid#153L, forum_containerofid#155L], [sum(c#424L) AS c#445L, postid#153L, forum_containerofid#155L]
# +- Project [(cast(c#418L as bigint) * c#419L) AS c#424L, postid#153L, forum_containerofid#155L, c#418L, forumid#109L, c#419L]
#    +- Join Inner, (forum_containerofid#155L = cast(forumid#109L as bigint))
#       :- Project [postid#153L, forum_containerofid#155L, 1 AS c#418L]
#       :  +- Project [postid#153L, forum_containerofid#155L]
#       :     +- Filter (isnotnull(Forum_containerOfId#155L) AND isnotnull(PostId#153L))
#       :        +- Relation [postid#153L,hascreator_personid#154L,forum_containerofid#155L,islocatedin_countryid#156L] JDBCRelation(post) [numPartitions=1]
#       +- Project [forumid#109L, 1 AS c#419L]
#          +- Project [forumid#109L]
#             +- Filter isnotnull(ForumId#109L)
#                +- Relation [forumid#109L,hasmoderator_personid#110L] JDBCRelation(forum) [numPartitions=1]
#
# 23/10/24 12:48:44 WARN Hypergraph: join item: Aggregate [replyof_postid#125L], [sum(c#443L) AS c#447L, replyof_postid#125L]
# +- Project [(cast(c#425L as bigint) * c#442L) AS c#443L, commentid#122L, replyof_postid#125L, c#425L, c#442L, commentid#191L]
#    +- Join Inner, (commentid#122L = cast(commentid#191L as bigint))
#       :- Project [commentid#122L, replyof_postid#125L, 1 AS c#425L]
#       :  +- Project [commentid#122L, replyof_postid#125L]
#       :     +- Filter (isnotnull(replyOf_PostId#125L) AND isnotnull(CommentId#122L))
#       :        +- Relation [commentid#122L,hascreator_personid#123L,islocatedin_countryid#124L,replyof_postid#125L,replyof_commentid#126L] JDBCRelation(comment) [numPartitions=1]
#       +- Aggregate [commentid#191L], [sum(c#438L) AS c#442L, commentid#191L]
#          +- Project [(cast(c#426L as bigint) * c#437L) AS c#438L, commentid#191L, tagid#192L, c#426L, c#437L, tagid#83L]
#             +- Join Inner, (tagid#192L = cast(tagid#83L as bigint))
#                :- Project [commentid#191L, tagid#192L, 1 AS c#426L]
#                :  +- Filter (isnotnull(CommentId#191L) AND isnotnull(TagId#192L))
#                :     +- Relation [commentid#191L,tagid#192L] JDBCRelation(comment_hastag_tag) [numPartitions=1]
#                +- Aggregate [tagid#83L], [sum(c#433L) AS c#437L, tagid#83L]
#                   +- Project [(cast(c#427L as bigint) * c#428L) AS c#433L, tagid#83L, hastype_tagclassid#84L, c#427L, tagclassid#96L, c#428L]
#                      +- Join Inner, (hastype_tagclassid#84L = cast(tagclassid#96L as bigint))
#                         :- Project [tagid#83L, hastype_tagclassid#84L, 1 AS c#427L]
#                         :  +- Filter (isnotnull(TagId#83L) AND isnotnull(hasType_TagClassId#84L))
#                         :     +- Relation [tagid#83L,hastype_tagclassid#84L] JDBCRelation(tag) [numPartitions=1]
#                         +- Project [tagclassid#96L, 1 AS c#428L]
# ...
# 23/10/24 15:24:15 WARN HTNode: edge: E2(MessageId#381L)
# 23/10/24 15:24:15 WARN HTNode: overlapping vertices: Set((messageid#341L,parentmessageid#329L))
# 23/10/24 15:24:15 WARN HTNode: can semi join: false
# 23/10/24 15:24:15 WARN HTNode: join output: List(messageid#341L, c#786L, parentmessageid#329L, c#787L)
# 23/10/24 15:24:15 WARN HTNode: keyRefs: List()
# 23/10/24 15:24:15 WARN HTNode: edge: E2(MessageId#381L)
# 23/10/24 15:24:15 WARN HTNode: overlapping vertices: Set((messageid#341L,messageid#354L))
# 23/10/24 15:24:15 WARN HTNode: can semi join: false
# 23/10/24 15:24:15 WARN HTNode: join output: List(c#795L, messageid#341L, messageid#354L, c#793L)
# 23/10/24 15:24:15 WARN HTNode: keyRefs: List()
# 23/10/24 15:24:15 WARN HTNode: edge: E2(MessageId#381L)
# 23/10/24 15:24:15 WARN HTNode: overlapping vertices: Set((messageid#341L,messageid#381L))
# 23/10/24 15:24:15 WARN HTNode: can semi join: false
# 23/10/24 15:24:15 WARN HTNode: join output: List(c#801L, messageid#341L, messageid#381L, c#799L)
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: new aggregate: Aggregate [toprettystring(sum(c#804L), Some(Etc/UTC)) AS toprettystring(count(1))#784]
# +- Project [c#804L]
#    +- Project [(cast(c#801L as bigint) * c#799L) AS c#804L, c#801L, messageid#341L, messageid#381L, c#799L]
#       +- Join Inner, (messageid#341L = cast(messageid#381L as bigint))
#          :- Aggregate [messageid#341L], [sum(c#798L) AS c#801L, messageid#341L]
#          :  +- Project [(cast(c#795L as bigint) * c#793L) AS c#798L, c#795L, messageid#341L, messageid#354L, c#793L]
#          :     +- Join Inner, (messageid#341L = cast(messageid#354L as bigint))
#          :        :- Aggregate [messageid#341L], [sum(c#792L) AS c#795L, messageid#341L]
#          :        :  +- Project [(cast(c#786L as bigint) * c#787L) AS c#792L, messageid#341L, c#786L, parentmessageid#329L, c#787L]
#          :        :     +- Join Inner, (messageid#341L = cast(parentmessageid#329L as bigint))
#          :        :        :- Project [messageid#341L, 1 AS c#786L]
#          :        :        :  +- Project [messageid#341L]
#          :        :        :     +- Filter isnotnull(MessageId#341L)
#          :        :        :        +- Relation [messageid#341L,hascreator_personid#342L] JDBCRelation(message_hascreator_person) [numPartitions=1]
#          :        :        +- Project [parentmessageid#329L, 1 AS c#787L]
#          :        :           +- Project [parentmessageid#329L]
#          :        :              +- Filter isnotnull(ParentMessageId#329L)
#          :        :                 +- Relation [commentid#328L,parentmessageid#329L] JDBCRelation(comment_replyof_message) [numPartitions=1]
#          :        +- Project [messageid#354L, 1 AS c#793L]
#          :           +- Project [messageid#354L]
#          :              +- Filter isnotnull(MessageId#354L)
#          :                 +- Relation [messageid#354L,tagid#355L] JDBCRelation(message_hastag_tag) [numPartitions=1]
#          +- Project [messageid#381L, 1 AS c#799L]
#             +- Project [messageid#381L]
#                +- Filter isnotnull(MessageId#381L)
#                   +- Relation [personid#380L,messageid#381L] JDBCRelation(person_likes_message) [numPartitions=1]
#
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: applying yannakakis rewriting to join: Aggregate [messageid#341L], [sum(c#798L) AS c#801L, messageid#341L]
# +- Project [(cast(c#795L as bigint) * c#793L) AS c#798L, c#795L, messageid#341L, messageid#354L, c#793L]
#    +- Join Inner, (messageid#341L = cast(messageid#354L as bigint))
#       :- Aggregate [messageid#341L], [sum(c#792L) AS c#795L, messageid#341L]
#       :  +- Project [(cast(c#786L as bigint) * c#787L) AS c#792L, messageid#341L, c#786L, parentmessageid#329L, c#787L]
#       :     +- Join Inner, (messageid#341L = cast(parentmessageid#329L as bigint))
#       :        :- Project [messageid#341L, 1 AS c#786L]
#       :        :  +- Project [messageid#341L]
#       :        :     +- Filter isnotnull(MessageId#341L)
#       :        :        +- Relation [messageid#341L,hascreator_personid#342L] JDBCRelation(message_hascreator_person) [numPartitions=1]
#       :        +- Project [parentmessageid#329L, 1 AS c#787L]
#       :           +- Project [parentmessageid#329L]
#       :              +- Filter isnotnull(ParentMessageId#329L)
#       :                 +- Relation [commentid#328L,parentmessageid#329L] JDBCRelation(comment_replyof_message) [numPartitions=1]
#       +- Project [messageid#354L, 1 AS c#793L]
#          +- Project [messageid#354L]
#             +- Filter isnotnull(MessageId#354L)
#                +- Relation [messageid#354L,tagid#355L] JDBCRelation(message_hastag_tag) [numPartitions=1]
#
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: agg(project(join))
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: items: List(Aggregate [messageid#341L], [sum(c#792L) AS c#795L, messageid#341L]
# +- Project [(cast(c#786L as bigint) * c#787L) AS c#792L, messageid#341L, c#786L, parentmessageid#329L, c#787L]
#    +- Join Inner, (messageid#341L = cast(parentmessageid#329L as bigint))
#       :- Project [messageid#341L, 1 AS c#786L]
#       :  +- Project [messageid#341L]
#       :     +- Filter isnotnull(MessageId#341L)
#       :        +- Relation [messageid#341L,hascreator_personid#342L] JDBCRelation(message_hascreator_person) [numPartitions=1]
#       +- Project [parentmessageid#329L, 1 AS c#787L]
#          +- Project [parentmessageid#329L]
#             +- Filter isnotnull(ParentMessageId#329L)
#                +- Relation [commentid#328L,parentmessageid#329L] JDBCRelation(comment_replyof_message) [numPartitions=1]
# , Project [messageid#354L, 1 AS c#793L]
# +- Project [messageid#354L]
#    +- Filter isnotnull(MessageId#354L)
#       +- Relation [messageid#354L,tagid#355L] JDBCRelation(message_hastag_tag) [numPartitions=1]
# )
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: conditions: Set((messageid#341L = cast(messageid#354L as bigint)))
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: agg: sum(c#798L) AS c#801L
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is 0MA: false
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is sum: true
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is non-agg: false
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: agg: messageid#341L
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is 0MA: true
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is sum: false
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is non-agg: true
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: aggregate attributes: {c#798L, messageid#341L}
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: groupingExpressions: Vector(messageid#341L)
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: group attributes: {messageid#341L}
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: counting aggregates: List()
# 23/10/24 15:24:15 WARN Hypergraph: equivalence classes: Set(Set(messageid#341L, messageid#354L))
# 23/10/24 15:24:15 WARN Hypergraph: vertex to attribute mapping: Map(messageid#341L -> Set(messageid#341L, messageid#354L))
# 23/10/24 15:24:15 WARN Hypergraph: attribute to vertex mapping: Map(ExprId(354,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> messageid#341L, ExprId(341,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> messageid#341L)
# 23/10/24 15:24:15 WARN Hypergraph: join item: Aggregate [messageid#341L], [sum(c#792L) AS c#795L, messageid#341L]
# +- Project [(cast(c#786L as bigint) * c#787L) AS c#792L, messageid#341L, c#786L, parentmessageid#329L, c#787L]
#    +- Join Inner, (messageid#341L = cast(parentmessageid#329L as bigint))
#       :- Project [messageid#341L, 1 AS c#786L]
#       :  +- Project [messageid#341L]
#       :     +- Filter isnotnull(MessageId#341L)
#       :        +- Relation [messageid#341L,hascreator_personid#342L] JDBCRelation(message_hascreator_person) [numPartitions=1]
#       +- Project [parentmessageid#329L, 1 AS c#787L]
#          +- Project [parentmessageid#329L]
#             +- Filter isnotnull(ParentMessageId#329L)
#                +- Relation [commentid#328L,parentmessageid#329L] JDBCRelation(comment_replyof_message) [numPartitions=1]
#
# 23/10/24 15:24:15 WARN Hypergraph: join item: Project [messageid#354L, 1 AS c#793L]
# +- Project [messageid#354L]
#    +- Filter isnotnull(MessageId#354L)
#       +- Relation [messageid#354L,tagid#355L] JDBCRelation(message_hastag_tag) [numPartitions=1]
#
# 23/10/24 15:24:15 WARN Hypergraph: hyperedges: Set(E1(messageid#341L), E2(messageid#341L))
# 23/10/24 15:24:15 WARN Hypergraph: gyo edge: E1(messageid#341L)
# 23/10/24 15:24:15 WARN Hypergraph: supersets: Set()
# 23/10/24 15:24:15 WARN Hypergraph: parentNode: TreeNode(Set(E1(messageid#341L)))[Set({c#795L, messageid#341L})] [[parent: false]]
#
# 23/10/24 15:24:15 WARN Hypergraph: subsets: Set(TreeNode(Set(E2(messageid#341L)))[Set({messageid#354L, c#793L})] [[parent: false]]
# )
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: join tree:
# TreeNode(Set(E1(messageid#341L)))[Set({c#795L, messageid#341L})] [[parent: false]]
# -- TreeNode(Set(E2(messageid#341L)))[Set({messageid#354L, c#793L})] [[parent: true]]
#
# 23/10/24 15:24:15 WARN HTNode: aggAttributes: {c#798L, messageid#341L}
# 23/10/24 15:24:15 WARN HTNode: nodeAttributes: {c#795L, messageid#341L}
# 23/10/24 15:24:15 WARN HTNode: aggAttributes: {c#798L, messageid#341L}
# 23/10/24 15:24:15 WARN HTNode: nodeAttributes: {messageid#354L, c#793L}
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: query is not 0MA
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: applying yannakakis rewriting to join: Aggregate [messageid#341L], [sum(c#792L) AS c#795L, messageid#341L]
# +- Project [(cast(c#786L as bigint) * c#787L) AS c#792L, messageid#341L, c#786L, parentmessageid#329L, c#787L]
#    +- Join Inner, (messageid#341L = cast(parentmessageid#329L as bigint))
#       :- Project [messageid#341L, 1 AS c#786L]
#       :  +- Project [messageid#341L]
#       :     +- Filter isnotnull(MessageId#341L)
#       :        +- Relation [messageid#341L,hascreator_personid#342L] JDBCRelation(message_hascreator_person) [numPartitions=1]
#       +- Project [parentmessageid#329L, 1 AS c#787L]
#          +- Project [parentmessageid#329L]
#             +- Filter isnotnull(ParentMessageId#329L)
#                +- Relation [commentid#328L,parentmessageid#329L] JDBCRelation(comment_replyof_message) [numPartitions=1]
#
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: agg(project(join))
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: items: List(Project [messageid#341L, 1 AS c#786L]
# +- Project [messageid#341L]
#    +- Filter isnotnull(MessageId#341L)
#       +- Relation [messageid#341L,hascreator_personid#342L] JDBCRelation(message_hascreator_person) [numPartitions=1]
# , Project [parentmessageid#329L, 1 AS c#787L]
# +- Project [parentmessageid#329L]
#    +- Filter isnotnull(ParentMessageId#329L)
#       +- Relation [commentid#328L,parentmessageid#329L] JDBCRelation(comment_replyof_message) [numPartitions=1]
# )
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: conditions: Set((messageid#341L = cast(parentmessageid#329L as bigint)))
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: agg: sum(c#792L) AS c#795L
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is 0MA: false
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is sum: true
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is non-agg: false
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: agg: messageid#341L
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is 0MA: true
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is percentile: false
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is sum: false
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: is non-agg: true
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: aggregate attributes: {c#792L, messageid#341L}
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: groupingExpressions: Vector(messageid#341L)
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: group attributes: {messageid#341L}
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: counting aggregates: List()
# 23/10/24 15:24:15 WARN Hypergraph: equivalence classes: Set(Set(messageid#341L, parentmessageid#329L))
# 23/10/24 15:24:15 WARN Hypergraph: vertex to attribute mapping: Map(messageid#341L -> Set(messageid#341L, parentmessageid#329L))
# 23/10/24 15:24:15 WARN Hypergraph: attribute to vertex mapping: Map(ExprId(341,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> messageid#341L, ExprId(329,5d4e7cb5-f787-4911-a882-aae2bf7eea4b) -> messageid#341L)
# 23/10/24 15:24:15 WARN Hypergraph: join item: Project [messageid#341L, 1 AS c#786L]
# +- Project [messageid#341L]
#    +- Filter isnotnull(MessageId#341L)
#       +- Relation [messageid#341L,hascreator_personid#342L] JDBCRelation(message_hascreator_person) [numPartitions=1]
#
# 23/10/24 15:24:15 WARN Hypergraph: join item: Project [parentmessageid#329L, 1 AS c#787L]
# +- Project [parentmessageid#329L]
#    +- Filter isnotnull(ParentMessageId#329L)
#       +- Relation [commentid#328L,parentmessageid#329L] JDBCRelation(comment_replyof_message) [numPartitions=1]
#
# 23/10/24 15:24:15 WARN Hypergraph: hyperedges: Set(E2(messageid#341L), E1(messageid#341L))
# 23/10/24 15:24:15 WARN Hypergraph: gyo edge: E1(messageid#341L)
# 23/10/24 15:24:15 WARN Hypergraph: supersets: Set()
# 23/10/24 15:24:15 WARN Hypergraph: parentNode: TreeNode(Set(E1(messageid#341L)))[Set({messageid#341L, c#786L})] [[parent: false]]
#
# 23/10/24 15:24:15 WARN Hypergraph: subsets: Set(TreeNode(Set(E2(messageid#341L)))[Set({parentmessageid#329L, c#787L})] [[parent: false]]
# )
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: join tree:
# TreeNode(Set(E1(messageid#341L)))[Set({messageid#341L, c#786L})] [[parent: false]]
# -- TreeNode(Set(E2(messageid#341L)))[Set({parentmessageid#329L, c#787L})] [[parent: true]]
#
# 23/10/24 15:24:15 WARN HTNode: aggAttributes: {c#792L, messageid#341L}
# 23/10/24 15:24:15 WARN HTNode: nodeAttributes: {messageid#341L, c#786L}
# 23/10/24 15:24:15 WARN HTNode: aggAttributes: {c#792L, messageid#341L}
# 23/10/24 15:24:15 WARN HTNode: nodeAttributes: {parentmessageid#329L, c#787L}
# 23/10/24 15:24:15 WARN RewriteJoinsAsSemijoins: query is not 0MA
# +--------+
# |count(1)|
# +--------+
# |  753570|
# +--------+
#
# +--------------------+-----+
# |                 key|value|
# +--------------------+-----+
# |spark.sql.yannaka...| true|
# +--------------------+-----+
#
# running query:
# SELECT count(*)
#
# FROM Message_hasTag_Tag
#
# JOIN Message_hasCreator_Person
#
#   ON Message_hasTag_Tag.MessageId = Message_hasCreator_Person.MessageId
#
# JOIN Comment_replyOf_Message
#
#   ON Comment_replyOf_Message.ParentMessageId = Message_hasTag_Tag.MessageId
#
# JOIN Person_likes_Message
#
#   ON Person_likes_Message.MessageId = Message_hasTag_Tag.MessageId;
# +--------+
# |count(1)|
# +--------+
# |14836038|
# +--------+
#
# +--------------------+-----+
# |                 key|value|
# +--------------------+-----+
# |spark.sql.yannaka...|false|
# +--------------------+-----+
#
# running query:
# SELECT count(*)
#
# FROM Message_hasTag_Tag
#
# JOIN Message_hasCreator_Person
#
#   ON Message_hasTag_Tag.MessageId = Message_hasCreator_Person.MessageId
#
# JOIN Comment_replyOf_Message
#
#   ON Comment_replyOf_Message.ParentMessageId = Message_hasTag_Tag.MessageId
#
# JOIN Person_likes_Message
#
#   ON Person_likes_Message.MessageId = Message_hasTag_Tag.MessageId;
# +--------+
# |count(1)|
# +--------+
# |14836038|
# +--------+
#
#              query     ref_time  yannakakis_time
# 0  lsqb/sql/q1.sql    16.608744         5.376228
# 1  lsqb/sql/q3.sql  4814.826147      4494.824324
# 2  lsqb/sql/q4.sql     2.609319         2.949713

# %%
#spark.conf.set("spark.sql.legacy.setCommandRejectsSparkCoreConfs","false")
#spark.conf.set("spark.executor.cores", "1")
#spark.conf.set("spark.executor.instances", "1")
spark.conf.set("spark.sql.shuffle.partitions", "1")

# %%
## Compare result
import time
#query = 'tpch-kit/dbgen/queries/postgres/2.sql'
#query = 'tpch-kit/dbgen/queries/postgres/13.sql'
#query = 'count-3.sql'
#query = 'tpch-kit/dbgen/queries/postgres/11.sql'
#query = '11-simple.sql'
query = 'median-2-hint.sql'
#query = 'tpch-kit/dbgen/queries/postgres/7.sql'
#query = '13-simple.sql'
query = 'dsb-queries/agg_queries/query101.sql'
query = 'snap-queries/patents02.sql'
query = 'lsqb/sql/q4.sql'

spark.sql("SET spark.sql.yannakakis.enabled = true").show()

start_time = time.time()

df1 = run_query(query)
df1.show()
df1.explain(mode="extended")

end_time = time.time()
yannakakis_time = end_time - start_time

spark.sql("SET spark.sql.yannakakis.enabled = false").show()

start_time = time.time()

df2 = run_query(query)
df2.show()
df2.explain(mode="extended")

end_time = time.time()
ref_time = end_time - start_time

#print(f'row count: {df1.count()} vs. {df2.count()}' )
print(f'time ref: {ref_time}\ntime yannakakis: {yannakakis_time}')
