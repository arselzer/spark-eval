# %%
from pyspark.sql import SparkSession
import os

# %%
spark = SparkSession.builder \
        .master("local[30]") \
        .appName("app") \
        .config("spark.driver.memory", "900g") \
        .config("spark.executor.memory", "900g") \
        .config("spark.memory.offHeap.enabled",False) \
        .config("spark.jars", "postgresql-42.3.3.jar") \
        .getOrCreate()
#spark.sparkContext.setLogLevel("DEBUG")
# Out:
# 23/11/11 23:17:19 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
spark.sparkContext.setLogLevel("WARN") # ALL, DEBUG, WARN,
#spark.sparkContext.setLogLevel("ALL") # ALL, DEBUG, WARN,

# %%
username = os.environ.get('USERNAME', 'tpch')
password = os.environ.get('PASSWORD', 'tpch')
dbname = os.environ.get('DBNAME', 'tpch')
dbhost = os.environ.get('DBHOST', 'postgres')

df_tables = spark.read.format("jdbc") \
    .option("url", f'jdbc:postgresql://{dbhost}:5432/{dbname}') \
    .option("driver", "org.postgresql.Driver") \
    .option("dbtable", "information_schema.tables") \
    .option("user", username) \
    .option("password", password) \
    .load()

for idx, row in df_tables.toPandas().iterrows():
        if row.table_schema == 'public':
            table_name = row.table_name
            df = spark.read.format("jdbc") \
                .option("url", f'jdbc:postgresql://{dbhost}:5432/{dbname}') \
                .option("driver", "org.postgresql.Driver") \
                .option("dbtable", table_name) \
                .option("user", username) \
                .option("password", password) \
                .load()
    
            print(table_name)
            #print(df.show())
            df.createOrReplaceTempView(table_name)
            spark.catalog.cacheTable(table_name)
# Out:
# part
# supplier
# partsupp
# customer
# orders
# lineitem
# nation
# region

# %%
def extract_metrics(spark, group_id):
    parsed = list(urlsplit(spark.sparkContext.uiWebUrl))
    host_port = parsed[1]
    parsed[1] = 'localhost' + host_port[host_port.find(':'):]
    API_URL = f'{urlunsplit(parsed)}/api/v1'

    app_id = spark.sparkContext.applicationId
    sql_queries = requests.get(API_URL + f'/applications/{app_id}/sql', params={'length': '100000'}).json()
    query_ids = [q['id'] for q in sql_queries if q['description'] == group_id]
    if (len(query_ids) == 0):
        print(f'query with group {group_id} not found')
        return None
    query_id = query_ids[0]
    print(f'query id: {query_id}')
    
    query_details = requests.get(API_URL + f'/applications/{app_id}/sql/{query_id}',
                                 params={'details': 'true', 'planDescription': 'true'}).json()
    
    success_job_ids = query_details['successJobIds']
    running_job_ids = query_details['runningJobIds']
    failed_job_ids = query_details['failedJobIds']
    
    job_ids = success_job_ids + running_job_ids + failed_job_ids
    
    job_details = [requests.get(API_URL + f'/applications/{app_id}/jobs/{jid}').json() for jid in job_ids]
    
    job_stages = {}
    
    for j in job_details:
        stage_ids = j['stageIds']
        
        stage_params = {'details': 'true', 'withSummaries': 'true'}
        stages = [requests.get(API_URL + f'/applications/{app_id}/stages/{sid}', stage_params) for sid in stage_ids]
        
        job_stages[j['jobId']] = [stage.json() for stage in stages if stage.status_code == 200] # can be 404
    
    return query_details, job_details, job_stages

# %%
spark.sql("SET spark.sql.yannakakis.countGroupInLeaves = false").show()

# %%
spark.sql("SET spark.sql.yannakakis.enabled = false").show()

# %%
spark.sql("SET spark.sql.yannakakis.enabled = true").show()
spark.sql("SET spark.sql.yannakakis.countGroupInLeaves = false").show()

# %%
spark.sql("SET spark.local.dir").show()

# %%
spark.sql("ANALYZE TABLE part COMPUTE STATISTICS;").show()

# %%
df = spark.sql("""select *
        		from
            part,
			partsupp,
			supplier,
			nation,
			region
		where
			p_partkey = ps_partkey
			and s_suppkey = ps_suppkey
			and s_nationkey = n_nationkey
			and n_regionkey = r_regionkey
            AND p_retailprice >
                (SELECT avg (p_retailprice) FROM part)""")

df.show(500)

df.explain(True)
# Out:
# 23/11/11 10:51:53 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# [Stage 216:====================================================>(197 + 3) / 200]
# +---------+--------------------+--------------------+----------+--------------------+------+-----------+--------------------+--------------------+----------+----------+-----------+--------------------+--------------------+---------+--------------------+--------------------+-----------+---------------+--------------------+--------------------+-----------+--------------------+-----------+--------------------+-----------+--------------------+--------------------+
# |p_partkey|              p_name|              p_mfgr|   p_brand|              p_type|p_size|p_container|       p_retailprice|           p_comment|ps_partkey|ps_suppkey|ps_availqty|       ps_supplycost|          ps_comment|s_suppkey|              s_name|           s_address|s_nationkey|        s_phone|           s_acctbal|           s_comment|n_nationkey|              n_name|n_regionkey|           n_comment|r_regionkey|              r_name|           r_comment|
# +---------+--------------------+--------------------+----------+--------------------+------+-----------+--------------------+--------------------+----------+----------+-----------+--------------------+--------------------+---------+--------------------+--------------------+-----------+---------------+--------------------+--------------------+-----------+--------------------+-----------+--------------------+-----------+--------------------+--------------------+
# | 14499997|coral lace blue p...|Manufacturer#2   ...|Brand#21  |ECONOMY POLISHED TIN|    39| LG DRUM   |1996.270000000000...|            onic dep|  14499997|        26|       3111|792.7000000000000...|re slyly unusual ...|       26|Supplier#00000002...|iV,MHzAx6Z939uzFN...|         21|31-758-894-4436|21.18000000000000...| ideas poach care...|         21|VIETNAM          ...|          2|hely enticingly e...|          2|ASIA             ...|ges. thinly even ...|
# | 10249995|cornflower sienna...|Manufacturer#1   ...|Brand#12  |  PROMO PLATED STEEL|    42| LG CAN    |1944.480000000000...|                bold|  10249995|        26|       1475|624.2800000000000...|leep quickly requ...|       26|Supplier#00000002...|iV,MHzAx6Z939uzFN...|         21|31-758-894-4436|21.18000000000000...| ideas poach care...|         21|VIETNAM          ...|          2|hely enticingly e...|          2|ASIA             ...|ges. thinly even ...|
# | 11249992|dim green midnigh...|Manufacturer#4   ...|Brand#45  |  PROMO POLISHED TIN|    33| JUMBO BAG |1941.430000000000...|         boost fluff|  11249992|        26|       3325|318.7200000000000...|y even dependenci...|       26|Supplier#00000002...|iV,MHzAx6Z939uzFN...|         21|31-758-894-4436|21.18000000000000...| ideas poach care...|         21|VIETNAM          ...|          2|hely enticingly e...|          2|ASIA             ...|ges. thinly even ...|
# | 13249986|light antique gre...|Manufacturer#1   ...|Brand#12  |LARGE BRUSHED NICKEL|    18| SM BOX    |1935.320000000000...|es. furiously final |  13249986|        26|       3424|41.34000000000000...|old. carefully ev...|       26|Supplier#00000002...|iV,MHzAx6Z939uzFN...|         21|31-758-894-4436|21.18000000000000...| ideas poach care...|         21|VIETNAM          ...|          2|hely enticingly e...|          2|ASIA             ...|ges. thinly even ...|
|      964|Supplier#00000096...|JpH9YUQjGXD1GChWc...|          7|17-693-102-9498|8411.780000000000...| instructions; fl...|          7|GERMANY          ...|          3|l platelets. regu...|          3|EUROPE           ...|ly final courts c...|
# |  3500957|frosted sienna in...|Manufacturer#3   ...|Brand#31  |LARGE POLISHED CO...|     4| LG PKG    |1957.780000000000...|   ound the furiousl|   3500957|       964|        145|161.5900000000000...|ly special theodo...|      964|Supplier#00000096...|JpH9YUQjGXD1GChWc...|          7|17-693-102-9498|8411.780000000000...| instructions; fl...|          7|GERMANY          ...|          3|l platelets. regu...|          3|EUROPE           ...|ly final courts c...|
# | 14000963|maroon goldenrod ...|Manufacturer#1   ...|Brand#11  |MEDIUM PLATED NICKEL|    40| MED PACK  |1863.260000000000...|     asymptotes dazz|  14000963|       964|       4978|75.89000000000000...|nto beans are alo...|      964|Supplier#00000096...|JpH9YUQjGXD1GChWc...|          7|17-693-102-9498|8411.780000000000...| instructions; fl...|          7|GERMANY          ...|          3|l platelets. regu...|          3|EUROPE           ...|ly final courts c...|
# |   500963|tomato seashell r...|Manufacturer#4   ...|Brand#45  |   SMALL BRUSHED TIN|    42| LG BOX    |1963.940000000000...|      ole carefully |    500963|       964|       5963|568.0300000000000...|s. blithely speci...|      964|Supplier#00000096...|JpH9YUQjGXD1GChWc...|          7|17-693-102-9498|8411.780000000000...| instructions; fl...|          7|GERMANY          ...|          3|l platelets. regu...|          3|EUROPE           ...|ly final courts c...|
# |  3000963|metallic honeydew...|Manufacturer#4   ...|Brand#43  |SMALL POLISHED NI...|    24| SM BOX    |1863.810000000000...|             nic pin|   3000963|       964|       8899|471.9500000000000...|gle after the exp...|      964|Supplier#00000096...|JpH9YUQjGXD1GChWc...|          7|17-693-102-9498|8411.780000000000...| instructions; fl...|          7|GERMANY          ...|          3|l platelets. regu...|          3|EUROPE           ...|ly final courts c...|
# | 19750944|indian powder cya...|Manufacturer#3   ...|Brand#35  | SMALL BRUSHED BRASS|    10| WRAP PKG  |1993.960000000000...|     ar dinos. brave|  19750944|       964|       4022|513.1200000000000...|uriously along th...|      964|Supplier#00000096...|JpH9YUQjGXD1GChWc...|          7|17-693-102-9498|8411.780000000000...| instructions; fl...|          7|GERMANY          ...|          3|l platelets. regu...|          3|EUROPE           ...|ly final courts c...|
# | 12000963|sky orchid salmon...|Manufacturer#5   ...|Brand#53  |  LARGE POLISHED TIN|    29| JUMBO CASE|1863.360000000000...|         xes wake pi|  12000963|       964|       5440|630.0300000000000...|ely final pinto b...|      964|Supplier#00000096...|JpH9YUQjGXD1GChWc...|          7|17-693-102-9498|8411.780000000000...| instructions; fl...|          7|GERMANY          ...|          3|l platelets. regu...|          3|EUROPE           ...|ly final courts c...|
# |  1750962|maroon grey gains...|Manufacturer#4   ...|Brand#45  |SMALL BURNISHED C...|    18| WRAP DRUM |2012.880000000000...|        al depths na|   1750962|       964|       1644|402.9500000000000...|ic asymptotes boo...|      964|Supplier#00000096...|JpH9YUQjGXD1GChWc...|          7|17-693-102-9498|8411.780000000000...| instructions; fl...|          7|GERMANY          ...|          3|l platelets. regu...|          3|EUROPE           ...|ly final courts c...|
# | 17000963|orchid olive maro...|Manufacturer#3   ...|Brand#31  |SMALL POLISHED BRASS|    29| LG PACK   |1863.110000000000...|        w. final, ir|  17000963|       964|       9971|524.0200000000000...|n dependencies wa...|      964|Supplier#00000096...|JpH9YUQjGXD1GChWc...|          7|17-693-102-9498|8411.780000000000...| instructions; fl...|          7|GERMANY          ...|          3|l platelets. regu...|          3|EUROPE           ...|ly final courts c...|
# | 10500943|seashell lavender...|Manufacturer#4   ...|Brand#45  |LARGE BURNISHED N...|    28| SM CASE   |1943.420000000000...|             gle abo|  10500943|       964|       6816|220.3200000000000...|ound the furiousl...|      964|Supplier#00000096...|JpH9YUQjGXD1GChWc...|          7|17-693-102-9498|8411.780000000000...| instructions; fl...|          7|GERMANY          ...|          3|l platelets. regu...|          3|EUROPE           ...|ly final courts c...|
# | 12500939|indian yellow whe...|Manufacturer#3   ...|Brand#32  |ECONOMY BRUSHED S...|    16| SM DRUM   |1939.310000000000...|     fully above the|  12500939|       964|       2737|456.1900000000000...|ding to the final...|      964|Supplier#00000096...|JpH9YUQjGXD1GChWc...|          7|17-693-102-9498|8411.780000000000...| instructions; fl...|          7|GERMANY          ...|          3|l platelets. regu...|          3|EUROPE           ...|ly final courts c...|
# |  6250945|rose tan slate me...|Manufacturer#1   ...|Brand#11  | MEDIUM PLATED BRASS|    28| SM BAG    |1895.630000000000...|       eyond the eve|   6250945|       964|        954|730.5900000000000...|r dependencies ha...|      964|Supplier#00000096...|JpH9YUQjGXD1GChWc...|          7|17-693-102-9498|8411.780000000000...| instructions; fl...|          7|GERMANY          ...|          3|l platelets. regu...|          3|EUROPE           ...|ly final courts c...|
# | 14250921|mint firebrick le...|Manufacturer#1   ...|Brand#12  |STANDARD PLATED B...|     4| WRAP BAG  |1871.210000000000...|s. blithely regular |  14250921|       964|       7317|413.5200000000000...|ses-- furiously p...|      964|Supplier#00000096...|JpH9YUQjGXD1GChWc...|          7|17-693-102-9498|8411.780000000000...| instructions; fl...|          7|GERMANY          ...|          3|l platelets. regu...|          3|EUROPE           ...|ly final courts c...|
# ...
# :  :- Join Inner, (cast(s_suppkey#99 as bigint) = ps_suppkey#158L)
# :  :  :- Join Inner, (cast(p_partkey#24 as bigint) = ps_partkey#157L)
# :  :  :  :- Filter ((isnotnull(p_retailprice#31) AND (cast(p_retailprice#31 as decimal(38,22)) > scalar-subquery#14822 [])) AND isnotnull(p_partkey#24))
# :  :  :  :  :  +- Aggregate [avg(p_retailprice#14832) AS avg(p_retailprice)#14824]
# :  :  :  :  :     +- Project [p_retailprice#14832]
# :  :  :  :  :        +- InMemoryRelation [p_partkey#14825, p_name#14826, p_mfgr#33, p_brand#34, p_type#14829, p_size#14830, p_container#35, p_retailprice#14832, p_comment#14833], StorageLevel(disk, memory, deserialized, 1 replicas)
# :  :  :  :  :              +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
# :  :  :  :  :                 +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
# :  :  :  :  +- InMemoryRelation [p_partkey#24, p_name#25, p_mfgr#33, p_brand#34, p_type#28, p_size#29, p_container#35, p_retailprice#31, p_comment#32], StorageLevel(disk, memory, deserialized, 1 replicas)
# :  :  :  :        +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
# :  :  :  :           +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
# :  :  :  +- Filter (isnotnull(ps_partkey#157L) AND isnotnull(ps_suppkey#158L))
# :  :  :     +- InMemoryRelation [ps_partkey#157L, ps_suppkey#158L, ps_availqty#159, ps_supplycost#160, ps_comment#161], StorageLevel(disk, memory, deserialized, 1 replicas)
# :  :  :           +- *(1) Scan JDBCRelation(partsupp) [numPartitions=1] [ps_partkey#157L,ps_suppkey#158L,ps_availqty#159,ps_supplycost#160,ps_comment#161] PushedFilters: [], ReadSchema: struct<ps_partkey:bigint,ps_suppkey:bigint,ps_availqty:int,ps_supplycost:decimal(38,18),ps_commen...
# :  :  +- Filter (isnotnull(s_suppkey#99) AND isnotnull(s_nationkey#102L))
# :  :     +- InMemoryRelation [s_suppkey#99, s_name#106, s_address#101, s_nationkey#102L, s_phone#107, s_acctbal#104, s_comment#105], StorageLevel(disk, memory, deserialized, 1 replicas)
# :  :           +- *(1) Project [s_suppkey#99, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, s_name#100, 25, true, false, true) AS s_name#106, s_address#101, s_nationkey#102L, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, s_phone#103, 15, true, false, true) AS s_phone#107, s_acctbal#104, s_comment#105]
# :  :              +- *(1) Scan JDBCRelation(supplier) [numPartitions=1] [s_suppkey#99,s_name#100,s_address#101,s_nationkey#102L,s_phone#103,s_acctbal#104,s_comment#105] PushedFilters: [], ReadSchema: struct<s_suppkey:int,s_name:string,s_address:string,s_nationkey:bigint,s_phone:string,s_acctbal:d...
# :  +- Filter (isnotnull(n_nationkey#470) AND isnotnull(n_regionkey#472L))
# :     +- InMemoryRelation [n_nationkey#470, n_name#474, n_regionkey#472L, n_comment#473], StorageLevel(disk, memory, deserialized, 1 replicas)
# :           +- *(1) Project [n_nationkey#470, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, n_name#471, 25, true, false, true) AS n_name#474, n_regionkey#472L, n_comment#473]
# :              +- *(1) Scan JDBCRelation(nation) [numPartitions=1] [n_nationkey#470,n_name#471,n_regionkey#472L,n_comment#473] PushedFilters: [], ReadSchema: struct<n_nationkey:int,n_name:string,n_regionkey:bigint,n_comment:string>
# +- Filter isnotnull(r_regionkey#503)
#    +- InMemoryRelation [r_regionkey#503, r_name#506, r_comment#505], StorageLevel(disk, memory, deserialized, 1 replicas)
#          +- *(1) Project [r_regionkey#503, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, r_name#504, 25, true, false, true) AS r_name#506, r_comment#505]
#             +- *(1) Scan JDBCRelation(region) [numPartitions=1] [r_regionkey#503,r_name#504,r_comment#505] PushedFilters: [], ReadSchema: struct<r_regionkey:int,r_name:string,r_comment:string>
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- BroadcastHashJoin [n_regionkey#472L], [cast(r_regionkey#503 as bigint)], Inner, BuildRight, false
#    :- BroadcastHashJoin [s_nationkey#102L], [cast(n_nationkey#470 as bigint)], Inner, BuildRight, false
#    :  :- SortMergeJoin [ps_suppkey#158L], [cast(s_suppkey#99 as bigint)], Inner
#    :  :  :- Sort [ps_suppkey#158L ASC NULLS FIRST], false, 0
#    :  :  :  +- Exchange hashpartitioning(ps_suppkey#158L, 200), ENSURE_REQUIREMENTS, [plan_id=11655]
#    :  :  :     +- SortMergeJoin [cast(p_partkey#24 as bigint)], [ps_partkey#157L], Inner
#    :  :  :        :- Sort [cast(p_partkey#24 as bigint) ASC NULLS FIRST], false, 0
#    :  :  :        :  +- Exchange hashpartitioning(cast(p_partkey#24 as bigint), 200), ENSURE_REQUIREMENTS, [plan_id=11648]
#    :  :  :        :     +- Filter ((isnotnull(p_retailprice#31) AND (cast(p_retailprice#31 as decimal(38,22)) > Subquery subquery#14822, [id=#11637])) AND isnotnull(p_partkey#24))
#    :  :  :        :        :  +- Subquery subquery#14822, [id=#11637]
#    :  :  :        :        :     +- AdaptiveSparkPlan isFinalPlan=false
#    :  :  :        :        :        +- HashAggregate(keys=[], functions=[avg(p_retailprice#14832)], output=[avg(p_retailprice)#14824])
#    :  :  :        :        :           +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=11635]
#    :  :  :        :        :              +- HashAggregate(keys=[], functions=[partial_avg(p_retailprice#14832)], output=[sum#15503, count#15504L])
#    :  :  :        :        :                 +- Scan In-memory table part [p_retailprice#14832]
#    :  :  :        :        :                       +- InMemoryRelation [p_partkey#14825, p_name#14826, p_mfgr#33, p_brand#34, p_type#14829, p_size#14830, p_container#35, p_retailprice#14832, p_comment#14833], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :  :  :        :        :                             +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#    :  :  :        :        :                                +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
#    :  :  :        :        +- Scan In-memory table part [p_partkey#24, p_name#25, p_mfgr#33, p_brand#34, p_type#28, p_size#29, p_container#35, p_retailprice#31, p_comment#32], [isnotnull(p_retailprice#31), (cast(p_retailprice#31 as decimal(38,22)) > Subquery subquery#14822, [id=#11639]), isnotnull(p_partkey#24)]
#    :  :  :        :              :- InMemoryRelation [p_partkey#24, p_name#25, p_mfgr#33, p_brand#34, p_type#28, p_size#29, p_container#35, p_retailprice#31, p_comment#32], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :  :  :        :              :     +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#    :  :  :        :              :        +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
#    :  :  :        :              +- Subquery subquery#14822, [id=#11639]
#    :  :  :        :                 +- AdaptiveSparkPlan isFinalPlan=false
#    :  :  :        :                    +- HashAggregate(keys=[], functions=[avg(p_retailprice#14832)], output=[avg(p_retailprice)#14824])
#    :  :  :        :                       +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=11635]
#    :  :  :        :                          +- HashAggregate(keys=[], functions=[partial_avg(p_retailprice#14832)], output=[sum#15503, count#15504L])
#    :  :  :        :                             +- Scan In-memory table part [p_retailprice#14832]
#    :  :  :        :                                   +- InMemoryRelation [p_partkey#14825, p_name#14826, p_mfgr#33, p_brand#34, p_type#14829, p_size#14830, p_container#35, p_retailprice#14832, p_comment#14833], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :  :  :        :                                         +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#    :  :  :        :                                            +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
#    :  :  :        +- Sort [ps_partkey#157L ASC NULLS FIRST], false, 0
#    :  :  :           +- Exchange hashpartitioning(ps_partkey#157L, 200), ENSURE_REQUIREMENTS, [plan_id=11649]
#    :  :  :              +- Filter (isnotnull(ps_partkey#157L) AND isnotnull(ps_suppkey#158L))
#    :  :  :                 +- Scan In-memory table partsupp [ps_partkey#157L, ps_suppkey#158L, ps_availqty#159, ps_supplycost#160, ps_comment#161], [isnotnull(ps_partkey#157L), isnotnull(ps_suppkey#158L)]
#    :  :  :                       +- InMemoryRelation [ps_partkey#157L, ps_suppkey#158L, ps_availqty#159, ps_supplycost#160, ps_comment#161], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :  :  :                             +- *(1) Scan JDBCRelation(partsupp) [numPartitions=1] [ps_partkey#157L,ps_suppkey#158L,ps_availqty#159,ps_supplycost#160,ps_comment#161] PushedFilters: [], ReadSchema: struct<ps_partkey:bigint,ps_suppkey:bigint,ps_availqty:int,ps_supplycost:decimal(38,18),ps_commen...
#    :  :  +- Sort [cast(s_suppkey#99 as bigint) ASC NULLS FIRST], false, 0
#    :  :     +- Exchange hashpartitioning(cast(s_suppkey#99 as bigint), 200), ENSURE_REQUIREMENTS, [plan_id=11656]
#    :  :        +- Filter (isnotnull(s_suppkey#99) AND isnotnull(s_nationkey#102L))
#    :  :           +- Scan In-memory table supplier [s_suppkey#99, s_name#106, s_address#101, s_nationkey#102L, s_phone#107, s_acctbal#104, s_comment#105], [isnotnull(s_suppkey#99), isnotnull(s_nationkey#102L)]
#    :  :                 +- InMemoryRelation [s_suppkey#99, s_name#106, s_address#101, s_nationkey#102L, s_phone#107, s_acctbal#104, s_comment#105], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :  :                       +- *(1) Project [s_suppkey#99, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, s_name#100, 25, true, false, true) AS s_name#106, s_address#101, s_nationkey#102L, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, s_phone#103, 15, true, false, true) AS s_phone#107, s_acctbal#104, s_comment#105]
#    :  :                          +- *(1) Scan JDBCRelation(supplier) [numPartitions=1] [s_suppkey#99,s_name#100,s_address#101,s_nationkey#102L,s_phone#103,s_acctbal#104,s_comment#105] PushedFilters: [], ReadSchema: struct<s_suppkey:int,s_name:string,s_address:string,s_nationkey:bigint,s_phone:string,s_acctbal:d...
#    :  +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=11661]
#    :     +- Filter (isnotnull(n_nationkey#470) AND isnotnull(n_regionkey#472L))
#    :        +- Scan In-memory table nation [n_nationkey#470, n_name#474, n_regionkey#472L, n_comment#473], [isnotnull(n_nationkey#470), isnotnull(n_regionkey#472L)]
#    :              +- InMemoryRelation [n_nationkey#470, n_name#474, n_regionkey#472L, n_comment#473], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :                    +- *(1) Project [n_nationkey#470, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, n_name#471, 25, true, false, true) AS n_name#474, n_regionkey#472L, n_comment#473]
#    :                       +- *(1) Scan JDBCRelation(nation) [numPartitions=1] [n_nationkey#470,n_name#471,n_regionkey#472L,n_comment#473] PushedFilters: [], ReadSchema: struct<n_nationkey:int,n_name:string,n_regionkey:bigint,n_comment:string>
#    +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=11664]
#       +- Filter isnotnull(r_regionkey#503)
#          +- Scan In-memory table region [r_regionkey#503, r_name#506, r_comment#505], [isnotnull(r_regionkey#503)]
#                +- InMemoryRelation [r_regionkey#503, r_name#506, r_comment#505], StorageLevel(disk, memory, deserialized, 1 replicas)
#                      +- *(1) Project [r_regionkey#503, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, r_name#504, 25, true, false, true) AS r_name#506, r_comment#505]
#                         +- *(1) Scan JDBCRelation(region) [numPartitions=1] [r_regionkey#503,r_name#504,r_comment#505] PushedFilters: [], ReadSchema: struct<r_regionkey:int,r_name:string,r_comment:string>

# %%
def run_query(file):
    with open(file, 'r') as f:
        query = '\n'.join(filter(lambda line: not line.startswith('limit') and not line.startswith('-'), f.readlines()))
        
        print("running query: \n" + query)
        return spark.sql(query)

# %%
df = spark.sql("""
SELECT * FROM region;
""")

df.show()

df.explain(True)

# %%
df = spark.sql("SELECT * from nation, region where n_regionkey = r_regionkey and r_name IN ('EUROPE', 'ASIA')")
df.show()
# Out:
# +-----------+--------------------+-----------+--------------------+-----------+--------------------+--------------------+
# |n_nationkey|              n_name|n_regionkey|           n_comment|r_regionkey|              r_name|           r_comment|
# +-----------+--------------------+-----------+--------------------+-----------+--------------------+--------------------+
# |         21|VIETNAM          ...|          2|hely enticingly e...|          2|ASIA             ...|ges. thinly even ...|
# |         18|CHINA            ...|          2|c dependencies. f...|          2|ASIA             ...|ges. thinly even ...|
# |         12|JAPAN            ...|          2|ously. final, exp...|          2|ASIA             ...|ges. thinly even ...|
# |          9|INDONESIA        ...|          2| slyly express as...|          2|ASIA             ...|ges. thinly even ...|
# |          8|INDIA            ...|          2|ss excuses cajole...|          2|ASIA             ...|ges. thinly even ...|
# |         23|UNITED KINGDOM   ...|          3|eans boost carefu...|          3|EUROPE           ...|ly final courts c...|
# |         22|RUSSIA           ...|          3| requests against...|          3|EUROPE           ...|ly final courts c...|
# |         19|ROMANIA          ...|          3|ular asymptotes a...|          3|EUROPE           ...|ly final courts c...|
# |          7|GERMANY          ...|          3|l platelets. regu...|          3|EUROPE           ...|ly final courts c...|
# |          6|FRANCE           ...|          3|refully final req...|          3|EUROPE           ...|ly final courts c...|
# +-----------+--------------------+-----------+--------------------+-----------+--------------------+--------------------+

# %%
df_t1 = spark.createDataFrame([(1,1), (2,1), (2,2), (3,2), (3,3), (4,3), (4,3), (5,2), (5,1), (6,4)], schema=("a","b"))
df_t1.createOrReplaceTempView("t1")
df_t2 = spark.createDataFrame([(1,1), (2,1), (3,2), (3,2), (3,3), (3,3), (4,3), (4,2), (5,1), (6,4)], schema=("c","d"))
df_t2.createOrReplaceTempView("t2")
df_t3 = spark.createDataFrame([(1,1), (2,1), (3,2), (3,2), (3,3), (3,3), (4,3), (4,2), (5,1), (6,4)], schema=("e","f"))
df_t3.createOrReplaceTempView("t3")

query = "select median(a) from t1, t2 where b = c"
#query = "select percentile(a, 0.5, b) from t1, t2 where b = c"
#query = "select median(a) from t1 where EXISTS (SELECT 1 FROM t2 WHERE b = c)"
#query = "select count(*) from t1, t2 where b = c"
#query = "select *a from t1 where EXISTS (SELECT 1 FROM t2 WHERE b = c)"

spark.sql("SET spark.sql.yannakakis.enabled = false").show()

df = spark.sql(query)
df.show()

spark.sql("SET spark.sql.yannakakis.enabled = true").show()

df = spark.sql(query)
df.show()

# %%
spark.conf.set("spark.sql.legacy.setCommandRejectsSparkCoreConfs","false")
#spark.conf.set("spark.executor.cores", "6")
#spark.conf.set("spark.executor.instances", "6")
spark.conf.set("spark.sql.shuffle.partitions", "6")

# %%
spark.sparkContext.uiWebUrl
# Out:
# 'http://a8dc08c6eef4:4040'

# %%
import pandas as pd
import time

def benchmark(query):
    df0 = run_query(query)
    df0.show()
    
    spark.sql("SET spark.sql.yannakakis.enabled = true").show()

    start_time = time.time()

    df1 = run_query(query)
    df1.show()
    #df1.explain(True)

    end_time = time.time()
    yannakakis_time = end_time - start_time

    spark.sql("SET spark.sql.yannakakis.enabled = false").show()

    start_time = time.time()

    df2 = run_query(query)
    df2.show()
    #df2.explain(True)

    end_time = time.time()
    ref_time = end_time - start_time
    
    #return [query, ref_time, yannakakis_time]
    return [query, ref_time, yannakakis_time]


queries = ['tpch-kit/dbgen/queries/postgres/2.sql',
           'tpch-kit/dbgen/queries/postgres/11.sql', 
           'tpch-kit/dbgen/queries/postgres/11-hint.sql',
           'median-1.sql',
           'median-2.sql', 
           'median-3.sql', 
           'median-4.sql', 
           'median-5.sql',
        'median-1-hint.sql',
           'median-2-hint.sql', 
           'median-3-hint.sql', 
           'median-4-hint.sql', 
           'median-5-hint.sql'] * 4

results = [benchmark(q) for q in queries]

df = pd.DataFrame(results, columns = ['query', 'ref_time', 'yannakakis_time'])

print(df)

df.to_csv("results.csv")
    

#print(f'row count: {df1.count()} vs. {df2.count()}' )
    #print(f'time ref: {ref_time}\ntime yannakakis: {yannakakis_time}')
# Out:
# running query:
#
#
#
#
# select
#
# 	s_acctbal,
#
# 	s_name,
#
# 	n_name,
#
# 	p_partkey,
#
# 	p_mfgr,
#
# 	s_address,
#
# 	s_phone,
#
# 	s_comment
#
# from
#
# 	part,
#
# 	supplier,
#
# 	partsupp,
#
# 	nation,
#
# 	region
#
# where
#
# 	p_partkey = ps_partkey
#
# 	and s_suppkey = ps_suppkey
#
# 	and p_size = 15
#
# 	and p_type like '%BRASS'
#
# 	and s_nationkey = n_nationkey
#
# 	and n_regionkey = r_regionkey
#
# 	and r_name = 'EUROPE'
#
# 	and ps_supplycost = (
#
# 		select
#
# 			min(ps_supplycost)
#
# 		from
#
# 			partsupp,
#
# 			supplier,
#
# 			nation,
#
# 			region
#
# 		where
#
# 			p_partkey = ps_partkey
#
# 			and s_suppkey = ps_suppkey
#
# 			and s_nationkey = n_nationkey
#
# 			and n_regionkey = r_regionkey
#
# 			and r_name = 'EUROPE'
#
# 	)
#
# order by
#
# 	s_acctbal desc,
#
# 	n_name,
#
# 	s_name,
#
# 	p_partkey;
# [Stage 2:>                  (0 + 1) / 1][Stage 3:>                  (0 + 1) / 1]

# %%
#spark.conf.set("spark.sql.legacy.setCommandRejectsSparkCoreConfs","false")
#spark.conf.set("spark.executor.cores", "1")
#spark.conf.set("spark.executor.instances", "1")
spark.conf.set("spark.sql.shuffle.partitions", "1")

# %%
spark.uiWebUrl

# %%
## Compare result
import time
query = 'tpch-kit/dbgen/queries/postgres/2.sql'
#query = 'tpch-kit/dbgen/queries/postgres/13.sql'
#query = 'count-3.sql'
#query = 'tpch-kit/dbgen/queries/postgres/11.sql'
#query = '11-simple.sql'
query = 'median-1-hint.sql'
#query = 'median-1.sql'
#query = 'tpch-kit/dbgen/queries/postgres/7.sql'
#query = '13-simple.sql'
#query = 'subselect-exists.sql'
#query = 'min-1.sql'

spark.sql("SET spark.sql.yannakakis.enabled = true").show()

start_time = time.time()

df1 = run_query(query)
df1.show()
df1.explain(mode="extended")

end_time = time.time()
yannakakis_time = end_time - start_time

spark.sql("SET spark.sql.yannakakis.enabled = false").show()

start_time = time.time()

df2 = run_query(query)
df2.show()
df2.explain(mode="extended")

end_time = time.time()
ref_time = end_time - start_time

#print(f'row count: {df1.count()} vs. {df2.count()}' )
print(f'time ref: {ref_time}\ntime yannakakis: {yannakakis_time}')
# Out:
# +--------------------+-----+
# |                 key|value|
# +--------------------+-----+
# |spark.sql.yannaka...| true|
# +--------------------+-----+
#
# running query:
# select
#
#     /*+ FK(ps_partkey, p_partkey), FK(n_regionkey, r_regionkey), FK(ps_suppkey, s_suppkey), FK(s_nationkey, n_nationkey), PK(ps_partkey, ps_suppkey) */
#
#         median(s_acctbal)
#
# 		from
#
#             part,
#
# 			partsupp,
#
# 			supplier,
#
# 			nation,
#
# 			region
#
# 		where
#
# 			p_partkey = ps_partkey
#
# 			and s_suppkey = ps_suppkey
#
# 			and s_nationkey = n_nationkey
#
# 			and n_regionkey = r_regionkey
#
#             AND p_retailprice >
#
#                 (SELECT avg (p_retailprice) FROM part)
#
#             and r_name IN ('EUROPE', 'ASIA')
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: not applicable to aggregate: Aggregate [avg(p_retailprice#7376) AS avg(p_retailprice)#7368]
# +- Project [p_retailprice#7376]
#    +- InMemoryRelation [p_partkey#7369, p_name#7370, p_mfgr#33, p_brand#34, p_type#7373, p_size#7374, p_container#35, p_retailprice#7376, p_comment#7377], StorageLevel(disk, memory, deserialized, 1 replicas)
#          +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#             +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
#
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: applying yannakakis rewriting to join: Aggregate [toprettystring(percentile(s_acctbal#104, 0.5, 1, 0, 0, false), Some(GMT)) AS toprettystring(median(s_acctbal))#7382]
# +- Project [s_acctbal#104]
#    +- FKHint [[ps_partkey#157L, p_partkey#24], [ps_suppkey#158L, s_suppkey#99], [n_regionkey#472L, r_regionkey#503], [s_nationkey#102L, n_nationkey#470]], [[ps_partkey#157L, ps_suppkey#158L]]
#       +- Join Inner, (n_regionkey#472L = cast(r_regionkey#503 as bigint))
#          :- Join Inner, (s_nationkey#102L = cast(n_nationkey#470 as bigint))
#          :  :- Join Inner, (cast(s_suppkey#99 as bigint) = ps_suppkey#158L)
#          :  :  :- Join Inner, (cast(p_partkey#24 as bigint) = ps_partkey#157L)
#          :  :  :  :- Project [p_partkey#24]
#          :  :  :  :  +- Filter ((isnotnull(p_retailprice#31) AND (cast(p_retailprice#31 as decimal(38,22)) > scalar-subquery#7366 [])) AND isnotnull(p_partkey#24))
#          :  :  :  :     :  +- Aggregate [avg(p_retailprice#7376) AS avg(p_retailprice)#7368]
#          :  :  :  :     :     +- Project [p_retailprice#7376]
#          :  :  :  :     :        +- InMemoryRelation [p_partkey#7369, p_name#7370, p_mfgr#33, p_brand#34, p_type#7373, p_size#7374, p_container#35, p_retailprice#7376, p_comment#7377], StorageLevel(disk, memory, deserialized, 1 replicas)
#          :  :  :  :     :              +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#          :  :  :  :     :                 +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
#          :  :  :  :     +- InMemoryRelation [p_partkey#24, p_name#25, p_mfgr#33, p_brand#34, p_type#28, p_size#29, p_container#35, p_retailprice#31, p_comment#32], StorageLevel(disk, memory, deserialized, 1 replicas)
#          :  :  :  :           +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#          :  :  :  :              +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
#          :  :  :  +- Project [ps_partkey#157L, ps_suppkey#158L]
#          :  :  :     +- Filter (isnotnull(ps_partkey#157L) AND isnotnull(ps_suppkey#158L))
#          :  :  :        +- InMemoryRelation [ps_partkey#157L, ps_suppkey#158L, ps_availqty#159, ps_supplycost#160, ps_comment#161], StorageLevel(disk, memory, deserialized, 1 replicas)
#          :  :  :              +- *(1) Scan JDBCRelation(partsupp) [numPartitions=1] [ps_partkey#157L,ps_suppkey#158L,ps_availqty#159,ps_supplycost#160,ps_comment#161] PushedFilters: [], ReadSchema: struct<ps_partkey:bigint,ps_suppkey:bigint,ps_availqty:int,ps_supplycost:decimal(38,18),ps_commen...
#          :  :  +- Project [s_suppkey#99, s_nationkey#102L, s_acctbal#104]
#          :  :     +- Filter (isnotnull(s_suppkey#99) AND isnotnull(s_nationkey#102L))
#          :  :        +- InMemoryRelation [s_suppkey#99, s_name#106, s_address#101, s_nationkey#102L, s_phone#107, s_acctbal#104, s_comment#105], StorageLevel(disk, memory, deserialized, 1 replicas)
#          :  :              +- *(1) Project [s_suppkey#99, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, s_name#100, 25, true, false, true) AS s_name#106, s_address#101, s_nationkey#102L, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, s_phone#103, 15, true, false, true) AS s_phone#107, s_acctbal#104, s_comment#105]
#          :  :                 +- *(1) Scan JDBCRelation(supplier) [numPartitions=1] [s_suppkey#99,s_name#100,s_address#101,s_nationkey#102L,s_phone#103,s_acctbal#104,s_comment#105] PushedFilters: [], ReadSchema: struct<s_suppkey:int,s_name:string,s_address:string,s_nationkey:bigint,s_phone:string,s_acctbal:d...
#          :  +- Project [n_nationkey#470, n_regionkey#472L]
#          :     +- Filter (isnotnull(n_nationkey#470) AND isnotnull(n_regionkey#472L))
#          :        +- InMemoryRelation [n_nationkey#470, n_name#474, n_regionkey#472L, n_comment#473], StorageLevel(disk, memory, deserialized, 1 replicas)
#          :              +- *(1) Project [n_nationkey#470, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, n_name#471, 25, true, false, true) AS n_name#474, n_regionkey#472L, n_comment#473]
#          :                 +- *(1) Scan JDBCRelation(nation) [numPartitions=1] [n_nationkey#470,n_name#471,n_regionkey#472L,n_comment#473] PushedFilters: [], ReadSchema: struct<n_nationkey:int,n_name:string,n_regionkey:bigint,n_comment:string>
#          +- Project [r_regionkey#503]
#             +- Filter (r_name#506 IN (EUROPE                   ,ASIA                     ) AND isnotnull(r_regionkey#503))
#                +- InMemoryRelation [r_regionkey#503, r_name#506, r_comment#505], StorageLevel(disk, memory, deserialized, 1 replicas)
#                      +- *(1) Project [r_regionkey#503, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, r_name#504, 25, true, false, true) AS r_name#506, r_comment#505]
#                         +- *(1) Scan JDBCRelation(region) [numPartitions=1] [r_regionkey#503,r_name#504,r_comment#505] PushedFilters: [], ReadSchema: struct<r_regionkey:int,r_name:string,r_comment:string>
#
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: agg(project(join))
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: items: List(Project [p_partkey#24]
# +- Filter ((isnotnull(p_retailprice#31) AND (cast(p_retailprice#31 as decimal(38,22)) > scalar-subquery#7366 [])) AND isnotnull(p_partkey#24))
#    :  +- Aggregate [avg(p_retailprice#7376) AS avg(p_retailprice)#7368]
#    :     +- Project [p_retailprice#7376]
#    :        +- InMemoryRelation [p_partkey#7369, p_name#7370, p_mfgr#33, p_brand#34, p_type#7373, p_size#7374, p_container#35, p_retailprice#7376, p_comment#7377], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :              +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#    :                 +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
#    +- InMemoryRelation [p_partkey#24, p_name#25, p_mfgr#33, p_brand#34, p_type#28, p_size#29, p_container#35, p_retailprice#31, p_comment#32], StorageLevel(disk, memory, deserialized, 1 replicas)
#          +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#             +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
# , Project [ps_partkey#157L, ps_suppkey#158L]
# +- Filter (isnotnull(ps_partkey#157L) AND isnotnull(ps_suppkey#158L))
#    +- InMemoryRelation [ps_partkey#157L, ps_suppkey#158L, ps_availqty#159, ps_supplycost#160, ps_comment#161], StorageLevel(disk, memory, deserialized, 1 replicas)
#          +- *(1) Scan JDBCRelation(partsupp) [numPartitions=1] [ps_partkey#157L,ps_suppkey#158L,ps_availqty#159,ps_supplycost#160,ps_comment#161] PushedFilters: [], ReadSchema: struct<ps_partkey:bigint,ps_suppkey:bigint,ps_availqty:int,ps_supplycost:decimal(38,18),ps_commen...
# , Project [s_suppkey#99, s_nationkey#102L, s_acctbal#104]
# +- Filter (isnotnull(s_suppkey#99) AND isnotnull(s_nationkey#102L))
#    +- InMemoryRelation [s_suppkey#99, s_name#106, s_address#101, s_nationkey#102L, s_phone#107, s_acctbal#104, s_comment#105], StorageLevel(disk, memory, deserialized, 1 replicas)
#          +- *(1) Project [s_suppkey#99, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, s_name#100, 25, true, false, true) AS s_name#106, s_address#101, s_nationkey#102L, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, s_phone#103, 15, true, false, true) AS s_phone#107, s_acctbal#104, s_comment#105]
#             +- *(1) Scan JDBCRelation(supplier) [numPartitions=1] [s_suppkey#99,s_name#100,s_address#101,s_nationkey#102L,s_phone#103,s_acctbal#104,s_comment#105] PushedFilters: [], ReadSchema: struct<s_suppkey:int,s_name:string,s_address:string,s_nationkey:bigint,s_phone:string,s_acctbal:d...
# , Project [n_nationkey#470, n_regionkey#472L]
# +- Filter (isnotnull(n_nationkey#470) AND isnotnull(n_regionkey#472L))
#    +- InMemoryRelation [n_nationkey#470, n_name#474, n_regionkey#472L, n_comment#473], StorageLevel(disk, memory, deserialized, 1 replicas)
#          +- *(1) Project [n_nationkey#470, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, n_name#471, 25, true, false, true) AS n_name#474, n_regionkey#472L, n_comment#473]
#             +- *(1) Scan JDBCRelation(nation) [numPartitions=1] [n_nationkey#470,n_name#471,n_regionkey#472L,n_comment#473] PushedFilters: [], ReadSchema: struct<n_nationkey:int,n_name:string,n_regionkey:bigint,n_comment:string>
# , Project [r_regionkey#503]
# +- Filter (r_name#506 IN (EUROPE                   ,ASIA                     ) AND isnotnull(r_regionkey#503))
#    +- InMemoryRelation [r_regionkey#503, r_name#506, r_comment#505], StorageLevel(disk, memory, deserialized, 1 replicas)
#          +- *(1) Project [r_regionkey#503, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, r_name#504, 25, true, false, true) AS r_name#506, r_comment#505]
#             +- *(1) Scan JDBCRelation(region) [numPartitions=1] [r_regionkey#503,r_name#504,r_comment#505] PushedFilters: [], ReadSchema: struct<r_regionkey:int,r_name:string,r_comment:string>
# )
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: conditions: Set((cast(p_partkey#24 as bigint) = ps_partkey#157L), (cast(s_suppkey#99 as bigint) = ps_suppkey#158L), (s_nationkey#102L = cast(n_nationkey#470 as bigint)), (n_regionkey#472L = cast(r_regionkey#503 as bigint)))
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: agg: toprettystring(percentile(s_acctbal#104, 0.5, 1, 0, 0, false), Some(GMT)) AS toprettystring(median(s_acctbal))#7382
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: is 0MA: false
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: is counting: false
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: is percentile: true
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: is sum: false
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: is avg: false
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: is non-agg: false
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: aggregate attributes: {s_acctbal#104}
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: groupingExpressions: List()
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: group attributes: {}
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: counting aggregates: List()
# 23/11/11 22:10:23 WARN Hypergraph: equivalence classes: Set(Set(p_partkey#24, ps_partkey#157L), Set(s_suppkey#99, ps_suppkey#158L), Set(s_nationkey#102L, n_nationkey#470), Set(n_regionkey#472L, r_regionkey#503))
# 23/11/11 22:10:23 WARN Hypergraph: vertex to attribute mapping: Map(s_suppkey#99 -> Set(s_suppkey#99, ps_suppkey#158L), s_nationkey#102L -> Set(s_nationkey#102L, n_nationkey#470), n_regionkey#472L -> Set(n_regionkey#472L, r_regionkey#503), p_partkey#24 -> Set(p_partkey#24, ps_partkey#157L))
# 23/11/11 22:10:23 WARN Hypergraph: attribute to vertex mapping: Map(ExprId(472,927460b1-0459-4f49-b47f-e413f7a55c65) -> n_regionkey#472L, ExprId(158,927460b1-0459-4f49-b47f-e413f7a55c65) -> s_suppkey#99, ExprId(157,927460b1-0459-4f49-b47f-e413f7a55c65) -> p_partkey#24, ExprId(503,927460b1-0459-4f49-b47f-e413f7a55c65) -> n_regionkey#472L, ExprId(470,927460b1-0459-4f49-b47f-e413f7a55c65) -> s_nationkey#102L, ExprId(99,927460b1-0459-4f49-b47f-e413f7a55c65) -> s_suppkey#99, ExprId(102,927460b1-0459-4f49-b47f-e413f7a55c65) -> s_nationkey#102L, ExprId(24,927460b1-0459-4f49-b47f-e413f7a55c65) -> p_partkey#24)
# 23/11/11 22:10:23 WARN Hypergraph: join item: Project [p_partkey#24]
# +- Filter ((isnotnull(p_retailprice#31) AND (cast(p_retailprice#31 as decimal(38,22)) > scalar-subquery#7366 [])) AND isnotnull(p_partkey#24))
#    :  +- Aggregate [avg(p_retailprice#7376) AS avg(p_retailprice)#7368]
#    :     +- Project [p_retailprice#7376]
#    :        +- InMemoryRelation [p_partkey#7369, p_name#7370, p_mfgr#33, p_brand#34, p_type#7373, p_size#7374, p_container#35, p_retailprice#7376, p_comment#7377], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :              +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#    :                 +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
#    +- InMemoryRelation [p_partkey#24, p_name#25, p_mfgr#33, p_brand#34, p_type#28, p_size#29, p_container#35, p_retailprice#31, p_comment#32], StorageLevel(disk, memory, deserialized, 1 replicas)
#          +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#             +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
#
# 23/11/11 22:10:23 WARN Hypergraph: join item: Project [ps_partkey#157L, ps_suppkey#158L]
# +- Filter (isnotnull(ps_partkey#157L) AND isnotnull(ps_suppkey#158L))
#    +- InMemoryRelation [ps_partkey#157L, ps_suppkey#158L, ps_availqty#159, ps_supplycost#160, ps_comment#161], StorageLevel(disk, memory, deserialized, 1 replicas)
#          +- *(1) Scan JDBCRelation(partsupp) [numPartitions=1] [ps_partkey#157L,ps_suppkey#158L,ps_availqty#159,ps_supplycost#160,ps_comment#161] PushedFilters: [], ReadSchema: struct<ps_partkey:bigint,ps_suppkey:bigint,ps_availqty:int,ps_supplycost:decimal(38,18),ps_commen...
#
# 23/11/11 22:10:23 WARN Hypergraph: join item: Project [s_suppkey#99, s_nationkey#102L, s_acctbal#104]
# +- Filter (isnotnull(s_suppkey#99) AND isnotnull(s_nationkey#102L))
#    +- InMemoryRelation [s_suppkey#99, s_name#106, s_address#101, s_nationkey#102L, s_phone#107, s_acctbal#104, s_comment#105], StorageLevel(disk, memory, deserialized, 1 replicas)
#          +- *(1) Project [s_suppkey#99, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, s_name#100, 25, true, false, true) AS s_name#106, s_address#101, s_nationkey#102L, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, s_phone#103, 15, true, false, true) AS s_phone#107, s_acctbal#104, s_comment#105]
#             +- *(1) Scan JDBCRelation(supplier) [numPartitions=1] [s_suppkey#99,s_name#100,s_address#101,s_nationkey#102L,s_phone#103,s_acctbal#104,s_comment#105] PushedFilters: [], ReadSchema: struct<s_suppkey:int,s_name:string,s_address:string,s_nationkey:bigint,s_phone:string,s_acctbal:d...
#
# 23/11/11 22:10:23 WARN Hypergraph: join item: Project [n_nationkey#470, n_regionkey#472L]
# +- Filter (isnotnull(n_nationkey#470) AND isnotnull(n_regionkey#472L))
#    +- InMemoryRelation [n_nationkey#470, n_name#474, n_regionkey#472L, n_comment#473], StorageLevel(disk, memory, deserialized, 1 replicas)
#          +- *(1) Project [n_nationkey#470, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, n_name#471, 25, true, false, true) AS n_name#474, n_regionkey#472L, n_comment#473]
#             +- *(1) Scan JDBCRelation(nation) [numPartitions=1] [n_nationkey#470,n_name#471,n_regionkey#472L,n_comment#473] PushedFilters: [], ReadSchema: struct<n_nationkey:int,n_name:string,n_regionkey:bigint,n_comment:string>
#
# 23/11/11 22:10:23 WARN Hypergraph: join item: Project [r_regionkey#503]
# +- Filter (r_name#506 IN (EUROPE                   ,ASIA                     ) AND isnotnull(r_regionkey#503))
#    +- InMemoryRelation [r_regionkey#503, r_name#506, r_comment#505], StorageLevel(disk, memory, deserialized, 1 replicas)
#          +- *(1) Project [r_regionkey#503, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, r_name#504, 25, true, false, true) AS r_name#506, r_comment#505]
#             +- *(1) Scan JDBCRelation(region) [numPartitions=1] [r_regionkey#503,r_name#504,r_comment#505] PushedFilters: [], ReadSchema: struct<r_regionkey:int,r_name:string,r_comment:string>
#
# 23/11/11 22:10:23 WARN Hypergraph: hyperedges: Set(E2(p_partkey#24, s_suppkey#99), E4(s_nationkey#102L, n_regionkey#472L), E3(s_suppkey#99, s_nationkey#102L), E5(n_regionkey#472L), E1(p_partkey#24))
# 23/11/11 22:10:23 WARN Hypergraph: gyo edge: E1(p_partkey#24)
# 23/11/11 22:10:23 WARN Hypergraph: supersets: Set(E2(p_partkey#24, s_suppkey#99))
# 23/11/11 22:10:23 WARN Hypergraph: gyo edge: E2(p_partkey#24, s_suppkey#99)
# 23/11/11 22:10:23 WARN Hypergraph: supersets: Set()
# 23/11/11 22:10:23 WARN Hypergraph: parentNode: TreeNode(Set(E2(p_partkey#24, s_suppkey#99)))[Set({ps_partkey#157L, ps_suppkey#158L})] [[parent: false]]
#
# 23/11/11 22:10:23 WARN Hypergraph: subsets: Set(TreeNode(Set(E1(p_partkey#24)))[Set({p_partkey#24})] [[parent: false]]
# )
# 23/11/11 22:10:23 WARN Hypergraph: gyo edge: E3(s_suppkey#99, s_nationkey#102L)
# 23/11/11 22:10:23 WARN Hypergraph: supersets: Set()
# 23/11/11 22:10:23 WARN Hypergraph: parentNode: TreeNode(Set(E3(s_suppkey#99, s_nationkey#102L)))[Set({s_suppkey#99, s_nationkey#102L, s_acctbal#104})] [[parent: false]]
#
# 23/11/11 22:10:23 WARN Hypergraph: subsets: Set()
# 23/11/11 22:10:23 WARN Hypergraph: gyo edge: E4(s_nationkey#102L, n_regionkey#472L)
# 23/11/11 22:10:23 WARN Hypergraph: supersets: Set()
# 23/11/11 22:10:23 WARN Hypergraph: parentNode: TreeNode(Set(E4(s_nationkey#102L, n_regionkey#472L)))[Set({n_nationkey#470, n_regionkey#472L})] [[parent: false]]
#
# 23/11/11 22:10:23 WARN Hypergraph: subsets: Set(TreeNode(Set(E5(n_regionkey#472L)))[Set({r_regionkey#503})] [[parent: false]]
# )
# 23/11/11 22:10:23 WARN Hypergraph: gyo edge: E3(s_suppkey#99, s_nationkey#102L)
# 23/11/11 22:10:23 WARN Hypergraph: supersets: Set()
# 23/11/11 22:10:23 WARN Hypergraph: parentNode: TreeNode(Set(E3(s_suppkey#99, s_nationkey#102L)))[Set({s_suppkey#99, s_nationkey#102L, s_acctbal#104})] [[parent: false]]
#
# 23/11/11 22:10:23 WARN Hypergraph: subsets: Set(TreeNode(Set(E2(p_partkey#24, s_suppkey#99)))[Set({ps_partkey#157L, ps_suppkey#158L})] [[parent: false]]
# -- TreeNode(Set(E1(p_partkey#24)))[Set({p_partkey#24})] [[parent: true]]
# , TreeNode(Set(E4(s_nationkey#102L, n_regionkey#472L)))[Set({n_nationkey#470, n_regionkey#472L})] [[parent: false]]
# -- TreeNode(Set(E5(n_regionkey#472L)))[Set({r_regionkey#503})] [[parent: true]]
# )
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: join tree:
# TreeNode(Set(E3(s_suppkey#99, s_nationkey#102L)))[Set({s_suppkey#99, s_nationkey#102L, s_acctbal#104})] [[parent: false]]
# -- TreeNode(Set(E2(p_partkey#24, s_suppkey#99)))[Set({ps_partkey#157L, ps_suppkey#158L})] [[parent: true]]
# -- -- TreeNode(Set(E1(p_partkey#24)))[Set({p_partkey#24})] [[parent: true]]
#
# -- TreeNode(Set(E4(s_nationkey#102L, n_regionkey#472L)))[Set({n_nationkey#470, n_regionkey#472L})] [[parent: true]]
# -- -- TreeNode(Set(E5(n_regionkey#472L)))[Set({r_regionkey#503})] [[parent: true]]
#
# 23/11/11 22:10:23 WARN HTNode: aggAttributes: {s_acctbal#104}
# 23/11/11 22:10:23 WARN HTNode: nodeAttributes: {s_suppkey#99, s_nationkey#102L, s_acctbal#104}
# 23/11/11 22:10:23 WARN HTNode: found subset in:
# TreeNode(Set(E3(s_suppkey#99, s_nationkey#102L)))[Set({s_suppkey#99, s_nationkey#102L, s_acctbal#104})] [[parent: false]]
# -- TreeNode(Set(E2(p_partkey#24, s_suppkey#99)))[Set({ps_partkey#157L, ps_suppkey#158L})] [[parent: true]]
# -- -- TreeNode(Set(E1(p_partkey#24)))[Set({p_partkey#24})] [[parent: true]]
#
# -- TreeNode(Set(E4(s_nationkey#102L, n_regionkey#472L)))[Set({n_nationkey#470, n_regionkey#472L})] [[parent: true]]
# -- -- TreeNode(Set(E5(n_regionkey#472L)))[Set({r_regionkey#503})] [[parent: true]]
#
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: rerooted:
# TreeNode(Set(E3(s_suppkey#99, s_nationkey#102L)))[Set({s_suppkey#99, s_nationkey#102L, s_acctbal#104})] [[parent: false]]
# -- TreeNode(Set(E2(p_partkey#24, s_suppkey#99)))[Set({ps_partkey#157L, ps_suppkey#158L})] [[parent: true]]
# -- -- TreeNode(Set(E1(p_partkey#24)))[Set({p_partkey#24})] [[parent: true]]
#
# -- TreeNode(Set(E4(s_nationkey#102L, n_regionkey#472L)))[Set({n_nationkey#470, n_regionkey#472L})] [[parent: true]]
# -- -- TreeNode(Set(E5(n_regionkey#472L)))[Set({r_regionkey#503})] [[parent: true]]
#
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: percentile aggregates: List(toprettystring(percentile(s_acctbal#104, 0.5, 1, 0, 0, false), Some(GMT)) AS toprettystring(median(s_acctbal))#7382)
# 23/11/11 22:10:23 WARN HTNode: keyRefs: List(List(ps_partkey#157L, p_partkey#24), List(ps_suppkey#158L, s_suppkey#99), List(n_regionkey#472L, r_regionkey#503), List(s_nationkey#102L, n_nationkey#470))
# 23/11/11 22:10:23 WARN HTNode: edge: E2(p_partkey#24, s_suppkey#99)
# 23/11/11 22:10:23 WARN HTNode: overlapping vertices: Set((ps_partkey#157L,p_partkey#24))
# 23/11/11 22:10:23 WARN HTNode: can semi join: true
# 23/11/11 22:10:23 WARN HTNode: join output: List(ps_partkey#157L, ps_suppkey#158L, c#7755L)
# 23/11/11 22:10:23 WARN HTNode: keyRefs: List(List(ps_partkey#157L, p_partkey#24), List(ps_suppkey#158L, s_suppkey#99), List(n_regionkey#472L, r_regionkey#503), List(s_nationkey#102L, n_nationkey#470))
# 23/11/11 22:10:23 WARN HTNode: edge: E3(s_suppkey#99, s_nationkey#102L)
# 23/11/11 22:10:23 WARN HTNode: overlapping vertices: Set((s_suppkey#99,ps_suppkey#158L))
# 23/11/11 22:10:23 WARN HTNode: can semi join: false
# 23/11/11 22:10:23 WARN HTNode: join output: List(s_suppkey#99, s_nationkey#102L, s_acctbal#104, c#7754L, c#7764L, ps_suppkey#158L)
# 23/11/11 22:10:23 WARN HTNode: keyRefs: List(List(ps_partkey#157L, p_partkey#24), List(ps_suppkey#158L, s_suppkey#99), List(n_regionkey#472L, r_regionkey#503), List(s_nationkey#102L, n_nationkey#470))
# 23/11/11 22:10:23 WARN HTNode: edge: E4(s_nationkey#102L, n_regionkey#472L)
# 23/11/11 22:10:23 WARN HTNode: overlapping vertices: Set((n_regionkey#472L,r_regionkey#503))
# 23/11/11 22:10:23 WARN HTNode: can semi join: true
# 23/11/11 22:10:23 WARN HTNode: join output: List(n_nationkey#470, n_regionkey#472L, c#7766L)
# 23/11/11 22:10:23 WARN HTNode: keyRefs: List(List(ps_partkey#157L, p_partkey#24), List(ps_suppkey#158L, s_suppkey#99), List(n_regionkey#472L, r_regionkey#503), List(s_nationkey#102L, n_nationkey#470))
# 23/11/11 22:10:23 WARN HTNode: edge: E3(s_suppkey#99, s_nationkey#102L)
# 23/11/11 22:10:23 WARN HTNode: overlapping vertices: Set((s_nationkey#102L,n_nationkey#470))
# 23/11/11 22:10:23 WARN HTNode: can semi join: true
# 23/11/11 22:10:23 WARN HTNode: join output: List(c#7765L, s_suppkey#99, s_nationkey#102L, s_acctbal#104, c#7754L, c#7764L, ps_suppkey#158L)
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: new aggregate: Aggregate [toprettystring(percentile(s_acctbal#104, 0.5, c#7765L, 0, 0, false), Some(GMT)) AS toprettystring(median(s_acctbal))#7382]
# +- Project [s_acctbal#104, c#7765L]
#    +- Project [c#7765L, s_suppkey#99, s_nationkey#102L, s_acctbal#104, c#7754L, c#7764L, ps_suppkey#158L]
#       +- Join LeftSemi, (s_nationkey#102L = cast(n_nationkey#470 as bigint))
#          :- Project [(cast(c#7754L as bigint) * c#7764L) AS c#7765L, s_suppkey#99, s_nationkey#102L, s_acctbal#104, c#7754L, c#7764L, ps_suppkey#158L]
#          :  +- Join Inner, (s_suppkey#99 = cast(ps_suppkey#158L as int))
#          :     :- Project [s_suppkey#99, s_nationkey#102L, s_acctbal#104, 1 AS c#7754L]
#          :     :  +- Project [s_suppkey#99, s_nationkey#102L, s_acctbal#104]
#          :     :     +- Filter (isnotnull(s_suppkey#99) AND isnotnull(s_nationkey#102L))
#          :     :        +- InMemoryRelation [s_suppkey#99, s_name#106, s_address#101, s_nationkey#102L, s_phone#107, s_acctbal#104, s_comment#105], StorageLevel(disk, memory, deserialized, 1 replicas)
#          :     :              +- *(1) Project [s_suppkey#99, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, s_name#100, 25, true, false, true) AS s_name#106, s_address#101, s_nationkey#102L, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, s_phone#103, 15, true, false, true) AS s_phone#107, s_acctbal#104, s_comment#105]
#          :     :                 +- *(1) Scan JDBCRelation(supplier) [numPartitions=1] [s_suppkey#99,s_name#100,s_address#101,s_nationkey#102L,s_phone#103,s_acctbal#104,s_comment#105] PushedFilters: [], ReadSchema: struct<s_suppkey:int,s_name:string,s_address:string,s_nationkey:bigint,s_phone:string,s_acctbal:d...
#          :     +- Aggregate [ps_suppkey#158L], [sum(c#7755L) AS c#7764L, ps_suppkey#158L]
#          :        +- Project [ps_partkey#157L, ps_suppkey#158L, c#7755L]
#          :           +- Join LeftSemi, (ps_partkey#157L = cast(p_partkey#24 as bigint))
#          :              :- Project [ps_partkey#157L, ps_suppkey#158L, 1 AS c#7755L]
#          :              :  +- Project [ps_partkey#157L, ps_suppkey#158L]
#          :              :     +- Filter (isnotnull(ps_partkey#157L) AND isnotnull(ps_suppkey#158L))
#          :              :        +- InMemoryRelation [ps_partkey#157L, ps_suppkey#158L, ps_availqty#159, ps_supplycost#160, ps_comment#161], StorageLevel(disk, memory, deserialized, 1 replicas)
#          :              :              +- *(1) Scan JDBCRelation(partsupp) [numPartitions=1] [ps_partkey#157L,ps_suppkey#158L,ps_availqty#159,ps_supplycost#160,ps_comment#161] PushedFilters: [], ReadSchema: struct<ps_partkey:bigint,ps_suppkey:bigint,ps_availqty:int,ps_supplycost:decimal(38,18),ps_commen...
#          :              +- Project [p_partkey#24, 1 AS c#7756L]
#          :                 +- Project [p_partkey#24]
#          :                    +- Filter ((isnotnull(p_retailprice#31) AND (cast(p_retailprice#31 as decimal(38,22)) > scalar-subquery#7366 [])) AND isnotnull(p_partkey#24))
#          :                       :  +- Aggregate [avg(p_retailprice#7376) AS avg(p_retailprice)#7368]
#          :                       :     +- Project [p_retailprice#7376]
#          :                       :        +- InMemoryRelation [p_partkey#7369, p_name#7370, p_mfgr#33, p_brand#34, p_type#7373, p_size#7374, p_container#35, p_retailprice#7376, p_comment#7377], StorageLevel(disk, memory, deserialized, 1 replicas)
#          :                       :              +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#          :                       :                 +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
#          :                       +- InMemoryRelation [p_partkey#24, p_name#25, p_mfgr#33, p_brand#34, p_type#28, p_size#29, p_container#35, p_retailprice#31, p_comment#32], StorageLevel(disk, memory, deserialized, 1 replicas)
#          :                             +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#          :                                +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
#          +- Project [n_nationkey#470, n_regionkey#472L, c#7766L]
#             +- Join LeftSemi, (n_regionkey#472L = cast(r_regionkey#503 as bigint))
#                :- Project [n_nationkey#470, n_regionkey#472L, 1 AS c#7766L]
#                :  +- Project [n_nationkey#470, n_regionkey#472L]
#                :     +- Filter (isnotnull(n_nationkey#470) AND isnotnull(n_regionkey#472L))
#                :        +- InMemoryRelation [n_nationkey#470, n_name#474, n_regionkey#472L, n_comment#473], StorageLevel(disk, memory, deserialized, 1 replicas)
#                :              +- *(1) Project [n_nationkey#470, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, n_name#471, 25, true, false, true) AS n_name#474, n_regionkey#472L, n_comment#473]
#                :                 +- *(1) Scan JDBCRelation(nation) [numPartitions=1] [n_nationkey#470,n_name#471,n_regionkey#472L,n_comment#473] PushedFilters: [], ReadSchema: struct<n_nationkey:int,n_name:string,n_regionkey:bigint,n_comment:string>
#                +- Project [r_regionkey#503, 1 AS c#7767L]
#                   +- Project [r_regionkey#503]
#                      +- Filter (r_name#506 IN (EUROPE                   ,ASIA                     ) AND isnotnull(r_regionkey#503))
#                         +- InMemoryRelation [r_regionkey#503, r_name#506, r_comment#505], StorageLevel(disk, memory, deserialized, 1 replicas)
#                               +- *(1) Project [r_regionkey#503, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, r_name#504, 25, true, false, true) AS r_name#506, r_comment#505]
#                                  +- *(1) Scan JDBCRelation(region) [numPartitions=1] [r_regionkey#503,r_name#504,r_comment#505] PushedFilters: [], ReadSchema: struct<r_regionkey:int,r_name:string,r_comment:string>
#
# 23/11/11 22:10:23 WARN RewriteJoinsAsSemijoins: not applicable to aggregate: Aggregate [ps_suppkey#158L], [sum(c#7755L) AS c#7764L, ps_suppkey#158L]
# +- Project [ps_partkey#157L, ps_suppkey#158L, c#7755L]
#    +- Join LeftSemi, (ps_partkey#157L = cast(p_partkey#24 as bigint))
#       :- Project [ps_partkey#157L, ps_suppkey#158L, 1 AS c#7755L]
#       :  +- Project [ps_partkey#157L, ps_suppkey#158L]
#       :     +- Filter (isnotnull(ps_partkey#157L) AND isnotnull(ps_suppkey#158L))
#       :        +- InMemoryRelation [ps_partkey#157L, ps_suppkey#158L, ps_availqty#159, ps_supplycost#160, ps_comment#161], StorageLevel(disk, memory, deserialized, 1 replicas)
#       :              +- *(1) Scan JDBCRelation(partsupp) [numPartitions=1] [ps_partkey#157L,ps_suppkey#158L,ps_availqty#159,ps_supplycost#160,ps_comment#161] PushedFilters: [], ReadSchema: struct<ps_partkey:bigint,ps_suppkey:bigint,ps_availqty:int,ps_supplycost:decimal(38,18),ps_commen...
#       +- Project [p_partkey#24, 1 AS c#7756L]
#          +- Project [p_partkey#24]
#             +- Filter ((isnotnull(p_retailprice#31) AND (cast(p_retailprice#31 as decimal(38,22)) > scalar-subquery#7366 [])) AND isnotnull(p_partkey#24))
#                :  +- Aggregate [avg(p_retailprice#7376) AS avg(p_retailprice)#7368]
#                :     +- Project [p_retailprice#7376]
#                :        +- InMemoryRelation [p_partkey#7369, p_name#7370, p_mfgr#33, p_brand#34, p_type#7373, p_size#7374, p_container#35, p_retailprice#7376, p_comment#7377], StorageLevel(disk, memory, deserialized, 1 replicas)
#                :              +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#                :                 +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
#                +- InMemoryRelation [p_partkey#24, p_name#25, p_mfgr#33, p_brand#34, p_type#28, p_size#29, p_container#35, p_retailprice#31, p_comment#32], StorageLevel(disk, memory, deserialized, 1 replicas)
#                      +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#                         +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
#
# 23/11/11 22:10:50 WARN RewriteJoinsAsSemijoins: not applicable to aggregate: Aggregate [avg(p_retailprice#7376) AS avg(p_retailprice)#7368]
# +- Project [p_retailprice#7376]
#    +- InMemoryRelation [p_partkey#7369, p_name#7370, p_mfgr#33, p_brand#34, p_type#7373, p_size#7374, p_container#35, p_retailprice#7376, p_comment#7377], StorageLevel(disk, memory, deserialized, 1 replicas)
#          +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#             +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
#
# 23/11/11 22:10:50 WARN RewriteJoinsAsSemijoins: applying yannakakis rewriting to join: Aggregate [percentile(s_acctbal#104, 0.5, 1, 0, 0, false) AS median(s_acctbal)#7379]
# +- Project [s_acctbal#104]
#    +- FKHint [[ps_partkey#157L, p_partkey#24], [ps_suppkey#158L, s_suppkey#99], [n_regionkey#472L, r_regionkey#503], [s_nationkey#102L, n_nationkey#470]], [[ps_partkey#157L, ps_suppkey#158L]]
#       +- Join Inner, (n_regionkey#472L = cast(r_regionkey#503 as bigint))
#          :- Join Inner, (s_nationkey#102L = cast(n_nationkey#470 as bigint))
#          :  :- Join Inner, (cast(s_suppkey#99 as bigint) = ps_suppkey#158L)
#          :  :  :- Join Inner, (cast(p_partkey#24 as bigint) = ps_partkey#157L)
#          :  :  :  :- Project [p_partkey#24]
#          :  :  :  :  +- Filter ((isnotnull(p_retailprice#31) AND (cast(p_retailprice#31 as decimal(38,22)) > scalar-subquery#7366 [])) AND isnotnull(p_partkey#24))
#          :  :  :  :     :  +- Aggregate [avg(p_retailprice#7376) AS avg(p_retailprice)#7368]
#          :  :  :  :     :     +- Project [p_retailprice#7376]
#          :  :  :  :     :        +- InMemoryRelation [p_partkey#7369, p_name#7370, p_mfgr#33, p_brand#34, p_type#7373, p_size#7374, p_container#35, p_retailprice#7376, p_comment#7377], StorageLevel(disk, memory, deserialized, 1 replicas)
#          :  :  :  :     :              +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#          :  :  :  :     :                 +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
#          :  :  :  :     +- InMemoryRelation [p_partkey#24, p_name#25, p_mfgr#33, p_brand#34, p_type#28, p_size#29, p_container#35, p_retailprice#31, p_comment#32], StorageLevel(disk, memory, deserialized, 1 replicas)
#          :  :  :  :           +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#          :  :  :  :              +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
#          :  :  :  +- Project [ps_partkey#157L, ps_suppkey#158L]
#          :  :  :     +- Filter (isnotnull(ps_partkey#157L) AND isnotnull(ps_suppkey#158L))
#          :  :  :        +- InMemoryRelation [ps_partkey#157L, ps_suppkey#158L, ps_availqty#159, ps_supplycost#160, ps_comment#161], StorageLevel(disk, memory, deserialized, 1 replicas)
#          :  :  :              +- *(1) Scan JDBCRelation(partsupp) [numPartitions=1] [ps_partkey#157L,ps_suppkey#158L,ps_availqty#159,ps_supplycost#160,ps_comment#161] PushedFilters: [], ReadSchema: struct<ps_partkey:bigint,ps_suppkey:bigint,ps_availqty:int,ps_supplycost:decimal(38,18),ps_commen...
#          :  :  +- Project [s_suppkey#99, s_nationkey#102L, s_acctbal#104]
#          :  :     +- Filter (isnotnull(s_suppkey#99) AND isnotnull(s_nationkey#102L))
#          :  :        +- InMemoryRelation [s_suppkey#99, s_name#106, s_address#101, s_nationkey#102L, s_phone#107, s_acctbal#104, s_comment#105], StorageLevel(disk, memory, deserialized, 1 replicas)
#          :  :              +- *(1) Project [s_suppkey#99, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, s_name#100, 25, true, false, true) AS s_name#106, s_address#101, s_nationkey#102L, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, s_phone#103, 15, true, false, true) AS s_phone#107, s_acctbal#104, s_comment#105]
#          :  :                 +- *(1) Scan JDBCRelation(supplier) [numPartitions=1] [s_suppkey#99,s_name#100,s_address#101,s_nationkey#102L,s_phone#103,s_acctbal#104,s_comment#105] PushedFilters: [], ReadSchema: struct<s_suppkey:int,s_name:string,s_address:string,s_nationkey:bigint,s_phone:string,s_acctbal:d...
#          :  +- Project [n_nationkey#470, n_regionkey#472L]
#          :     +- Filter (isnotnull(n_nationkey#470) AND isnotnull(n_regionkey#472L))
#          :        +- InMemoryRelation [n_nationkey#470, n_name#474, n_regionkey#472L, n_comment#473], StorageLevel(disk, memory, deserialized, 1 replicas)
#          :              +- *(1) Project [n_nationkey#470, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, n_name#471, 25, true, false, true) AS n_name#474, n_regionkey#472L, n_comment#473]
#          :                 +- *(1) Scan JDBCRelation(nation) [numPartitions=1] [n_nationkey#470,n_name#471,n_regionkey#472L,n_comment#473] PushedFilters: [], ReadSchema: struct<n_nationkey:int,n_name:string,n_regionkey:bigint,n_comment:string>
#          +- Project [r_regionkey#503]
#             +- Filter (r_name#506 IN (EUROPE                   ,ASIA                     ) AND isnotnull(r_regionkey#503))
#                +- InMemoryRelation [r_regionkey#503, r_name#506, r_comment#505], StorageLevel(disk, memory, deserialized, 1 replicas)
#                      +- *(1) Project [r_regionkey#503, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, r_name#504, 25, true, false, true) AS r_name#506, r_comment#505]
#                         +- *(1) Scan JDBCRelation(region) [numPartitions=1] [r_regionkey#503,r_name#504,r_comment#505] PushedFilters: [], ReadSchema: struct<r_regionkey:int,r_name:string,r_comment:string>
#
# 23/11/11 22:10:50 WARN RewriteJoinsAsSemijoins: agg(project(join))
# 23/11/11 22:10:50 WARN RewriteJoinsAsSemijoins: items: List(Project [p_partkey#24]
# ...
# AdaptiveSparkPlan isFinalPlan=false
# +- ObjectHashAggregate(keys=[], functions=[percentile(s_acctbal#104, 0.5, 1, 0, 0, false)], output=[median(s_acctbal)#9068])
#    +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=8039]
#       +- ObjectHashAggregate(keys=[], functions=[partial_percentile(s_acctbal#104, 0.5, 1, 0, 0, false)], output=[buf#9605])
#          +- Project [s_acctbal#104]
#             +- BroadcastHashJoin [n_regionkey#472L], [cast(r_regionkey#503 as bigint)], Inner, BuildRight, false
#                :- Project [s_acctbal#104, n_regionkey#472L]
#                :  +- BroadcastHashJoin [s_nationkey#102L], [cast(n_nationkey#470 as bigint)], Inner, BuildRight, false
#                :     :- Project [s_nationkey#102L, s_acctbal#104]
#                :     :  +- SortMergeJoin [ps_suppkey#158L], [cast(s_suppkey#99 as bigint)], Inner
#                :     :     :- Sort [ps_suppkey#158L ASC NULLS FIRST], false, 0
#                :     :     :  +- Exchange hashpartitioning(ps_suppkey#158L, 200), ENSURE_REQUIREMENTS, [plan_id=8023]
#                :     :     :     +- Project [ps_suppkey#158L]
#                :     :     :        +- SortMergeJoin [cast(p_partkey#24 as bigint)], [ps_partkey#157L], Inner
#                :     :     :           :- Sort [cast(p_partkey#24 as bigint) ASC NULLS FIRST], false, 0
#                :     :     :           :  +- Exchange hashpartitioning(cast(p_partkey#24 as bigint), 200), ENSURE_REQUIREMENTS, [plan_id=8015]
#                :     :     :           :     +- Project [p_partkey#24]
#                :     :     :           :        +- Filter ((isnotnull(p_retailprice#31) AND (cast(p_retailprice#31 as decimal(38,22)) > Subquery subquery#9055, [id=#7992])) AND isnotnull(p_partkey#24))
#                :     :     :           :           :  +- Subquery subquery#9055, [id=#7992]
#                :     :     :           :           :     +- AdaptiveSparkPlan isFinalPlan=false
#                :     :     :           :           :        +- HashAggregate(keys=[], functions=[avg(p_retailprice#9065)], output=[avg(p_retailprice)#9057])
#                :     :     :           :           :           +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=7978]
#                :     :     :           :           :              +- HashAggregate(keys=[], functions=[partial_avg(p_retailprice#9065)], output=[sum#9651, count#9652L])
#                :     :     :           :           :                 +- Scan In-memory table part [p_retailprice#9065]
#                :     :     :           :           :                       +- InMemoryRelation [p_partkey#9058, p_name#9059, p_mfgr#33, p_brand#34, p_type#9062, p_size#9063, p_container#35, p_retailprice#9065, p_comment#9066], StorageLevel(disk, memory, deserialized, 1 replicas)
#                :     :     :           :           :                             +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#                :     :     :           :           :                                +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
#                :     :     :           :           +- Scan In-memory table part [p_partkey#24, p_retailprice#31], [isnotnull(p_retailprice#31), (cast(p_retailprice#31 as decimal(38,22)) > Subquery subquery#9055, [id=#7994]), isnotnull(p_partkey#24)]
#                :     :     :           :                 :- InMemoryRelation [p_partkey#24, p_name#25, p_mfgr#33, p_brand#34, p_type#28, p_size#29, p_container#35, p_retailprice#31, p_comment#32], StorageLevel(disk, memory, deserialized, 1 replicas)
#                :     :     :           :                 :     +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#                :     :     :           :                 :        +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
#                :     :     :           :                 +- Subquery subquery#9055, [id=#7994]
#                :     :     :           :                    +- AdaptiveSparkPlan isFinalPlan=false
#                :     :     :           :                       +- HashAggregate(keys=[], functions=[avg(p_retailprice#9065)], output=[avg(p_retailprice)#9057])
#                :     :     :           :                          +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=7978]
#                :     :     :           :                             +- HashAggregate(keys=[], functions=[partial_avg(p_retailprice#9065)], output=[sum#9651, count#9652L])
#                :     :     :           :                                +- Scan In-memory table part [p_retailprice#9065]
#                :     :     :           :                                      +- InMemoryRelation [p_partkey#9058, p_name#9059, p_mfgr#33, p_brand#34, p_type#9062, p_size#9063, p_container#35, p_retailprice#9065, p_comment#9066], StorageLevel(disk, memory, deserialized, 1 replicas)
#                :     :     :           :                                            +- *(1) Project [p_partkey#24, p_name#25, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_mfgr#26, 25, true, false, true) AS p_mfgr#33, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_brand#27, 10, true, false, true) AS p_brand#34, p_type#28, p_size#29, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, p_container#30, 10, true, false, true) AS p_container#35, p_retailprice#31, p_comment#32]
#                :     :     :           :                                               +- *(1) Scan JDBCRelation(part) [numPartitions=1] [p_partkey#24,p_name#25,p_mfgr#26,p_brand#27,p_type#28,p_size#29,p_container#30,p_retailprice#31,p_comment#32] PushedFilters: [], ReadSchema: struct<p_partkey:int,p_name:string,p_mfgr:string,p_brand:string,p_type:string,p_size:int,p_contai...
#                :     :     :           +- Sort [ps_partkey#157L ASC NULLS FIRST], false, 0
#                :     :     :              +- Exchange hashpartitioning(ps_partkey#157L, 200), ENSURE_REQUIREMENTS, [plan_id=8016]
#                :     :     :                 +- Filter (isnotnull(ps_partkey#157L) AND isnotnull(ps_suppkey#158L))
#                :     :     :                    +- Scan In-memory table partsupp [ps_partkey#157L, ps_suppkey#158L], [isnotnull(ps_partkey#157L), isnotnull(ps_suppkey#158L)]
#                :     :     :                          +- InMemoryRelation [ps_partkey#157L, ps_suppkey#158L, ps_availqty#159, ps_supplycost#160, ps_comment#161], StorageLevel(disk, memory, deserialized, 1 replicas)
#                :     :     :                                +- *(1) Scan JDBCRelation(partsupp) [numPartitions=1] [ps_partkey#157L,ps_suppkey#158L,ps_availqty#159,ps_supplycost#160,ps_comment#161] PushedFilters: [], ReadSchema: struct<ps_partkey:bigint,ps_suppkey:bigint,ps_availqty:int,ps_supplycost:decimal(38,18),ps_commen...
#                :     :     +- Sort [cast(s_suppkey#99 as bigint) ASC NULLS FIRST], false, 0
#                :     :        +- Exchange hashpartitioning(cast(s_suppkey#99 as bigint), 200), ENSURE_REQUIREMENTS, [plan_id=8024]
#                :     :           +- Filter (isnotnull(s_suppkey#99) AND isnotnull(s_nationkey#102L))
#                :     :              +- Scan In-memory table supplier [s_suppkey#99, s_nationkey#102L, s_acctbal#104], [isnotnull(s_suppkey#99), isnotnull(s_nationkey#102L)]
#                :     :                    +- InMemoryRelation [s_suppkey#99, s_name#106, s_address#101, s_nationkey#102L, s_phone#107, s_acctbal#104, s_comment#105], StorageLevel(disk, memory, deserialized, 1 replicas)
#                :     :                          +- *(1) Project [s_suppkey#99, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, s_name#100, 25, true, false, true) AS s_name#106, s_address#101, s_nationkey#102L, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, s_phone#103, 15, true, false, true) AS s_phone#107, s_acctbal#104, s_comment#105]
#                :     :                             +- *(1) Scan JDBCRelation(supplier) [numPartitions=1] [s_suppkey#99,s_name#100,s_address#101,s_nationkey#102L,s_phone#103,s_acctbal#104,s_comment#105] PushedFilters: [], ReadSchema: struct<s_suppkey:int,s_name:string,s_address:string,s_nationkey:bigint,s_phone:string,s_acctbal:d...
#                :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=8030]
#                :        +- Filter ((isnotnull(n_nationkey#470) AND isnotnull(n_regionkey#472L)) AND might_contain(Subquery subquery#10564, [id=#8002], xxhash64(n_regionkey#472L, 42)))
#                :           :  +- Subquery subquery#10564, [id=#8002]
#                :           :     +- AdaptiveSparkPlan isFinalPlan=false
#                :           :        +- ObjectHashAggregate(keys=[], functions=[bloom_filter_agg(xxhash64(cast(r_regionkey#503 as bigint), 42), 1000000, 8388608, 0, 0)], output=[bloomFilter#10563])
#                :           :           +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=7990]
#                :           :              +- ObjectHashAggregate(keys=[], functions=[partial_bloom_filter_agg(xxhash64(cast(r_regionkey#503 as bigint), 42), 1000000, 8388608, 0, 0)], output=[buf#10781])
#                :           :                 +- Project [r_regionkey#503]
#                :           :                    +- Filter (r_name#506 IN (EUROPE                   ,ASIA                     ) AND isnotnull(r_regionkey#503))
#                :           :                       +- Scan In-memory table region [r_name#506, r_regionkey#503], [r_name#506 IN (EUROPE                   ,ASIA                     ), isnotnull(r_regionkey#503)]
#                :           :                             +- InMemoryRelation [r_regionkey#503, r_name#506, r_comment#505], StorageLevel(disk, memory, deserialized, 1 replicas)
#                :           :                                   +- *(1) Project [r_regionkey#503, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, r_name#504, 25, true, false, true) AS r_name#506, r_comment#505]
#                :           :                                      +- *(1) Scan JDBCRelation(region) [numPartitions=1] [r_regionkey#503,r_name#504,r_comment#505] PushedFilters: [], ReadSchema: struct<r_regionkey:int,r_name:string,r_comment:string>
#                :           +- Scan In-memory table nation [n_nationkey#470, n_regionkey#472L], [isnotnull(n_nationkey#470), isnotnull(n_regionkey#472L), might_contain(Subquery subquery#10564, [id=#8004], xxhash64(n_regionkey#472L, 42))]
#                :                 :- InMemoryRelation [n_nationkey#470, n_name#474, n_regionkey#472L, n_comment#473], StorageLevel(disk, memory, deserialized, 1 replicas)
#                :                 :     +- *(1) Project [n_nationkey#470, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, n_name#471, 25, true, false, true) AS n_name#474, n_regionkey#472L, n_comment#473]
#                :                 :        +- *(1) Scan JDBCRelation(nation) [numPartitions=1] [n_nationkey#470,n_name#471,n_regionkey#472L,n_comment#473] PushedFilters: [], ReadSchema: struct<n_nationkey:int,n_name:string,n_regionkey:bigint,n_comment:string>
#                :                 +- Subquery subquery#10564, [id=#8004]
#                :                    +- AdaptiveSparkPlan isFinalPlan=false
#                :                       +- ObjectHashAggregate(keys=[], functions=[bloom_filter_agg(xxhash64(cast(r_regionkey#503 as bigint), 42), 1000000, 8388608, 0, 0)], output=[bloomFilter#10563])
#                :                          +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=7990]
#                :                             +- ObjectHashAggregate(keys=[], functions=[partial_bloom_filter_agg(xxhash64(cast(r_regionkey#503 as bigint), 42), 1000000, 8388608, 0, 0)], output=[buf#10781])
#                :                                +- Project [r_regionkey#503]
#                :                                   +- Filter (r_name#506 IN (EUROPE                   ,ASIA                     ) AND isnotnull(r_regionkey#503))
#                :                                      +- Scan In-memory table region [r_name#506, r_regionkey#503], [r_name#506 IN (EUROPE                   ,ASIA                     ), isnotnull(r_regionkey#503)]
#                :                                            +- InMemoryRelation [r_regionkey#503, r_name#506, r_comment#505], StorageLevel(disk, memory, deserialized, 1 replicas)
#                :                                                  +- *(1) Project [r_regionkey#503, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, r_name#504, 25, true, false, true) AS r_name#506, r_comment#505]
#                :                                                     +- *(1) Scan JDBCRelation(region) [numPartitions=1] [r_regionkey#503,r_name#504,r_comment#505] PushedFilters: [], ReadSchema: struct<r_regionkey:int,r_name:string,r_comment:string>
#                +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=8034]
#                   +- Project [r_regionkey#503]
#                      +- Filter (r_name#506 IN (EUROPE                   ,ASIA                     ) AND isnotnull(r_regionkey#503))
#                         +- Scan In-memory table region [r_name#506, r_regionkey#503], [r_name#506 IN (EUROPE                   ,ASIA                     ), isnotnull(r_regionkey#503)]
#                               +- InMemoryRelation [r_regionkey#503, r_name#506, r_comment#505], StorageLevel(disk, memory, deserialized, 1 replicas)
#                                     +- *(1) Project [r_regionkey#503, staticinvoke(class org.apache.spark.sql.catalyst.util.CharVarcharCodegenUtils, StringType, readSidePadding, r_name#504, 25, true, false, true) AS r_name#506, r_comment#505]
#                                        +- *(1) Scan JDBCRelation(region) [numPartitions=1] [r_regionkey#503,r_name#504,r_comment#505] PushedFilters: [], ReadSchema: struct<r_regionkey:int,r_name:string,r_comment:string>
#
# time ref: 35.316152572631836
# time yannakakis: 27.359992742538452
